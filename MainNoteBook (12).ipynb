# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
print("fd")
# Out:
# fd

# %%
print("fd")
# Out:
# fd

# %%
#df=pd.concat([df_1 , df_2 , df_3 ,df_4 , df_5, df_6, df_7 , df_8 ,df_9 , df_10,df_11 , df_12])

# %%
df=pd.read_csv('202106-divvy-tripdata.csv')
df
# Out:
#                  ride_id  rideable_type           started_at  \
# 0       99FEC93BA843FB20  electric_bike  2021-06-13 14:31:28
# 1       06048DCFC8520CAF  electric_bike  2021-06-04 11:18:02
# 2       9598066F68045DF2  electric_bike  2021-06-04 09:49:35
# 3       B03C0FE48C412214  electric_bike  2021-06-03 19:56:05
# 4       B9EEA89F8FEE73B7  electric_bike  2021-06-04 14:05:51
# ...                  ...            ...                  ...
# 729590  CB282292CCFCE74F  electric_bike  2021-06-14 00:17:31
# 729591  47BD346FAFB9BE6D   classic_bike  2021-06-30 17:35:10
# 729592  52467C23D17C6AFE   classic_bike  2021-06-13 19:24:30
# 729593  7DF6D74420D7D9E6  electric_bike  2021-06-08 15:44:28
# 729594  0C01F8BA99E512E5  electric_bike  2021-06-03 16:18:38
#
#                    ended_at      start_station_name start_station_id  \
# 0       2021-06-13 14:34:11                     NaN              NaN
# 1       2021-06-04 11:24:19                     NaN              NaN
# 2       2021-06-04 09:55:34                     NaN              NaN
# 3       2021-06-03 20:21:55                     NaN              NaN
# 4       2021-06-04 14:09:59                     NaN              NaN
# ...                     ...                     ...              ...
# 729590  2021-06-14 00:56:46      Wells St & Polk St           SL-011
# 729591  2021-06-30 17:43:20  Clark St & Chicago Ave            13303
# 729592  2021-06-13 19:34:11   Indiana Ave & 26th St     TA1307000005
# 729593  2021-06-08 16:15:01  Clark St & Chicago Ave            13303
# 729594  2021-06-03 16:47:49  Clark St & Chicago Ave            13303
#
#                 end_station_name end_station_id  start_lat  start_lng  \
# 0                            NaN            NaN  41.800000 -87.590000
# 1                            NaN            NaN  41.790000 -87.590000
# 2                            NaN            NaN  41.800000 -87.600000
# 3                            NaN            NaN  41.780000 -87.580000
# 4                            NaN            NaN  41.800000 -87.590000
# ...                          ...            ...        ...        ...
# 729590                       NaN            NaN  41.872412 -87.633715
# 729591  Kingsbury St & Kinzie St   KA1503000043  41.896750 -87.630890
# 729592        State St & 19th St         SL-013  41.845687 -87.622481
# 729593                       NaN            NaN  41.896485 -87.630608
# 729594                       NaN            NaN  41.896596 -87.630868
#
#           end_lat    end_lng member_casual
# 0       41.800000 -87.600000        member
# 1       41.800000 -87.600000        member
# 2       41.790000 -87.590000        member
# 3       41.800000 -87.600000        member
# 4       41.790000 -87.590000        member
# ...           ...        ...           ...
# 729590  41.880000 -87.620000        casual
# 729591  41.889177 -87.638506        member
# 729592  41.856594 -87.627542        member
# 729593  41.940000 -87.710000        member
# 729594  41.940000 -87.710000        member
#
# [729595 rows x 13 columns]

# %%
df_2=pd.read_csv('202107-divvy-tripdata.csv')
df_2
# Out:
#                  ride_id  rideable_type           started_at  \
# 0       0A1B623926EF4E16    docked_bike  2021-07-02 14:44:36
# 1       B2D5583A5A5E76EE   classic_bike  2021-07-07 16:57:42
# 2       6F264597DDBF427A   classic_bike  2021-07-25 11:30:55
# 3       379B58EAB20E8AA5   classic_bike  2021-07-08 22:08:30
# 4       6615C1E4EB08E8FB  electric_bike  2021-07-28 16:08:06
# ...                  ...            ...                  ...
# 822405  1E660BF8DCDAAAB6  electric_bike  2021-07-04 10:40:41
# 822406  A2448BDFD9B3653D  electric_bike  2021-07-04 12:47:41
# 822407  2D612BF8530379DA  electric_bike  2021-07-03 21:41:58
# 822408  6D615D18B765C9B3  electric_bike  2021-07-03 22:10:31
# 822409  0F31D311323F0048  electric_bike  2021-07-04 07:03:50
#
#                    ended_at            start_station_name start_station_id  \
# 0       2021-07-02 15:19:58  Michigan Ave & Washington St            13001
# 1       2021-07-07 17:16:09    California Ave & Cortez St            17660
# 2       2021-07-25 11:48:45          Wabash Ave & 16th St           SL-012
# 3       2021-07-08 22:23:32    California Ave & Cortez St            17660
# 4       2021-07-28 16:27:09    California Ave & Cortez St            17660
# ...                     ...                           ...              ...
# 822405  2021-07-04 11:30:13                           NaN              NaN
# 822406  2021-07-04 12:54:46                           NaN              NaN
# 822407  2021-07-03 21:57:14                           NaN              NaN
# 822408  2021-07-03 22:11:39                           NaN              NaN
# 822409  2021-07-04 07:32:38                           NaN              NaN
#
#                       end_station_name end_station_id  start_lat  start_lng  \
# 0         Halsted St & North Branch St   KA1504000117  41.883984 -87.624684
# 1                 Wood St & Hubbard St          13432  41.900363 -87.696704
# 2                 Rush St & Hubbard St   KA1503000044  41.860384 -87.625813
# 3              Carpenter St & Huron St          13196  41.900363 -87.696704
# 4       Elizabeth (May) St & Fulton St          13197  41.900350 -87.696682
# ...                                ...            ...        ...        ...
# 822405                             NaN            NaN  41.720000 -87.680000
# 822406                             NaN            NaN  41.770000 -87.660000
# 822407                             NaN            NaN  41.720000 -87.680000
# 822408                             NaN            NaN  41.720000 -87.680000
# 822409                             NaN            NaN  41.720000 -87.680000
#
#           end_lat    end_lng member_casual
# 0       41.899368 -87.648480        casual
# 1       41.889899 -87.671473        casual
# 2       41.890173 -87.626185        member
# 3       41.894556 -87.653449        member
# 4       41.886593 -87.658387        casual
# ...           ...        ...           ...
# 822405  41.770000 -87.660000        member
# 822406  41.780000 -87.660000        member
# 822407  41.720000 -87.680000        member
# 822408  41.720000 -87.680000        member
# 822409  41.720000 -87.680000        member
#
# [822410 rows x 13 columns]

# %%
df_3=pd.read_csv('202108-divvy-tripdata.csv')
df_3
# Out:
#                  ride_id  rideable_type           started_at  \
# 0       99103BB87CC6C1BB  electric_bike  2021-08-10 17:15:49
# 1       EAFCCCFB0A3FC5A1  electric_bike  2021-08-10 17:23:14
# 2       9EF4F46C57AD234D  electric_bike  2021-08-21 02:34:23
# 3       5834D3208BFAF1DA  electric_bike  2021-08-21 06:52:55
# 4       CD825CB87ED1D096  electric_bike  2021-08-19 11:55:29
# ...                  ...            ...                  ...
# 804347  5E5C9CD681E0419C   classic_bike  2021-08-07 18:07:43
# 804348  96FB57CF4AA456F6  electric_bike  2021-08-09 08:49:31
# 804349  226A0910DCCE904C   classic_bike  2021-08-12 16:55:57
# 804350  1A97D27AE23DE1E7   classic_bike  2021-08-08 22:47:43
# 804351  BBC36E4AA3652361  electric_bike  2021-08-27 18:53:53
#
#                    ended_at        start_station_name start_station_id  \
# 0       2021-08-10 17:22:44                       NaN              NaN
# 1       2021-08-10 17:39:24                       NaN              NaN
# 2       2021-08-21 02:50:36                       NaN              NaN
# 3       2021-08-21 07:08:13                       NaN              NaN
# 4       2021-08-19 12:04:11                       NaN              NaN
# ...                     ...                       ...              ...
# 804347  2021-08-07 18:21:21  Wells St & Evergreen Ave     TA1308000049
# 804348  2021-08-09 09:03:51    Broadway & Sheridan Rd            13323
# 804349  2021-08-12 17:15:10    Dearborn St & Adams St     TA1305000005
# 804350  2021-08-08 23:08:12    Broadway & Sheridan Rd            13323
# 804351  2021-08-27 19:02:16   Paulina Ave & North Ave     TA1305000037
#
#                    end_station_name end_station_id  start_lat  start_lng  \
# 0                               NaN            NaN  41.770000 -87.680000
# 1                               NaN            NaN  41.770000 -87.680000
# 2                               NaN            NaN  41.950000 -87.650000
# 3                               NaN            NaN  41.970000 -87.670000
# 4                               NaN            NaN  41.790000 -87.600000
# ...                             ...            ...        ...        ...
# 804347  Lincoln Ave & Diversey Pkwy   TA1307000064  41.906724 -87.634830
# 804348       Clark St & Lincoln Ave          13179  41.952709 -87.649940
# 804349       Clark St & Lincoln Ave          13179  41.879356 -87.629791
# 804350      Clark St & Winnemac Ave   TA1309000035  41.952833 -87.649993
# 804351        Dayton St & North Ave          13058  41.909851 -87.669808
#
#           end_lat    end_lng member_casual
# 0       41.770000 -87.680000        member
# 1       41.770000 -87.630000        member
# 2       41.970000 -87.660000        member
# 3       41.950000 -87.650000        member
# 4       41.770000 -87.620000        member
# ...           ...        ...           ...
# 804347  41.932225 -87.658617        member
# 804348  41.915973 -87.634762        member
# 804349  41.915689 -87.634600        member
# 804350  41.973348 -87.667855        casual
# 804351  41.910674 -87.649547        casual
#
# [804352 rows x 13 columns]

# %%
df_4=pd.read_csv('202109-divvy-tripdata.csv')
df_4
# Out:
#                  ride_id  rideable_type           started_at  \
# 0       9DC7B962304CBFD8  electric_bike  2021-09-28 16:07:10
# 1       F930E2C6872D6B32  electric_bike  2021-09-28 14:24:51
# 2       6EF72137900BB910  electric_bike  2021-09-28 00:20:16
# 3       78D1DE133B3DBF55  electric_bike  2021-09-28 14:51:17
# 4       E03D4ACDCAEF6E00  electric_bike  2021-09-28 09:53:12
# ...                  ...            ...                  ...
# 756142  FA66BCAB0D73DDC2   classic_bike  2021-09-22 15:46:57
# 756143  1D44DEFB5D36CA04   classic_bike  2021-09-25 16:25:23
# 756144  6A346EA57FC23C45   classic_bike  2021-09-25 16:26:05
# 756145  49360AFD771100A6   classic_bike  2021-09-15 17:57:48
# 756146  343190A2DC023FED  electric_bike  2021-09-11 18:01:06
#
#                    ended_at   start_station_name start_station_id  \
# 0       2021-09-28 16:09:54                  NaN              NaN
# 1       2021-09-28 14:40:05                  NaN              NaN
# 2       2021-09-28 00:23:57                  NaN              NaN
# 3       2021-09-28 15:00:06                  NaN              NaN
# 4       2021-09-28 10:03:44                  NaN              NaN
# ...                     ...                  ...              ...
# 756142  2021-09-22 16:01:15  Ellis Ave & 83rd St              584
# 756143  2021-09-25 16:40:29  Ellis Ave & 60th St     KA1503000014
# 756144  2021-09-25 16:40:30  Ellis Ave & 60th St     KA1503000014
# 756145  2021-09-15 18:24:06  Ellis Ave & 60th St     KA1503000014
# 756146  2021-09-11 18:08:26  Wells St & Huron St     TA1306000012
#
#                   end_station_name end_station_id  start_lat  start_lng  \
# 0                              NaN            NaN  41.890000 -87.680000
# 1                              NaN            NaN  41.940000 -87.640000
# 2                              NaN            NaN  41.810000 -87.720000
# 3                              NaN            NaN  41.800000 -87.720000
# 4                              NaN            NaN  41.880000 -87.740000
# ...                            ...            ...        ...        ...
# 756142  Stony Island Ave & 75th St   KA1503000019  41.744123 -87.599034
# 756143          Shore Dr & 55th St   TA1308000009  41.785097 -87.601073
# 756144          Shore Dr & 55th St   TA1308000009  41.785097 -87.601073
# 756145          Shore Dr & 55th St   TA1308000009  41.785097 -87.601073
# 756146        Clinton St & Lake St          13021  41.894887 -87.634343
#
#           end_lat    end_lng member_casual
# 0       41.890000 -87.670000        casual
# 1       41.980000 -87.670000        casual
# 2       41.800000 -87.720000        casual
# 3       41.810000 -87.720000        casual
# 4       41.880000 -87.710000        casual
# ...           ...        ...           ...
# 756142  41.758670 -87.586883        casual
# 756143  41.795212 -87.580715        casual
# 756144  41.795212 -87.580715        casual
# 756145  41.795212 -87.580715        casual
# 756146  41.885771 -87.641373        member
#
# [756147 rows x 13 columns]

# %%
df_5=pd.read_csv('202110-divvy-tripdata.csv')
df_5
# Out:
#                  ride_id  rideable_type           started_at  \
# 0       620BC6107255BF4C  electric_bike  2021-10-22 12:46:42
# 1       4471C70731AB2E45  electric_bike  2021-10-21 09:12:37
# 2       26CA69D43D15EE14  electric_bike  2021-10-16 16:28:39
# 3       362947F0437E1514  electric_bike  2021-10-16 16:17:48
# 4       BB731DE2F2EC51C5  electric_bike  2021-10-20 23:17:54
# ...                  ...            ...                  ...
# 631221  BA077FDD42DABF12   classic_bike  2021-10-14 21:45:05
# 631222  B7D99254E798AA6B   classic_bike  2021-10-02 15:28:28
# 631223  BCCFD66DA466400F  electric_bike  2021-10-08 16:47:10
# 631224  623E0F6F50CDD6E4   classic_bike  2021-10-08 07:49:47
# 631225  83FA6AC52B7B7A7B   classic_bike  2021-10-02 12:55:45
#
#                    ended_at           start_station_name start_station_id  \
# 0       2021-10-22 12:49:50     Kingsbury St & Kinzie St     KA1503000043
# 1       2021-10-21 09:14:14                          NaN              NaN
# 2       2021-10-16 16:36:26                          NaN              NaN
# 3       2021-10-16 16:19:03                          NaN              NaN
# 4       2021-10-20 23:26:10                          NaN              NaN
# ...                     ...                          ...              ...
# 631221  2021-10-14 22:07:25    Franklin St & Chicago Ave            13017
# 631222  2021-10-02 15:51:02      Streeter Dr & Grand Ave            13022
# 631223  2021-10-08 16:52:43        Calumet Ave & 21st St            15546
# 631224  2021-10-08 07:55:15        Calumet Ave & 21st St            15546
# 631225  2021-10-02 13:21:10  Winthrop Ave & Lawrence Ave     TA1308000021
#
#                      end_station_name end_station_id  start_lat  start_lng  \
# 0                                 NaN            NaN  41.889186 -87.638495
# 1                                 NaN            NaN  41.930000 -87.700000
# 2                                 NaN            NaN  41.920000 -87.700000
# 3                                 NaN            NaN  41.920000 -87.690000
# 4                                 NaN            NaN  41.890000 -87.710000
# ...                               ...            ...        ...        ...
# 631221         Michigan Ave & 14th St   TA1307000124  41.896747 -87.635668
# 631222         Michigan Ave & 14th St   TA1307000124  41.892278 -87.612043
# 631223         Michigan Ave & 14th St   TA1307000124  41.854055 -87.619187
# 631224         Michigan Ave & 14th St   TA1307000124  41.854184 -87.619154
# 631225  Sheffield Ave & Fullerton Ave   TA1306000016  41.968812 -87.657659
#
#           end_lat    end_lng member_casual
# 0       41.890000 -87.630000        member
# 1       41.930000 -87.710000        member
# 2       41.940000 -87.720000        member
# 3       41.920000 -87.690000        member
# 4       41.890000 -87.690000        member
# ...           ...        ...           ...
# 631221  41.864059 -87.623727        casual
# 631222  41.864059 -87.623727        casual
# 631223  41.864009 -87.623601        member
# 631224  41.864059 -87.623727        member
# 631225  41.925602 -87.653708        member
#
# [631226 rows x 13 columns]

# %%
df_6=pd.read_csv('202111-divvy-tripdata.csv')
df_6
# Out:
#                  ride_id  rideable_type           started_at  \
# 0       7C00A93E10556E47  electric_bike  2021-11-27 13:27:38
# 1       90854840DFD508BA  electric_bike  2021-11-27 13:38:25
# 2       0A7D10CDD144061C  electric_bike  2021-11-26 22:03:34
# 3       2F3BE33085BCFF02  electric_bike  2021-11-27 09:56:49
# 4       D67B4781A19928D4  electric_bike  2021-11-26 19:09:28
# ...                  ...            ...                  ...
# 359973  E00E9F3500D69BAA  electric_bike  2021-11-29 00:39:13
# 359974  8EAA66CE314E5FF1  electric_bike  2021-11-03 13:56:33
# 359975  36C2DC8BB1E13491  electric_bike  2021-11-02 19:32:18
# 359976  8E42FE5C67DF6A96  electric_bike  2021-11-10 20:15:06
# 359977  4F15069E2D2519BC  electric_bike  2021-11-30 20:18:00
#
#                    ended_at       start_station_name start_station_id  \
# 0       2021-11-27 13:46:38                      NaN              NaN
# 1       2021-11-27 13:56:10                      NaN              NaN
# 2       2021-11-26 22:05:56                      NaN              NaN
# 3       2021-11-27 10:01:50                      NaN              NaN
# 4       2021-11-26 19:30:41                      NaN              NaN
# ...                     ...                      ...              ...
# 359973  2021-11-29 00:51:41  Logan Blvd & Elston Ave     TA1308000031
# 359974  2021-11-03 14:01:27  Logan Blvd & Elston Ave     TA1308000031
# 359975  2021-11-02 19:36:16  Logan Blvd & Elston Ave     TA1308000031
# 359976  2021-11-10 20:22:01  Logan Blvd & Elston Ave     TA1308000031
# 359977  2021-11-30 20:37:27  Ogden Ave & Chicago Ave     TA1305000020
#
#        end_station_name end_station_id  start_lat  start_lng  end_lat  \
# 0                   NaN            NaN  41.930000 -87.720000    41.96
# 1                   NaN            NaN  41.960000 -87.700000    41.92
# 2                   NaN            NaN  41.960000 -87.700000    41.96
# 3                   NaN            NaN  41.940000 -87.790000    41.93
# 4                   NaN            NaN  41.900000 -87.630000    41.88
# ...                 ...            ...        ...        ...      ...
# 359973              NaN            NaN  41.929454 -87.684195    41.93
# 359974              NaN            NaN  41.929440 -87.684180    41.94
# 359975              NaN            NaN  41.929452 -87.684135    41.94
# 359976              NaN            NaN  41.929428 -87.684175    41.94
# 359977              NaN            NaN  41.896354 -87.653982    41.95
#
#         end_lng member_casual
# 0        -87.73        casual
# 1        -87.70        casual
# 2        -87.70        casual
# 3        -87.79        casual
# 4        -87.62        casual
# ...         ...           ...
# 359973   -87.72        member
# 359974   -87.69        member
# 359975   -87.69        member
# 359976   -87.69        member
# 359977   -87.70        member
#
# [359978 rows x 13 columns]

# %%
df_7=pd.read_csv('202112-divvy-tripdata.csv')
df_7
# Out:
#                  ride_id  rideable_type           started_at  \
# 0       46F8167220E4431F  electric_bike  2021-12-07 15:06:07
# 1       73A77762838B32FD  electric_bike  2021-12-11 03:43:29
# 2       4CF42452054F59C5  electric_bike  2021-12-15 23:10:28
# 3       3278BA87BF698339   classic_bike  2021-12-26 16:16:10
# 4       6FF54232576A3B73  electric_bike  2021-12-30 11:31:05
# ...                  ...            ...                  ...
# 247535  847431F3D5353AB7  electric_bike  2021-12-12 13:36:55
# 247536  CF407BBC3B9FAD63  electric_bike  2021-12-06 19:37:50
# 247537  60BB69EBF5440E92  electric_bike  2021-12-02 08:57:04
# 247538  C414F654A28635B8  electric_bike  2021-12-13 09:00:26
# 247539  37AC57E34B2E7E97   classic_bike  2021-12-13 08:45:32
#
#                    ended_at            start_station_name start_station_id  \
# 0       2021-12-07 15:13:42      Laflin St & Cullerton St            13307
# 1       2021-12-11 04:10:23         LaSalle Dr & Huron St     KP1705001026
# 2       2021-12-15 23:23:14  Halsted St & North Branch St     KA1504000117
# 3       2021-12-26 16:30:53  Halsted St & North Branch St     KA1504000117
# 4       2021-12-30 11:51:21      Leavitt St & Chicago Ave            18058
# ...                     ...                           ...              ...
# 247535  2021-12-12 13:56:08         Canal St & Madison St            13341
# 247536  2021-12-06 19:44:51         Canal St & Madison St            13341
# 247537  2021-12-02 09:05:21         Canal St & Madison St            13341
# 247538  2021-12-13 09:14:39        Lawndale Ave & 16th St            362.0
# 247539  2021-12-13 08:49:09   Michigan Ave & Jackson Blvd     TA1309000002
#
#                   end_station_name end_station_id  start_lat  start_lng  \
# 0              Morgan St & Polk St   TA1307000130  41.854833 -87.663660
# 1       Clarendon Ave & Leland Ave   TA1307000119  41.894405 -87.632331
# 2             Broadway & Barry Ave          13137  41.899357 -87.648522
# 3            LaSalle Dr & Huron St   KP1705001026  41.899390 -87.648545
# 4           Clark St & Drummond Pl   TA1307000142  41.895579 -87.682024
# ...                            ...            ...        ...        ...
# 247535                         NaN            NaN  41.882289 -87.639752
# 247536    Kingsbury St & Kinzie St   KA1503000043  41.882123 -87.640053
# 247537     Dearborn St & Monroe St   TA1305000006  41.881956 -87.639955
# 247538                         NaN            NaN  41.860000 -87.720000
# 247539     Dearborn St & Monroe St   TA1305000006  41.877850 -87.624080
#
#           end_lat    end_lng member_casual
# 0       41.871969 -87.650965        member
# 1       41.967968 -87.650001        casual
# 2       41.937582 -87.644098        member
# 3       41.894877 -87.632326        member
# 4       41.931248 -87.644336        member
# ...           ...        ...           ...
# 247535  41.890000 -87.610000        casual
# 247536  41.889106 -87.638862        member
# 247537  41.880254 -87.629603        member
# 247538  41.850000 -87.710000        member
# 247539  41.881320 -87.629521        member
#
# [247540 rows x 13 columns]

# %%
df_8=pd.read_csv('202201-divvy-tripdata.csv')
df_8
# Out:
#                  ride_id  rideable_type           started_at  \
# 0       C2F7DD78E82EC875  electric_bike  2022-01-13 11:59:47
# 1       A6CF8980A652D272  electric_bike  2022-01-10 08:41:56
# 2       BD0F91DFF741C66D   classic_bike  2022-01-25 04:53:40
# 3       CBB80ED419105406   classic_bike  2022-01-04 00:18:04
# 4       DDC963BFDDA51EEA   classic_bike  2022-01-20 01:31:10
# ...                  ...            ...                  ...
# 103765  8788DA3EDE8FD8AB  electric_bike  2022-01-18 12:36:48
# 103766  C6C3B64FDC827D8C  electric_bike  2022-01-27 11:00:06
# 103767  CA281AE7D8B06F5A  electric_bike  2022-01-10 16:14:51
# 103768  44E348991862319B  electric_bike  2022-01-19 13:22:11
# 103769  E477C594A182AE58  electric_bike  2022-01-13 17:24:43
#
#                    ended_at             start_station_name start_station_id  \
# 0       2022-01-13 12:02:44       Glenwood Ave & Touhy Ave              525
# 1       2022-01-10 08:46:17       Glenwood Ave & Touhy Ave              525
# 2       2022-01-25 04:58:01  Sheffield Ave & Fullerton Ave     TA1306000016
# 3       2022-01-04 00:33:00       Clark St & Bryn Mawr Ave     KA1504000151
# 4       2022-01-20 01:37:12    Michigan Ave & Jackson Blvd     TA1309000002
# ...                     ...                            ...              ...
# 103765  2022-01-18 12:46:19   Clinton St & Washington Blvd           WL-012
# 103766  2022-01-27 11:02:40       Racine Ave & Randolph St            13155
# 103767  2022-01-10 16:20:58        Broadway & Waveland Ave            13325
# 103768  2022-01-19 13:24:27       Racine Ave & Randolph St            13155
# 103769  2022-01-13 17:28:14   Clinton St & Washington Blvd           WL-012
#
#                      end_station_name end_station_id  start_lat  start_lng  \
# 0                Clark St & Touhy Ave         RP-007  42.012800 -87.665906
# 1                Clark St & Touhy Ave         RP-007  42.012763 -87.665967
# 2       Greenview Ave & Fullerton Ave   TA1307000001  41.925602 -87.653708
# 3           Paulina St & Montrose Ave   TA1309000021  41.983593 -87.669154
# 4              State St & Randolph St   TA1305000029  41.877850 -87.624080
# ...                               ...            ...        ...        ...
# 103765                            NaN            NaN  41.883436 -87.641391
# 103766                            NaN            NaN  41.884158 -87.656977
# 103767            Clark St & Grace St   TA1307000127  41.949066 -87.648611
# 103768                            NaN            NaN  41.884005 -87.657031
# 103769      Desplaines St & Kinzie St   TA1306000003  41.883248 -87.641244
#
#           end_lat    end_lng member_casual
# 0       42.012560 -87.674367        casual
# 1       42.012560 -87.674367        casual
# 2       41.925330 -87.665800        member
# 3       41.961507 -87.671387        casual
# 4       41.884621 -87.627834        member
# ...           ...        ...           ...
# 103765  41.890000 -87.620000        casual
# 103766  41.880000 -87.650000        casual
# 103767  41.950780 -87.659172        casual
# 103768  41.880000 -87.660000        casual
# 103769  41.888716 -87.644448        casual
#
# [103770 rows x 13 columns]

# %%
df_9=pd.read_csv('202202-divvy-tripdata.csv')
df_9
# Out:
#                  ride_id  rideable_type           started_at  \
# 0       E1E065E7ED285C02   classic_bike  2022-02-19 18:08:41
# 1       1602DCDC5B30FFE3   classic_bike  2022-02-20 17:41:30
# 2       BE7DD2AF4B55C4AF   classic_bike  2022-02-25 18:55:56
# 3       A1789BDF844412BE   classic_bike  2022-02-14 11:57:03
# 4       07DE78092C62F7B3   classic_bike  2022-02-16 05:36:06
# ...                  ...            ...                  ...
# 115604  211BE0DC162D85B7  electric_bike  2022-02-23 17:47:49
# 115605  D4D53E78000C8CA1  electric_bike  2022-02-04 10:43:47
# 115606  9E85F07D2F94492B  electric_bike  2022-02-28 09:16:33
# 115607  B61B559F81F1D823  electric_bike  2022-02-10 16:55:16
# 115608  841C701610CF0609  electric_bike  2022-02-21 16:35:20
#
#                    ended_at            start_station_name start_station_id  \
# 0       2022-02-19 18:23:56        State St & Randolph St     TA1305000029
# 1       2022-02-20 17:45:56   Halsted St & Wrightwood Ave     TA1309000061
# 2       2022-02-25 19:09:34        State St & Randolph St     TA1305000029
# 3       2022-02-14 12:04:00  Southport Ave & Waveland Ave            13235
# 4       2022-02-16 05:39:00        State St & Randolph St     TA1305000029
# ...                     ...                           ...              ...
# 115604  2022-02-23 18:02:29                           NaN              NaN
# 115605  2022-02-04 10:50:52                           NaN              NaN
# 115606  2022-02-28 09:28:11         Wood St & Chicago Ave              637
# 115607  2022-02-10 16:57:53                           NaN              NaN
# 115608  2022-02-21 16:42:53                           NaN              NaN
#
#                       end_station_name end_station_id  start_lat  start_lng  \
# 0               Clark St & Lincoln Ave          13179  41.884621 -87.627834
# 1       Southport Ave & Wrightwood Ave   TA1307000113  41.929143 -87.649077
# 2                  Canal St & Adams St          13011  41.884621 -87.627834
# 3               Broadway & Sheridan Rd          13323  41.948150 -87.663940
# 4                Franklin St & Lake St   TA1307000111  41.884621 -87.627834
# ...                                ...            ...        ...        ...
# 115604        Leavitt St & Chicago Ave          18058  41.880000 -87.630000
# 115605        Leavitt St & Chicago Ave          18058  41.910000 -87.680000
# 115606             Canal St & Adams St          13011  41.895714 -87.672210
# 115607             Canal St & Adams St          13011  41.880000 -87.630000
# 115608            Larrabee St & Oak St   KA1504000116  41.880000 -87.650000
#
#           end_lat    end_lng member_casual
# 0       41.915689 -87.634600        member
# 1       41.928773 -87.663913        member
# 2       41.879255 -87.639904        member
# 3       41.952833 -87.649993        member
# 4       41.885837 -87.635500        member
# ...           ...        ...           ...
# 115604  41.895501 -87.682017        member
# 115605  41.895501 -87.682017        member
# 115606  41.879255 -87.639904        member
# 115607  41.879255 -87.639904        member
# 115608  41.900219 -87.642985        member
#
# [115609 rows x 13 columns]

# %%
df_10=pd.read_csv('202203-divvy-tripdata.csv')
df_10
# Out:
#                  ride_id  rideable_type           started_at  \
# 0       47EC0A7F82E65D52   classic_bike  2022-03-21 13:45:01
# 1       8494861979B0F477  electric_bike  2022-03-16 09:37:16
# 2       EFE527AF80B66109   classic_bike  2022-03-23 19:52:02
# 3       9F446FD9DEE3F389   classic_bike  2022-03-01 19:12:26
# 4       431128AD9AFFEDC0   classic_bike  2022-03-21 18:37:01
# ...                  ...            ...                  ...
# 284037  E23BE3DB740BE3B4    docked_bike  2022-03-13 16:31:03
# 284038  15AF71F3220F2A75    docked_bike  2022-03-09 06:56:02
# 284039  9C4CE6CC19F8225B  electric_bike  2022-03-09 15:55:26
# 284040  F4E136DEF696F3AE  electric_bike  2022-03-21 16:12:44
# 284041  5AEC5F39AF711895   classic_bike  2022-03-03 18:13:40
#
#                    ended_at                  start_station_name  \
# 0       2022-03-21 13:51:18              Wabash Ave & Wacker Pl
# 1       2022-03-16 09:43:34               Michigan Ave & Oak St
# 2       2022-03-23 19:54:48               Broadway & Berwyn Ave
# 3       2022-03-01 19:22:14              Wabash Ave & Wacker Pl
# 4       2022-03-21 19:19:11  DuSable Lake Shore Dr & North Blvd
# ...                     ...                                 ...
# 284037  2022-03-13 16:39:32               Michigan Ave & Oak St
# 284038  2022-03-09 07:42:14                Broadway & Barry Ave
# 284039  2022-03-09 16:08:54                                 NaN
# 284040  2022-03-21 16:18:24                                 NaN
# 284041  2022-03-03 18:23:39              Clark St & Randolph St
#
#        start_station_id                      end_station_name end_station_id  \
# 0          TA1307000131              Kingsbury St & Kinzie St   KA1503000043
# 1                 13042  Orleans St & Chestnut St (NEXT Apts)            620
# 2                 13109                  Broadway & Ridge Ave          15578
# 3          TA1307000131            Franklin St & Jackson Blvd   TA1305000025
# 4                LF-005              Loomis St & Jackson Blvd          13206
# ...                 ...                                   ...            ...
# 284037            13042               Streeter Dr & Grand Ave          13022
# 284038            13137          Ravenswood Ave & Berteau Ave   TA1309000018
# 284039              NaN             Albany Ave & Montrose Ave          15621
# 284040              NaN             Larrabee St & Division St   KA1504000079
# 284041     TA1305000030               Streeter Dr & Grand Ave          13022
#
#         start_lat  start_lng    end_lat    end_lng member_casual
# 0       41.886875 -87.626030  41.889177 -87.638506        member
# 1       41.900998 -87.623752  41.898203 -87.637536        member
# 2       41.978353 -87.659753  41.984045 -87.660274        member
# 3       41.886875 -87.626030  41.877708 -87.635321        member
# 4       41.911722 -87.626804  41.877945 -87.662007        member
# ...           ...        ...        ...        ...           ...
# 284037  41.900960 -87.623777  41.892278 -87.612043        casual
# 284038  41.937582 -87.644098  41.957921 -87.673567        casual
# 284039  41.940000 -87.710000  41.961041 -87.705866        member
# 284040  41.910000 -87.650000  41.903486 -87.643353        member
# 284041  41.884576 -87.631890  41.892278 -87.612043        member
#
# [284042 rows x 13 columns]

# %%
df_11=pd.read_csv('202204-divvy-tripdata.csv')
df_11
# Out:
#                  ride_id  rideable_type           started_at  \
# 0       3564070EEFD12711  electric_bike  2022-04-06 17:42:48
# 1       0B820C7FCF22F489   classic_bike  2022-04-24 19:23:07
# 2       89EEEE32293F07FF   classic_bike  2022-04-20 19:29:08
# 3       84D4751AEB31888D   classic_bike  2022-04-22 21:14:06
# 4       5664BCF0D1DE7A8B  electric_bike  2022-04-16 15:56:30
# ...                  ...            ...                  ...
# 371244  C5A123D7BF8D350A  electric_bike  2022-04-22 15:54:11
# 371245  F7FCC7C26D8D137D  electric_bike  2022-04-21 20:18:17
# 371246  43D351300A40000A   classic_bike  2022-04-21 16:46:02
# 371247  1618BFEEA7B566EF  electric_bike  2022-04-16 13:19:44
# 371248  92C069001A6B17B1  electric_bike  2022-04-21 18:06:41
#
#                    ended_at          start_station_name start_station_id  \
# 0       2022-04-06 17:54:36      Paulina St & Howard St              515
# 1       2022-04-24 19:43:17   Wentworth Ave & Cermak Rd            13075
# 2       2022-04-20 19:35:16        Halsted St & Polk St     TA1307000121
# 3       2022-04-22 21:23:29   Wentworth Ave & Cermak Rd            13075
# 4       2022-04-16 16:02:11        Halsted St & Polk St     TA1307000121
# ...                     ...                         ...              ...
# 371244  2022-04-22 16:20:59     Streeter Dr & Grand Ave            13022
# 371245  2022-04-21 20:46:45     Streeter Dr & Grand Ave            13022
# 371246  2022-04-21 17:15:05     Franklin St & Monroe St     TA1309000007
# 371247  2022-04-16 13:37:31  Ashland Ave & Blackhawk St            13224
# 371248  2022-04-21 18:11:49    Southport Ave & Clark St     TA1308000047
#
#                     end_station_name end_station_id  start_lat  start_lng  \
# 0            University Library (NU)            605  42.019135 -87.673532
# 1              Green St & Madison St   TA1307000120  41.853085 -87.631931
# 2              Green St & Madison St   TA1307000120  41.871840 -87.646640
# 3           Delano Ct & Roosevelt Rd   KA1706005007  41.853085 -87.631931
# 4            Clinton St & Madison St   TA1305000032  41.871808 -87.646574
# ...                              ...            ...        ...        ...
# 371244    California Ave & North Ave          13258  41.892296 -87.612198
# 371245    California Ave & North Ave          13258  41.892295 -87.612323
# 371246        St. Clair St & Erie St          13016  41.880317 -87.635185
# 371247  Southport Ave & Waveland Ave          13235  41.907094 -87.667217
# 371248  Southport Ave & Waveland Ave          13235  41.957102 -87.664184
#
#           end_lat    end_lng member_casual
# 0       42.052939 -87.673447        member
# 1       41.881892 -87.648789        member
# 2       41.881892 -87.648789        member
# 3       41.867491 -87.632190        casual
# 4       41.882242 -87.641066        member
# ...           ...        ...           ...
# 371244  41.910475 -87.696894        member
# 371245  41.910475 -87.696894        member
# 371246  41.894345 -87.622798        member
# 371247  41.948150 -87.663940        casual
# 371248  41.948150 -87.663940        casual
#
# [371249 rows x 13 columns]

# %%
df_12=pd.read_csv('202205-divvy-tripdata.csv')
df_12
# Out:
#                  ride_id  rideable_type           started_at  \
# 0       EC2DE40644C6B0F4   classic_bike  2022-05-23 23:06:58
# 1       1C31AD03897EE385   classic_bike  2022-05-11 08:53:28
# 2       1542FBEC830415CF   classic_bike  2022-05-26 18:36:28
# 3       6FF59852924528F8   classic_bike  2022-05-10 07:30:07
# 4       483C52CAAE12E3AC   classic_bike  2022-05-10 17:31:56
# ...                  ...            ...                  ...
# 634853  8891BA0053ECEC4F  electric_bike  2022-05-27 22:00:02
# 634854  47D8B5FBCADECFC1  electric_bike  2022-05-15 16:05:39
# 634855  AA8D16CF38B40703  electric_bike  2022-05-21 10:10:13
# 634856  897EBFD44F329E0A  electric_bike  2022-05-12 07:53:58
# 634857  AAC23AB89E8A7733  electric_bike  2022-05-11 21:14:28
#
#                    ended_at                 start_station_name  \
# 0       2022-05-23 23:40:19             Wabash Ave & Grand Ave
# 1       2022-05-11 09:31:22  DuSable Lake Shore Dr & Monroe St
# 2       2022-05-26 18:58:18            Clinton St & Madison St
# 3       2022-05-10 07:38:49            Clinton St & Madison St
# 4       2022-05-10 17:36:57            Clinton St & Madison St
# ...                     ...                                ...
# 634853  2022-05-27 22:07:01              Clark St & Newport St
# 634854  2022-05-15 16:44:12              Clark St & Newport St
# 634855  2022-05-21 10:26:09   Francisco Ave & Bloomingdale Ave
# 634856  2022-05-12 08:01:18   Francisco Ave & Bloomingdale Ave
# 634857  2022-05-11 21:18:16              Clark St & Newport St
#
#        start_station_id             end_station_name end_station_id  \
# 0          TA1307000117       Halsted St & Roscoe St   TA1309000025
# 1                 13300  Field Blvd & South Water St          15534
# 2          TA1305000032      Wood St & Milwaukee Ave          13221
# 3          TA1305000032       Clark St & Randolph St   TA1305000030
# 4          TA1305000032          Morgan St & Lake St   TA1306000015
# ...                 ...                          ...            ...
# 634853              632                          NaN            NaN
# 634854              632                          NaN            NaN
# 634855              429                          NaN            NaN
# 634856              429                          NaN            NaN
# 634857              632                          NaN            NaN
#
#         start_lat  start_lng    end_lat    end_lng member_casual
# 0       41.891466 -87.626761  41.943670 -87.648950        member
# 1       41.880958 -87.616743  41.886349 -87.617517        member
# 2       41.882242 -87.641066  41.907655 -87.672552        member
# 3       41.882242 -87.641066  41.884576 -87.631890        member
# 4       41.882242 -87.641066  41.885779 -87.651025        member
# ...           ...        ...        ...        ...           ...
# 634853  41.944557 -87.654830  41.920000 -87.650000        member
# 634854  41.944479 -87.654758  41.920000 -87.760000        member
# 634855  41.910000 -87.700000  41.920000 -87.660000        casual
# 634856  41.910000 -87.700000  41.900000 -87.690000        member
# 634857  41.944567 -87.654802  41.940000 -87.650000        member
#
# [634858 rows x 13 columns]

# %%
df=df.append([df_2 , df_3 ,df_4 , df_5, df_6, df_7 , df_8 ,df_9 , df_10,df_11 , df_12],ignore_index=True)

# %%
df
# Out:
#                   ride_id  rideable_type           started_at  \
# 0        99FEC93BA843FB20  electric_bike  2021-06-13 14:31:28
# 1        06048DCFC8520CAF  electric_bike  2021-06-04 11:18:02
# 2        9598066F68045DF2  electric_bike  2021-06-04 09:49:35
# 3        B03C0FE48C412214  electric_bike  2021-06-03 19:56:05
# 4        B9EEA89F8FEE73B7  electric_bike  2021-06-04 14:05:51
# ...                   ...            ...                  ...
# 5860771  8891BA0053ECEC4F  electric_bike  2022-05-27 22:00:02
# 5860772  47D8B5FBCADECFC1  electric_bike  2022-05-15 16:05:39
# 5860773  AA8D16CF38B40703  electric_bike  2022-05-21 10:10:13
# 5860774  897EBFD44F329E0A  electric_bike  2022-05-12 07:53:58
# 5860775  AAC23AB89E8A7733  electric_bike  2022-05-11 21:14:28
#
#                     ended_at                start_station_name  \
# 0        2021-06-13 14:34:11                               NaN
# 1        2021-06-04 11:24:19                               NaN
# 2        2021-06-04 09:55:34                               NaN
# 3        2021-06-03 20:21:55                               NaN
# 4        2021-06-04 14:09:59                               NaN
# ...                      ...                               ...
# 5860771  2022-05-27 22:07:01             Clark St & Newport St
# 5860772  2022-05-15 16:44:12             Clark St & Newport St
# 5860773  2022-05-21 10:26:09  Francisco Ave & Bloomingdale Ave
# 5860774  2022-05-12 08:01:18  Francisco Ave & Bloomingdale Ave
# 5860775  2022-05-11 21:18:16             Clark St & Newport St
#
#         start_station_id end_station_name end_station_id  start_lat  \
# 0                    NaN              NaN            NaN  41.800000
# 1                    NaN              NaN            NaN  41.790000
# 2                    NaN              NaN            NaN  41.800000
# 3                    NaN              NaN            NaN  41.780000
# 4                    NaN              NaN            NaN  41.800000
# ...                  ...              ...            ...        ...
# 5860771              632              NaN            NaN  41.944557
# 5860772              632              NaN            NaN  41.944479
# 5860773              429              NaN            NaN  41.910000
# 5860774              429              NaN            NaN  41.910000
# 5860775              632              NaN            NaN  41.944567
#
#          start_lng  end_lat  end_lng member_casual
# 0       -87.590000    41.80   -87.60        member
# 1       -87.590000    41.80   -87.60        member
# 2       -87.600000    41.79   -87.59        member
# 3       -87.580000    41.80   -87.60        member
# 4       -87.590000    41.79   -87.59        member
# ...            ...      ...      ...           ...
# 5860771 -87.654830    41.92   -87.65        member
# 5860772 -87.654758    41.92   -87.76        member
# 5860773 -87.700000    41.92   -87.66        casual
# 5860774 -87.700000    41.90   -87.69        member
# 5860775 -87.654802    41.94   -87.65        member
#
# [5860776 rows x 13 columns]

# %%
#df[df['started_at']==df['ended_at']]

# %%
# Check For duplicated Data
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ## Lest Apply univariate analysis

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5860776 entries, 0 to 5860775
# Data columns (total 13 columns):
#  #   Column              Dtype
# ---  ------              -----
#  0   ride_id             object
#  1   rideable_type       object
#  2   started_at          object
#  3   ended_at            object
#  4   start_station_name  object
#  5   start_station_id    object
#  6   end_station_name    object
#  7   end_station_id      object
#  8   start_lat           float64
#  9   start_lng           float64
#  10  end_lat             float64
#  11  end_lng             float64
#  12  member_casual       object
# dtypes: float64(4), object(9)
# memory usage: 581.3+ MB

# %%
df['ride_id'].unique().tolist()
# Out:
# ['99FEC93BA843FB20',
#  '06048DCFC8520CAF',
#  '9598066F68045DF2',
#  'B03C0FE48C412214',
#  'B9EEA89F8FEE73B7',
#  '62B943CEAAA420BA',
#  '7E2546FBA79C46EE',
#  '3DDF3BBF6C4C3C89',
#  '2608805637155AB6',
#  'AF529C946F28ED42',
#  'E6010941FB92E4A6',
#  '1149C0723F7AFFD5',
#  '8762DB62099E6011',
#  'BE3AC77CBFF17E6A',
#  '8E9F2CB0893B96A0',
#  '6344B71B7BB6E09E',
#  '59CE9444E2ED2530',
#  '2D6929277855EBE5',
#  'F7107122A837A50B',
#  '45ABF9231CC02E3C',
#  '72A9D5DE0570104F',
#  '82EDA4ED954704C5',
#  '922E13B48EA4669B',
#  '77A2D0AE046B18ED',
#  '56E82E79B2D32963',
#  '2898BD8A94246F91',
#  '7541F4775B76B62F',
#  '901AD3F46D418897',
#  'EADD330AC4F28667',
#  'AACFC0AD742E15BC',
#  '5620F68FAF041C96',
#  '8FA2BB0200F008D4',
#  '5A8763CE97B3A8A0',
#  '98B404C87F4122E1',
#  '9822A8E834308933',
#  'A714D49E229150CD',
#  '3EF7CA50A21BEB5B',
#  'D6D06D1E6C4B3AAA',
#  '73FAA1C75EE2548E',
#  '70FD4BA48730FB8C',
#  '33891F0F00036C9C',
#  'BB764626C8627DBC',
#  'BB76805F3AA2DB21',
#  '36BD8B9A9606DE12',
#  '86FD7B218D70DCFB',
#  'E0A442C8EE0E9538',
#  'B67725D9606A85F8',
#  '0C213740A7CDFA4D',
#  'E75148DEE48C13D0',
#  '77904BEC09446E8D',
#  '0D904FEC5F84A538',
#  'C4185F300D6B552B',
#  '084B50A56D96F00C',
#  '60F97090AC85F55E',
#  'FB01BFE0C295B22B',
#  '9F8A6A90B1B3E083',
#  'FBC7B1F0160AA304',
#  '37A52001AEEFA4E5',
#  '76EBCE0447BD7276',
#  'A983B0285F949434',
#  '18A43747D6725F40',
#  'F33251175ABE836D',
#  '0DBFA221F45B20FA',
#  '095FD6C608510156',
#  '42369ACFF2D6A1FA',
#  'E86EFC2EF5462AAF',
#  'E49E5426F0B74023',
#  'BBE0E4CB78DC0C1C',
#  '5C82525EA81EE731',
#  '005F84793A1B6CA3',
#  'CC1DD5FE24C22927',
#  'BA16164272308D6C',
#  '2D7C13EA5494E100',
#  '96C90CEA38DC9D59',
#  '57802BCD7A4EB75F',
#  '7B9B8F431B6B46B5',
#  'C0B2A2D07DA7795A',
#  'B67171B41889482B',
#  '343597E46A233858',
#  '4CF3D9C5DD036935',
#  'EA62343059A2CE84',
#  '318F391B5A5E11EA',
#  'CBA9394BDEC25955',
#  'A0FCE305E80B1CF0',
#  'BE652C0BA89F0F19',
#  '1F4223B4DA441392',
#  'BDA9627EE0A0FC2E',
#  'D4EC17F2B5D6725A',
#  'A5877E4976F9FDBD',
#  'ADA876FA80A2AFB6',
#  '1402BC0102F8401B',
#  '997C8A5373256DFC',
#  'D5BEFD5891985FAC',
#  'AF7BB3D697992127',
#  '931CB7633018437F',
#  'B00B4A21AB969648',
#  'A8187E8E0E12D9DA',
#  'B8B7CD076CD9238D',
#  '7C0256DC1B909725',
#  '3F3E7D050BC7BE4C',
#  'AFA1EB74258B8074',
#  '4BBB8C3F0A64F1D4',
#  '1092FB370BF8C3CC',
#  'A1A6972AB1C259B2',
#  '02255041C7A3EAAA',
#  '36455E79D2147BE7',
#  'A577A098B2EEE3C7',
#  '22DDFEFE3AF9AF5A',
#  'D0E0F646A8BE351A',
#  '26AD7173645707C7',
#  'D08F5356E9D89E0E',
#  'FC96999D53BEEC46',
#  '72C43E37E0401861',
#  '8BFBD3ED3B6A1DFD',
#  '6BDFE6F915B93BB7',
#  '316203BE7008E67F',
#  'CD28450B9E1CC918',
#  '7B9C239614E58AE3',
#  'CC6B26881D5116A7',
#  'C90091A35D160803',
#  '43CAE32DAF16BFB6',
#  '8965BBCC4286B2E9',
#  'ACEDB608C557CA11',
#  '35CB5FCA45756202',
#  '7FDD594162C7FED9',
#  '6A40BE8657A9F958',
#  'ADAECFEFED0DF5A9',
#  'B5B99B3A77CF71F1',
#  '5A7076F3B76DDB6C',
#  'F1356F3062AF7094',
#  '40017AC671081797',
#  '0D0F9C79AE993188',
#  'DECBE1A87ABBD7F5',
#  '6974A4534D72FE47',
#  '46485E4014175528',
#  '3F4668B9AEDB4EAD',
#  '3DF37932DC3B66D0',
#  '39FD89C527EEE642',
#  'B71FDEBB4D8E082E',
#  '1D9BA2F635532F0B',
#  '7936560B9441E414',
#  '75B574C46A3254EA',
#  'DA9DE950CDCC9DE1',
#  '3CBE0A235B0B2AD3',
#  '3D76092C464FA22A',
#  '0137E25F0A3666AF',
#  'FBFA867A5DDF3C8E',
#  '348B788FD312E42A',
#  '2396610848658A54',
#  '55E4D236C8213093',
#  'CB23B53FDB5F32D1',
#  '46510F4C04EECCF2',
#  'BC304173488419E7',
#  'BD20ACF1862503B5',
#  '003F6A48DEFEF945',
#  'F2000E1FA9AA2BDE',
#  '0D24A048CDA47E50',
#  '6FFE0A7B2FC7A92D',
#  '2CF785C1E8379AD7',
#  '8C1F79023C6B9BE9',
#  'FB2F95B54619F5EC',
#  '18447DCA82C197B0',
#  'CD161AD27F0179FD',
#  '8DF548C70816224F',
#  '0E76402E4A574AC3',
#  'A3437D638F0A6035',
#  '43FD1BC8BF5A1DC0',
#  'AF7418842A8EB3CA',
#  '582692571DEE3A1A',
#  'D9B69B3EA13483CD',
#  'B46853430BD23970',
#  '9D11EFC79C0AC84F',
#  '793C266C7839F5FA',
#  'B93BEC32D4FC24EF',
#  'FA720CB32DCB6F8B',
#  'D67AB9696A31EB2A',
#  '58572C39676AC805',
#  '2C569F23225515C1',
#  'A5263126E46BDB36',
#  '22D9E1FCF3A48C87',
#  '55F18034CC6ED8CB',
#  '57CCEDD875A46E15',
#  '08B37BEC063E312B',
#  'C7DAE95BD25D7812',
#  'C7CB2E47862B4543',
#  '2B8A2C08953DE160',
#  'C62BE34CF33C73DF',
#  'CB50E548AA70183E',
#  'F38094FF5314C4C9',
#  'C59C27D5966C2687',
#  '13CEB4FEA72E0BD2',
#  '28EB8F63288B5009',
#  'AAD9B0718A051AFE',
#  '67CB19C55DDCAADE',
#  '599EEF88B6DBA204',
#  '785BA6F24D35C813',
#  '4631511715A1825D',
#  'E5EDBD471DFECDD2',
#  '8C5036C335A4BD62',
#  'BA1A4019925911A3',
#  'F3E6E1A5B6BD19AF',
#  '223088CF254C8F78',
#  '97DA84A49A5AB0AA',
#  'EC4CFF45C77AEE34',
#  'B6EFB42334065739',
#  '1453DFC456D13134',
#  'D4355E27B14404C1',
#  'CF1DBC9A4BE37A91',
#  '46E3A5218210C4A6',
#  'C3277F8A7809798B',
#  'F8C8FAA9A8F6F328',
#  'E30A478C68F74C36',
#  '7690C5CD485F20EE',
#  '04C9ABA6A1FCC5E7',
#  '6ED1F51FA4EC018B',
#  '13D518865A9F0CA0',
#  '43CEE756F7FD2F44',
#  'E0863098FF1CA0C5',
#  '9A1A68E010BD8639',
#  'E2BAE6ADF1FA3676',
#  '2953D4A85F8A6A0A',
#  '8EF7E0E794F89FF0',
#  'CAEFBB5D6CDD9520',
#  'D47443D28302BCD5',
#  'BE785501E9F3008D',
#  '07F3AE55318F1E35',
#  '254384CE12F37671',
#  'A20E13CBFD0BC206',
#  '38D67BCCF380A714',
#  '9DA9D7A530B75AB8',
#  'C2D72D5F317970E4',
#  '3756618764D78BEF',
#  '7040D5936470EAE5',
#  'D42C59A947A1EA6D',
#  '522D2E7C004F2161',
#  '06F9CFD3F0E813A7',
#  '56C693984424B0AD',
#  'BDA20F9C6E619FA5',
#  '59D976EBADFDED2D',
#  'CAB1E6FA8A3DCA52',
#  'F9D4E9207FE607E9',
#  '6C942ECB10587A28',
#  '168C9FE9CE3D5A1B',
#  '3085FF3CD9DE77F1',
#  '55D0574DA0B5FF85',
#  '11388BD1E012ADD3',
#  '4389779A4AE33481',
#  'EA00AB1167E9108D',
#  '0E361905772AD404',
#  '60D8C6A1ABA191D0',
#  '4B17B99201A64E9E',
#  '3320B6AB42FD7A66',
#  '8C74224C237BB6D8',
#  '3C33EC71C7FEBC9C',
#  'C46B54623EF20231',
#  '07CA7B861F4509C7',
#  'DF3BC865F660A85B',
#  '4080BF1546D5EE23',
#  '5C72419AC39F559D',
#  '40BCF61EF0838901',
#  'F6496DF223062E4D',
#  'C6D699AD4CCB3A9E',
#  '184AAAC9194A4DAB',
#  '5D0F76ABDB3D731A',
#  'C606B93B5C74C938',
#  '3CC4D83811B04F25',
#  '65C4EBA5ED2ADF6A',
#  '1D49BB8D36382F67',
#  '8747C83487C3FA04',
#  '2B4FB98F1CEAE6FE',
#  '766FB1D6E433DE3E',
#  '0599685EB9255255',
#  '91E9565A0104FEE6',
#  'A1ECBA8A21FA3DCB',
#  'FB3612A303016D58',
#  '8DCBAA979872F8B4',
#  '421DC194BFC146D0',
#  '8C001BB103C3CA88',
#  '764B7A5AD51E7594',
#  '2C3D2BA0BFD417D8',
#  '75AD2DA8407A956B',
#  'CC8F8C8980E52ECC',
#  '470D465D4988AF1F',
#  '09A474EAA70A4FB3',
#  'F6789B8073D95F6B',
#  'E4930F461D7CAC3C',
#  '014B8329F5F0AA59',
#  '2CAC8D16EC284E98',
#  '6C06B8FC1C195D88',
#  'AE1AA9C0202CA043',
#  '9AC4569BF560092E',
#  '46ACD576FE38FA07',
#  'F57A78FD5660F209',
#  'D811A96FFB16CDDE',
#  '472EBC885AAE278F',
#  'AA11925CB7C65426',
#  '2296FA10FFEFBD7E',
#  '3040CC2B378CC177',
#  '3E475AB4639E9169',
#  '5D44F84E5C99445F',
#  '6EC620C72B6F7CA0',
#  '5A0950C4F25F6069',
#  '7551691D1D38F55E',
#  '294124CA261B8BD7',
#  'A96FD9D1C8CE7471',
#  '7CCAD714D89C9D69',
#  '669D93FAB05DB7CA',
#  '3A29ED44F85696E5',
#  'C6146E689E8010C4',
#  '2C5F9BA3D18C5147',
#  '1ECF61757CAD5441',
#  '119EBC9074DF62DE',
#  'C029038637AD79BC',
#  '0D166BB69E5050DA',
#  'EA25DBF33E6A6E59',
#  '0D3683B9E4A59506',
#  '9AD708A5D6F2923F',
#  '33E820143F35B70A',
#  'AE78F4B27A244912',
#  'ED164E7C636EF762',
#  '9AE8149F58040CB6',
#  '9E22E7B40DAF0520',
#  '4F397260B8E1822F',
#  'A083BF79939E4783',
#  '5A07C1B93CAD179D',
#  'B6FE468806D23804',
#  'E65E29BAC48238D3',
#  '4631AA3C2F65CD19',
#  'D913669918EE1409',
#  '7B346365F0705DDE',
#  '33DFC2E6E12A9380',
#  'F35CF1E20DFA7CEA',
#  '569604D340FBB8BB',
#  'F13949EB7166EB07',
#  'AB1F9627A7598245',
#  'DA9ED984CA532E5A',
#  'B7798560B3D28B41',
#  '3A93BFCDE84A6279',
#  '906A0D6C199B9006',
#  '6100BFB17894F76A',
#  '9668988E2EB7A3F6',
#  '6857981160B5EDD4',
#  '9A61652C58B5FB34',
#  'B3FA54300C14BD3F',
#  '06259271E2B7BC5C',
#  'E1BB4758E6AC34F7',
#  '708BD03D3D9A9E3A',
#  '9D9424A42A9A3BD1',
#  '65C7BC29BECEB50E',
#  '2B827918287A2414',
#  '88B2D21223EF5B55',
#  '8DA1EB9F64E69C74',
#  '53280BD0CC04E749',
#  'EE56CB1DB5F00F1D',
#  '61567F431323109D',
#  '22B836B81B47925B',
#  '8CDEC0253C08FE7D',
#  '298D6ECE3BAD16EA',
#  '5D23B0D770C9D1C5',
#  '128A22BA0684B94F',
#  '61B8AB46091738BE',
#  '06983E079ECF6A1C',
#  '881E519D0E515274',
#  '0694307AE49E23F2',
#  'C91169CBECB23732',
#  'EA092D4F1FC97E8F',
#  '46430C96B0C026EB',
#  'BC08505A781DA4A3',
#  'EA4711B62C7AFEDC',
#  '3FFD90775D8BA215',
#  'AB0BA11385E3ECDE',
#  '1AFCA637D8C8B116',
#  '85917B6A738642D6',
#  '8C1E2E3BF4B7DF0F',
#  '76F6D7431691A7DD',
#  '56E1ECBAF2F09B57',
#  '4BF8B62E66842627',
#  'B0ACBE78CE8B5225',
#  '3CC644888FB511DB',
#  '2ED7A736D7833F3F',
#  'BFAFDECF376F4AC3',
#  '97A6390803008470',
#  'CDD2637C3535B24E',
#  '67DCCD3AD0DEBD09',
#  '5C417EE3BA2A39C4',
#  '6A624A5BF71C33DA',
#  '6C6878A5EB7C98B5',
#  '5061AF4C8FBC7D14',
#  '22B2406D589D493E',
#  'D7A9976B154F3CF7',
#  'A88615C5647CD4A4',
#  'FE1AB1E30BCD268D',
#  '7EEE2CF01A151C56',
#  '20BAA8E2798A3225',
#  '1B1CDF63BDD55DE5',
#  '8ABD9E84FC53A236',
#  'A739ED457D8582AE',
#  '85DD43C58D365E5A',
#  'CDAD19D1A1579408',
#  'A7DBEE6496FBBDBB',
#  '682FC3C41BC98A7E',
#  'A8911718104F982E',
#  '2244446D7F4CE251',
#  '567C822F9F4371EE',
#  '7A2FAA0F9434AAE5',
#  '503685ABDCF5340E',
#  '55176F1D84B72557',
#  'A6A5CAB61B35AA9D',
#  '98A80DA94B722141',
#  '14E85B3BF6AC010C',
#  '1DFCD0426E012A46',
#  'DE680C0E2925CA68',
#  'CF10395C7A269A70',
#  '4F66F31F35AEE9B3',
#  'D6DACA6AA6856D4D',
#  '794E0542BF0A0AE9',
#  '7B1F889B0E57452E',
#  '3CE439B6C406CB9B',
#  '641FE74452BBD173',
#  'F15E049407386D19',
#  'C79F1AE0B5FA1710',
#  '442A6C2844007B16',
#  '990B43239BEB2597',
#  '0D3BE74F1C986CC0',
#  'A8D60326BBFF479E',
#  'C2E35B3453AC2ADD',
#  'F87683404BCEE065',
#  '194DE5415AF194DC',
#  'C1D0F02E9485EB90',
#  'E5C12BFE00BAA566',
#  '4FE788D6B97BC502',
#  '30721293CB3E24E6',
#  '38D5379321F29AB1',
#  'E988F4B04F42A9F5',
#  '7D0499A0CB484D88',
#  'F8A533EE5CD60731',
#  '2299801B8139557D',
#  '9031B898DB3DA008',
#  '2CF80FA5A7C0DE6E',
#  '9DD60809A47625FF',
#  '3BB0B0832A0DF9FD',
#  '468471551F511546',
#  'FFFB136002DCD967',
#  '2EF544F31F02D070',
#  'EFB6DE69B26652E1',
#  '2812D07C9ECE37D2',
#  '23A3708BFE60EA20',
#  '9CA5815C927007D9',
#  '02E63DBDD7401DB4',
#  '4128E7ABEEFEB9F6',
#  '57B75C7DD2D4F35A',
#  '8CDBB0988C59B71B',
#  'A865B103C78A2B01',
#  'A1F224B8F22844BD',
#  '1659EE7BC61D70FC',
#  '4D8551E66E394C67',
#  'B65684118D857D25',
#  '860FBFA395BA4850',
#  '4FBB8D12AF747610',
#  '567237BC7AD498B9',
#  '4C45B960FB68EEA9',
#  '998931A57DD57F6C',
#  'DFB844E9CABCCB33',
#  '2856858982B1F531',
#  'F8B4E58DF6CD894E',
#  'E529582E4715E9C6',
#  '7E4631D8C05B8D94',
#  'F2B1CD23D7BCD513',
#  '85E022CE64DCC72C',
#  'D63F9FC394A456AD',
#  '70539FD1BEB9FFFE',
#  '6BCB534B27424545',
#  '414B0DCFD97897AE',
#  'C74A0AE1D4B594BD',
#  '755B558835588AB1',
#  '7B68B50290074BCF',
#  '54777A005DB2322A',
#  '78B79DC2BCBE671F',
#  '17916308C4A8F621',
#  '907EA1ABED7043D5',
#  '850D370DA2ECF27E',
#  'ACF93824D135FCA5',
#  'C40C4A6569845BD0',
#  'B56220FF558C5529',
#  '72E39200413FE59E',
#  'A9FB9D3A6D242F46',
#  'F8D0B32615593E64',
#  '3EAD81AFBB63871A',
#  'C503A5BC07FA8251',
#  'E47AA4E75BF66F16',
#  '72988C1DC5ED5891',
#  '5F553D346745F4BB',
#  'C69C670ED613D76E',
#  '4B5C75CD6CFC52E8',
#  'F4D15B409CE3D776',
#  '1A4D7E75DEB1EE52',
#  '965E714F537C4635',
#  'CDC4A1EF06C05569',
#  'CBC951E9018132FF',
#  '08C55AC49346AD29',
#  'B621CCF911E07A50',
#  '44DFC0FB446521F7',
#  '1EBBB83A04701162',
#  '29EA4F3FEF591C7C',
#  '3013D77DE562E90F',
#  '962345A23B77BA42',
#  '606C394EFB0B3B8E',
#  'AD84ECDB7ADF2DD2',
#  '2CF9DED2242526FA',
#  'D7EB3B1802EDDF76',
#  '99DC48540C2780D9',
#  '64EDF086050A828B',
#  '4F95E4050C3787EF',
#  '470807681F760A3C',
#  '91E30C3E5E0D033F',
#  '888A9194E08BC84C',
#  '5A92ED3ED88FA822',
#  '2FE8A99185C60F15',
#  'BDF2F3853AD8857D',
#  '49ABFC41FD7063FA',
#  '9E67F123F575453C',
#  '354D12A7B5C91756',
#  '0F423165C9AE2EB8',
#  '1F8EC5F92488080C',
#  '879A2F1CEE45C122',
#  '83A8873562143B3D',
#  '6EBD8113B54DE064',
#  '6340AD6A108A1D4C',
#  '1F8F444613392720',
#  'E53827F484D845D2',
#  '7DC115AB8D5C8EB8',
#  '83B31B7DD7574D63',
#  '6AA41E3C3A24E99C',
#  'B6F9200B97FB0F19',
#  'F2056A66F0471794',
#  'FCC9AC1A59B32185',
#  '5A3D5880A3F23D86',
#  '71A109680C21C98B',
#  'EACA413F79422D2F',
#  '93A5022D0436B83D',
#  'BDA887A784AAB6E7',
#  '7132E28B0C3A2FA5',
#  '5259450D80148ACF',
#  'B5ABDD2951D23B79',
#  '416428FB726E3885',
#  'FC803576182C4724',
#  'B1BF19D9C1EC0E72',
#  '290B0187B36C2498',
#  '661ABDD6A091236D',
#  '01315DAE3C23CD88',
#  '54932AAFEA3F6100',
#  '2CB8DAB3B1D4F8CF',
#  'BD3720B833F243C0',
#  'E6ADB390F998434D',
#  '412BB1FF27A5DDE0',
#  '37C89694471448E2',
#  '126553E67F3FCF60',
#  'F7C0DAB317954911',
#  '2482DF14BB77C8E9',
#  '2A065F5490C89CF3',
#  'FD8D060511C2F5D3',
#  'B8416ADF99A37346',
#  '748234E8A914EF9A',
#  '15C8A5E4D2C28468',
#  '2E900F67E1E2AC0F',
#  'E17A9FAD18CE9B1C',
#  '0927749ACA863548',
#  '50951DA56FC9051E',
#  'AA0002042C1C018B',
#  '824CE6D60DC47C12',
#  '486424918BEA825C',
#  '0775F386D03729CE',
#  '06C72FC66896D091',
#  '45C69CEB70B1A9AB',
#  '62AF07B50D2B6010',
#  '0ABC0B1753968D2F',
#  '6F6DD241776325CF',
#  '16E84D569CBCCBAD',
#  '20564BFC203557D2',
#  'F32EFB476691E0DE',
#  'B3EF24A838EED961',
#  '5C80DFD2EC16224F',
#  '95A03696F51AF8FB',
#  '17FBBCDAB15F735A',
#  '6079FB13F2D6AE69',
#  '1F7AB0709A433526',
#  '4FFA0FDCE4FE41B3',
#  '02EEFBCADAC19719',
#  'BC332D158B2022F6',
#  'D5AC12D4C5CF83E5',
#  'B4398873314DBF67',
#  '4D3A8818E21EA81E',
#  '3EF3C3675F6029B2',
#  '03B67102FFB8B425',
#  '6CE66B9F00E46724',
#  '0354FC98C88F425B',
#  'B75F4C42DC8AD19F',
#  '586CF83DD9D17EE8',
#  '30CC3D1A5FDC9200',
#  '090EB5C6C75A482E',
#  '5822B6C400599207',
#  'A6A7F0A8878057FE',
#  'F05710545ED898EE',
#  '984BA0E9BE66F1E3',
#  'F1278D4900FCDFB7',
#  'DF50B6B2B06B8990',
#  '5DB9B1EB88D2CEFC',
#  '044FED670F12320A',
#  'A70BBB652750D8BE',
#  '7CDA0AD20BCE8CD1',
#  '88D8F61E4ED22121',
#  '608799E966603BF8',
#  '04BB2AABB69AFE09',
#  'E91896CE0F96BB39',
#  'A44AB7F24A8C3B74',
#  '487FB2D42C55F900',
#  '3A16EE282A3FC534',
#  '10AB0BF0FF22653E',
#  '5ED68BB0E9E7F9CD',
#  '52BEC5167013DE80',
#  '5F91526966147DFB',
#  'F7761E05E21D2F9E',
#  '2C970B83A7496508',
#  '13EC6F633C04858D',
#  '91F21688815E1625',
#  '94BB25A32D081E8F',
#  'E5A158901CA140AB',
#  '6FA3BE7789C4A09B',
#  '3A65AA9B6BC064DD',
#  'B433BE9D21DC7951',
#  '79F414895A4ACD59',
#  '8F87FF266DF2E74C',
#  '1BC6282FE8F1081F',
#  '581E6002BC931DD7',
#  '321CEBF1E4DD1652',
#  '0FEF691AFE3D6026',
#  '5790B3140E0D0E16',
#  '44714743841ED84A',
#  '5CA2DE91BAC40C56',
#  'D4EFEE79C20FFB3A',
#  'DFC86A4F908643AD',
#  'B99BE1C4FA089689',
#  'BAF67B23C67E161D',
#  'B431A93F77C5AE93',
#  '726D86C964A75685',
#  '4FDE0EAB1E6AAD81',
#  '4676D0831361484A',
#  'BC5893BADCB613B8',
#  '8C9AD60048700B17',
#  '51CBCA87F21BAA6C',
#  'FFC3C587FBAF3C1D',
#  'F9632578B8ECADF5',
#  'D1145807362F3AC7',
#  'E65B4BA91C9B904E',
#  'C27C079A8FAA7B68',
#  '834C51750FD68F81',
#  '0D19D2902921D7A1',
#  '7863E6E09B031AD3',
#  'A25AC1414A1925FB',
#  '65C91970DF5A8409',
#  '2857C52ADF1B6AD3',
#  'FA27C9C4A8A62138',
#  '9F87F4E349236CBA',
#  '060151BEE139EFC9',
#  'FC0D8D68F87BAE98',
#  '228D0652A9E8BEF4',
#  '651325DE4AA386BA',
#  'B0F5A6D1ED0EB854',
#  'B235526AE11EA0A7',
#  '9874DAEA1000F4A1',
#  'A5410F87C1E5EF25',
#  'F7DF4EC1FE2242F2',
#  '9AFC9B42C64771B2',
#  '2F066B0C515D239F',
#  '51D255D5A062CB4C',
#  'D7D59BE49497EDF8',
#  '727D7A1D10BAA974',
#  '583915172938B320',
#  '825D6024E0AA00F1',
#  '22032687047248CF',
#  '22F345F5885D8BEC',
#  'F8744D931743A016',
#  'F6008706E0ABEFBE',
#  'A5EDE434C728BBD4',
#  '589F1626D665E8B8',
#  'BA2A9DCD95960F3B',
#  '9E38C91CEEDECF1A',
#  '5EE9597420B7DC29',
#  '5E881D72B033FDF7',
#  '2F617AD1B60C09C7',
#  'FF00E9158992FD32',
#  '317D614779228E2B',
#  '97816469CF7A8E69',
#  '6E64D948B9C9ED44',
#  '48544A4E9721DCD5',
#  'F54444D905F1F90A',
#  'A2D91A23FB7062EE',
#  'DC9F291893EB44B3',
#  '9C18B4D62B34997D',
#  '353ABCAE653C9EA9',
#  'C3E9D149B0E5F261',
#  '105E942FFFDEE0FC',
#  '28F4AF52E28A56E7',
#  'C5AB96FF426FE1C6',
#  'BA3AC1BF24A83A61',
#  'CCF451955A8B7AD5',
#  '2378F0BD8C782CE1',
#  '6786972C297AC9CD',
#  '7C548026340E1E17',
#  '85209EE72B158E06',
#  '4224C9C3B97210C1',
#  'E0C86A25F538AB51',
#  'F81DA88248FE6FB9',
#  '400CA835AD022EF0',
#  '837B59BCC272D9F7',
#  '7FD2657E3FF28A51',
#  '2B117933A53D08A2',
#  'A792D8A10AC0DC03',
#  '28FA5194712B3E43',
#  'D9B461417F22D15A',
#  '8AC6C71EA83BEA61',
#  '632983ACBFD4BD30',
#  '00C21A4C0FFB4A6A',
#  'F04E1116153BE67C',
#  '2B750BA541EC50C5',
#  '8BF2655C14DB4EE7',
#  'C3E9720089B2E0DA',
#  '99FB50859B283531',
#  '170AF73C462F734C',
#  'E2A87DC270589F7C',
#  '0A1BD5DC867A6A0F',
#  'D5F65A36A67C5DFA',
#  'A978C841149B1C14',
#  '0723F498EC0B24BB',
#  'E40832AFAB04F884',
#  'FD4989CF5C7E6E40',
#  'DBD95670E8356720',
#  '11915B532573AE2F',
#  'ECD828911E53612D',
#  '7AB7FF0AFBD23E27',
#  'E09877E6DFD76C1D',
#  'F0A6F07E54889160',
#  'E5F66535FD56AEF7',
#  'C1B2582DD5CCE31A',
#  '94DDF2C786851BE8',
#  '61392629848F9AB5',
#  '40B02E080E74192E',
#  '70EB2EDB9973E64F',
#  '983962FB9D084B09',
#  'D38274B53B5256B6',
#  'B08FE528C7E2502F',
#  'D9422E2974A06DA0',
#  '29DCCA6459DB9B0F',
#  '27119717BCA8ED3F',
#  'F34A8A1B847D6233',
#  '748C9ED97A9E511F',
#  'D3FFDEA8C9238EFC',
#  '83337152DAA542F9',
#  'D50535D19BEB894A',
#  'FAA77B0AF387D460',
#  '4F49EB6FA7B4B624',
#  '5D736AFF8177A6F3',
#  '2AE9A830685530BB',
#  '4617ADCB81C8A44F',
#  '60ACAE52B50FF7A4',
#  '7D95A85A3D2456CF',
#  'FF8971A50AD9DC23',
#  'EC102D55E7BB7F3A',
#  '5381DFA24F81C3D9',
#  '2C362C0A7D0C9D0B',
#  '47485C372AEE7339',
#  '4209F4A45E51D75E',
#  '6BA211D1BB89197B',
#  'E56F7BA45F40796A',
#  '4817984911FC4F95',
#  'A8640E06C47CD7F8',
#  '6A27E91488F1D824',
#  '49575AAD1CCB8470',
#  'AED82D27D148B38E',
#  'B3FE430BBCBBEDE7',
#  'C11D2130E8FF5751',
#  '25CBC467FE7CF486',
#  '036F9427C1DB411D',
#  '2FEF1C517B3122EF',
#  'A4AD131FB4FAAC0A',
#  'DAC3DD675AE46E90',
#  '27CB2E456DA24111',
#  '3D3C0DA0A6AB4012',
#  '786F1C92EA298D0C',
#  '12F3E371DDB7526D',
#  '24D29A95414C0BD6',
#  '426F643F65EA5209',
#  'DA4803BFAA75D5BF',
#  '8196F3B89C357708',
#  '308D2419A199923D',
#  '62A4DC4BB12C5D93',
#  'D36E2B029A68529D',
#  'FC2540BC10AADD96',
#  '927D16E2E1D8EBCB',
#  '0798A1E2539C5450',
#  'B9739EBFE1313838',
#  '9232713AF32F7DB6',
#  'DBC12A8B5531AE1D',
#  '4A5CC9D4D5CF6793',
#  'E0FF42C45C228CBC',
#  '73B8D70D08508EED',
#  '0D2CE5DBF460CE34',
#  '3411E2A8BD92033F',
#  '00675D57C7AAF967',
#  'CCB443DE866CE2E4',
#  '3D8FCBF0C92381D0',
#  'A88B4E9E5C08AF18',
#  'B6E524DF38B2085B',
#  '610993B533E31CFE',
#  '0CC8E9D746DA0881',
#  'B417B5090C8B4E7E',
#  '0B0AB51B76ECB029',
#  '5A2E234D2BFF7F38',
#  '64D8598D9F931642',
#  '15A467B0FEDA06E1',
#  'C264ECAC42551343',
#  'CB36DD7E59CDA9EA',
#  'BC2E0BD6773E16DE',
#  'B2E8BB5C6E64F222',
#  'CD35BCF492C168C4',
#  '0146B6B8F1AD1A1F',
#  'D749288A699DAA2D',
#  '8A3627AA170B152F',
#  'A3F349618491D6E5',
#  'CEED29C63B8EAD95',
#  'D72A6C67CF031D41',
#  '35B42AE55B155DB8',
#  '0F6F6DBEA5A6E246',
#  'A73D6B1A7442262C',
#  '605A4702B05F34BF',
#  'CD6095AF21DAECA7',
#  'F66DC20FB5CEF56E',
#  '5211F7AF93D59263',
#  '8EF585E91F28A771',
#  '34C0A0A4A73DB5FC',
#  '32F578D5954C3755',
#  'E03488AF811FBC9F',
#  'E865F2097759A1CA',
#  'E1A4C8AFFC0C870F',
#  'FDD074002297D482',
#  '57EEC20075B13EFF',
#  'F70CC3BD3745168E',
#  '266A6D5991F77393',
#  '1A951C1A6B9C70D8',
#  '7F27FBAC886CF923',
#  '31A409A4C78979D1',
#  '0F7A1BBFADAEF239',
#  '69B507C37E62F922',
#  'C6CA92E56B1AEF37',
#  '213A5E94E0509F99',
#  '9839C16F9C174129',
#  '4087445067288E06',
#  '7ECA727E45853070',
#  'E8AE604D8A0BD67A',
#  '8D1F2D2A6CC49E44',
#  'A9FDDCCD1DD6E416',
#  '24770EE8251B7218',
#  '9414CEE7A39544AF',
#  '12CE799438815B8E',
#  'B325852478FABB4B',
#  '3365FC33813971D9',
#  '6887BDB2FAEDD13A',
#  '1456D35FC14368D5',
#  '91EC66889422A62F',
#  'FBDB88AC657C6E74',
#  'D66F72522775F9AF',
#  'BF0EFEFBCE032EC9',
#  'D13367F0C85EA48D',
#  'A0EC378F59361F6E',
#  '795478B274E68520',
#  'A5442529B1215891',
#  'E31595F0987221E5',
#  'C0C1CA771C3A380D',
#  '660E2D8B29396639',
#  'EB2B0B767056D7C9',
#  'FDB4D0670AF6242B',
#  '786EA73E6D98066B',
#  'B518BCAC099A54A9',
#  'D8E194CC9AE46775',
#  '7875019E6A42B344',
#  '6CFB88C7B7780A46',
#  '684DFB7D0A8A1C9F',
#  'E12E6B2BADAEAA91',
#  'BABBE5BA06DB5F11',
#  '11DA9E857669540F',
#  'B37DF38F9D126E7B',
#  '5FBAD5A5E097844F',
#  'C534A0A2EA7C0835',
#  'D60E5BA03450B38F',
#  'D1AA9964D298DA2C',
#  '97CC4C0E3CAD14F9',
#  'C4D974AA49B9DED5',
#  'AF55609C589CD143',
#  'EB66A3B06A9086CB',
#  'BFDC37DD302ABCD1',
#  'DD750CC770FF846A',
#  '97C934C5FAC1D92D',
#  '283A19F7A89FA228',
#  '2E78C5228E135035',
#  '970982FF65C191F6',
#  '2641CDC50CC374FD',
#  '6A0B81689198A672',
#  'DF477468435DC968',
#  '4F5977C9D5898567',
#  '9579E276F6A4DC99',
#  '942AEB9A9ABDC763',
#  'C58C9994281F390F',
#  'CFE2AD341A063B59',
#  '5546BFA414DFAAD3',
#  '99157EC711137FF7',
#  '16C1B2FFFA8E619A',
#  '7492E3875AD1E128',
#  'DD60A6091B8B0880',
#  'C92B32D39DC7B817',
#  '7701CCCF45E5223D',
#  '5C5EB8F8A2A95E20',
#  '7A239E1E939E61DC',
#  '27F9BB115A6012FC',
#  '716C9F6B0E393343',
#  '34ACB545FE464095',
#  'D57DA9CC0EB9F435',
#  '2F30FBD31C67E061',
#  'E6F83F5298EAAAF0',
#  'A021E884D7D24440',
#  'E64AB05CBEA492ED',
#  '2BCFEAAD509591CA',
#  '4BD7B32AD7313295',
#  '9D72C072779F6406',
#  'B7A64C060CE5F4CC',
#  'F7D618DA084CC99A',
#  '1951ADB33FAF367F',
#  '65D045C83EE43AB4',
#  '9C3862544CBE857C',
#  '1DADE0DE693E9C24',
#  '0CCB94B80D537BB3',
#  '3EBE7530E2DA5C37',
#  'E7E8D2982AF984B8',
#  'BFE502B3884CC93F',
#  'AE78CCE86DAF1821',
#  '4039F88474D7FD2D',
#  '3E2CB33DBC6072B6',
#  '07727B2241EE3741',
#  '77695BCE95A0A6E4',
#  'F967D20C165E68CF',
#  '38456B968BDB846C',
#  '965569CDF7E6171F',
#  '38635DEDE5F4B24F',
#  'C578E2BBBAA8A041',
#  '13BF8607C35FC226',
#  'AF329836F37936B8',
#  '91CE518B651CB4AD',
#  '55F86F79C60A2D64',
#  'E45A945389C2EAC7',
#  'A368B5EDFF8BB378',
#  '6A34FB71357A3629',
#  '83BEC6FB90E12DB3',
#  '75E47E82B54ED197',
#  '80718A5B2C5CA33A',
#  'B5ED39C8D55837FB',
#  '9381FD64BB80D4DB',
#  '95E7065752D6DB1D',
#  'C537843B74A180C7',
#  '4FAF4587CDD0611B',
#  '74369AA4A323E929',
#  'D005733B8E2D7C7E',
#  '14590F4EA475D78A',
#  '74AA7CB616E36B3E',
#  '892F2DA5C46DB5C1',
#  '9C2888B12663AC18',
#  'DA6B34FF7CDAB9B8',
#  '92E9A52C20B69DBE',
#  '4C5EFBD23249BE1A',
#  'A3374D0C54F86927',
#  'F5BA7613708CE8E8',
#  '2CFAFE04AE43C255',
#  '361FF1562326C0BA',
#  '66B39EB577A29D15',
#  '09916561B1EF5132',
#  '21A0540027D0E464',
#  '9F347C9FAF6DFC5B',
#  '756B6A4C3A556955',
#  '3A62164A247E068F',
#  'B2435ABE6C581622',
#  'B84C4FB0F5732D9E',
#  '3F1B5BA6516E74BB',
#  '6BDBE5204CB26D2A',
#  '36793677794E1D97',
#  '80594736BBED1F3D',
#  '4ABECF5E2F80356E',
#  'DD7C8B34C62CA6EF',
#  '1A111E4A43AEDD13',
#  'BD28B67B7710F77E',
#  'E3C379EFCD97E60F',
#  'B3C0020FF491072B',
#  '71E5EA1612893647',
#  ...]

# %%
def Id(id):
    New_Id=""
    try:
        for i in id:
            try:
                New_Id+=str(int(i))
            except:
                continue
        return int(New_Id)
    except:
        return np.nan

# %%
Id('TA1307000127')
# Out:
# 1307000127

# %%
df['ride_id']=df['ride_id'].apply(Id)

# %%
#print(df['start_station_id'].unique().tolist())

# %%
#df['start_station_id_Copy']=df['start_station_id'].apply(Id)

# %%
#df['start_station_id_Copy'].tolist()

# %%
def f(i):
    try:
        return str(i)
    except:
        return "AA"

# %%
#df['start_station_id_Copy'].apply(np.int64)

# %%
#df['start_station_id_Copy'].astype(int)

# %%
#df['start_station_id'].tolist()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5860776 entries, 0 to 5860775
# Data columns (total 13 columns):
#  #   Column              Dtype
# ---  ------              -----
#  0   ride_id             int64
#  1   rideable_type       object
#  2   started_at          object
#  3   ended_at            object
#  4   start_station_name  object
#  5   start_station_id    object
#  6   end_station_name    object
#  7   end_station_id      object
#  8   start_lat           float64
#  9   start_lng           float64
#  10  end_lat             float64
#  11  end_lng             float64
#  12  member_casual       object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 581.3+ MB

# %%
#3print(df['start_station_id'].unique().tolist())

# %%
df['rideable_type'].unique()
# Out:
# array(['electric_bike', 'classic_bike', 'docked_bike'], dtype=object)

# %%
df['rideable_type'].value_counts()
# Out:
# classic_bike     3217737
# electric_bike    2368592
# docked_bike       274447
# Name: rideable_type, dtype: int64

# %%
sns.countplot(data=df,x='rideable_type')
# Out:
# <AxesSubplot:xlabel='rideable_type', ylabel='count'>

# %%
print(df['start_station_name'].unique().tolist())
# Out:
# [nan, 'Orleans St & Elm St', 'Desplaines St & Kinzie St', 'Clark St & Grace St', 'Kingsbury St & Kinzie St', 'Sheridan Rd & Noyes St (NU)', 'Larrabee St & Armitage Ave', 'State St & 19th St', 'Michigan Ave & Oak St', 'Dearborn St & Monroe St', 'Aberdeen St & Jackson Blvd', 'Wells St & Walton St', 'Clark St & Leland Ave', 'Cornell Dr & Hayes Dr', 'Halsted St & North Branch St', 'Central Park Ave & North Ave', 'Clark St & Chicago Ave', 'Drake Ave & Montrose Ave', 'Damen Ave & Pershing Rd', 'Clark St & Newport St', 'Seeley Ave & Garfield Blvd', 'Burling St & Diversey Pkwy', 'Troy St & Elston Ave', 'N Sheffield Ave & W Wellington Ave', 'Sheffield Ave & Fullerton Ave', 'Fairbanks Ct & Grand Ave', 'Sheffield Ave & Wrightwood Ave', 'Ritchie Ct & Banks St', 'Ashland Ave & Grace St', 'Clinton St & Polk St', 'Dorchester Ave & 49th St', 'State St & 35th St', 'LaSalle St & Washington St', 'Ashland Ave & 63rd St', 'Wabash Ave & 16th St', 'Glenwood Ave & Touhy Ave', 'Halsted St & 18th St', 'Clark St & Armitage Ave', 'Wells St & Polk St', 'Halsted St & Polk St', 'Indiana Ave & 26th St', 'Central Park Ave & Elbridge Ave', 'Cannon Dr & Fullerton Ave', 'Cityfront Plaza Dr & Pioneer Ct', 'Sheridan Rd & Irving Park Rd', 'LaSalle St & Jackson Blvd', 'Ellis Ave & 55th St', 'Harper Ave & 59th St', 'Damen Ave & Leland Ave', 'Austin Blvd & Madison St', 'California Ave & Lake St', 'Elizabeth (May) St & Fulton St', 'California Ave & Cortez St', 'Clark St & Lunt Ave', 'Wabash Ave & Roosevelt Rd', 'LaSalle Dr & Huron St', 'Smith Park', 'Lake Shore Dr & North Blvd', 'Campbell Ave & North Ave', 'Kedzie Ave & Palmer Ct', 'Milwaukee Ave & Rockwell St', 'Spaulding Ave & Armitage Ave', 'Damen Ave & Wabansia Ave', 'California Ave & Milwaukee Ave', 'Wood St & Milwaukee Ave', 'Kimball Ave & Belmont Ave', 'Western Ave & Monroe St', 'Elston Ave & Cortland St', 'Elston Ave & Wabansia Ave', 'Clinton St & Madison St', 'St. Louis Ave & Fullerton Ave', 'Morgan St & Polk St', 'Milwaukee Ave & Wabansia Ave', 'Sheridan Rd & Montrose Ave', 'Damen Ave & Grand Ave', 'Ashland Ave & Division St', 'Damen Ave & Cullerton St', 'Sheridan Rd & Lawrence Ave', 'Damen Ave & Wellington Ave', 'Racine Ave & Wrightwood Ave', 'Southport Ave & Roscoe St', 'Broadway & Thorndale Ave', 'Orleans St & Chestnut St (NEXT Apts)', 'Halsted St & Wrightwood Ave', 'Paulina Ave & North Ave', 'Broadway & Sheridan Rd', 'Broadway & Barry Ave', 'Broadway & Wilson - Truman College Vaccination Site', 'Halsted St & Roscoe St', 'Lincoln Ave & Belmont Ave', 'Bernard St & Elston Ave', 'Sedgwick St & Webster Ave', 'Calumet Ave & 18th St', 'Cornell Ave & Hyde Park Blvd', 'Broadway & Waveland Ave', 'Kedzie Ave & Milwaukee Ave', 'Lincoln Ave & Diversey Pkwy', 'Halsted St & 35th St', 'Lincoln Ave & Addison St', 'Clarendon Ave & Gordon Ter', 'Wallace St & 35th St', 'California Ave & Altgeld St', 'Clark St & Wellington Ave', 'Clark St & Wrightwood Ave', 'Benson Ave & Church St', 'Wood St & Taylor St (Temp)', 'Lincoln Park Conservatory', 'Indiana Ave & Roosevelt Rd', 'McClurg Ct & Erie St', 'Clinton St & Washington Blvd', 'Shedd Aquarium', 'Cottage Grove Ave & 47th St', 'Wentworth Ave & 24th St (Temp)', 'Clark St & Schreiber Ave', 'State St & 33rd St', 'Dearborn St & Van Buren St', 'Ashland Ave & Archer Ave', 'Morgan St & 31st St', 'Racine Ave & 15th St', 'Honore St & Division St', 'Ashland Ave & Blackhawk St', 'Lincoln Ave & Belle Plaine Ave', 'Federal St & Polk St', 'Shields Ave & 28th Pl', 'Lake Shore Dr & Belmont Ave', 'Loomis St & Lexington St', 'State St & 29th St', 'Sheffield Ave & Wellington Ave', 'Wells St & Concord Ln', 'Lincoln Ave & Waveland Ave', 'Paulina St & Montrose Ave', 'Michigan Ave & Pearson St', 'Damen Ave & Sunnyside Ave', 'Monticello Ave & Irving Park Rd', 'Western Ave & Leland Ave', 'Lincoln Ave & Winona St', 'Damen Ave & Foster Ave', 'Ravenswood Ave & Lawrence Ave', 'Stave St & Armitage Ave', 'Damen Ave & Pierce Ave', 'Montrose Harbor', 'Halsted St & Dickens Ave', 'Clybourn Ave & Division St', 'Cam ...

# %%
print(df['end_station_name'].unique().tolist())
# Out:
# [nan, 'Michigan Ave & Oak St', 'Orleans St & Elm St', 'Kingsbury St & Kinzie St', 'Clark St & Leland Ave', 'Desplaines St & Kinzie St', 'Sheridan Rd & Noyes St (NU)', 'State St & 19th St', 'Clark St & Grace St', 'Dearborn St & Monroe St', 'Larrabee St & Armitage Ave', 'Wells St & Walton St', 'Aberdeen St & Jackson Blvd', 'Cornell Dr & Hayes Dr', 'Peoria St & Jackson Blvd', 'Damen Ave & Chicago Ave', 'Dearborn St & Van Buren St', 'Albany Ave & Montrose Ave', 'Damen Ave & Pershing Rd', 'Clark St & Newport St', 'Western Blvd & 48th Pl', 'Damen Ave & Leland Ave', 'Franklin St & Illinois St', 'Larrabee St & Webster Ave', 'Sedgwick St & North Ave', 'Southport Ave & Waveland Ave', 'Seeley Ave & Roscoe St', 'LaSalle St & Jackson Blvd', 'Clinton St & Jackson Blvd', 'Sedgwick St & Webster Ave', 'Clinton St & Polk St', 'Dorchester Ave & 49th St', 'Theater on the Lake', 'Calumet Ave & 35th St', 'Rush St & Superior St', 'Ashland Ave & 74th St', 'Michigan Ave & 14th St', 'Wells St & Huron St', 'Glenwood Ave & Touhy Ave', 'Central Park Ave & Bloomingdale Ave', 'Stave St & Armitage Ave', 'LaSalle Dr & Huron St', 'Financial Pl & Ida B Wells Dr', 'Southport Ave & Wellington Ave', 'Lake Shore Dr & North Blvd', 'Western Ave & Monroe St', 'Burling St & Diversey Pkwy', 'Oakley Ave & Touhy Ave', 'MLK Jr Dr & 56th St', 'Clark St & Winnemac Ave', 'Emerald Ave & 28th St', 'Halsted St & Wrightwood Ave', 'Stockton Dr & Wrightwood Ave', 'Rush St & Hubbard St', 'Wabash Ave & Cermak Rd', 'Woodlawn Ave & 55th St', 'Clarendon Ave & Gordon Ter', 'State St & Pearson St', 'Christiana Ave & Lawrence Ave', 'Clark St & Berwyn Ave', 'Clark St & Lake St', 'Clark St & Armitage Ave', 'Franklin St & Monroe St', 'Ellis Ave & 60th St', 'Shore Dr & 55th St', 'Broadway & Wilson - Truman College Vaccination Site', 'Clarendon Ave & Leland Ave', 'Ashland Ave & Wrightwood Ave', 'Central Ave & Madison St', 'Clinton St & Washington Blvd', 'Damen Ave & Pierce Ave', 'Michigan Ave & Lake St', 'Leavitt St & Division St', 'Broadway & Granville Ave', 'Michigan Ave & 18th St', 'Green St & Madison St', 'Damen Ave & Wabansia Ave', 'Spaulding Ave & Armitage Ave', 'Clinton St & Madison St', 'Fairbanks Ct & Grand Ave', 'Albany Ave & Bloomingdale Ave', 'Laflin St & Cullerton St', 'Dodge Ave & Church St', 'Ellis Ave & 58th St', 'Calumet Ave & 18th St', 'MLK Jr Dr & 47th St', 'Michigan Ave & Pearson St', 'Shields Ave & 28th Pl', 'Emerald Ave & 31st St', 'Winchester (Ravenswood) Ave & Balmoral Ave', 'Wentworth Ave & 33rd St', 'Damen Ave & Charleston St', 'Clinton St & Roosevelt Rd', 'Lake Shore Dr & Monroe St', 'Larrabee St & Kingsbury St', 'State St & Kinzie St', 'MLK Jr Dr & Pershing Rd', 'California Ave & Cortez St', 'Central Ave & Lake St', '2112 W Peterson Ave', 'California Ave & Milwaukee Ave', 'State St & 35th St', 'Hegewisch Metra Station', 'Ashland Ave & Grace St', 'McClurg Ct & Erie St', 'Michigan Ave & Washington St', 'Wood St & Taylor St (Temp)', 'Pine Grove Ave & Irving Park Rd', 'Bissell St & Armitage Ave', 'Sedgwick St & Schiller St', 'Eckhart Park', 'Marine Dr & Ainslie St', 'Kosciuszko Park', 'Sheffield Ave & Webster Ave', 'Broadway & Berwyn Ave', 'Desplaines St & Randolph St', 'Pine Grove Ave & Waveland Ave', 'Halsted St & Roscoe St', 'Western Ave & 24th St', 'Indiana Ave & Roosevelt Rd', 'Clarendon Ave & Junior Ter', 'Drake Ave & Addison St', 'Orleans St & Hubbard St', 'Halsted St & Maxwell St', 'Southport Ave & Roscoe St', 'Clark St & Schiller St', 'Broadway & Cornelia Ave', 'Southport Ave & Clark St', 'Wells St & Hubbard St', 'Hoyne Ave & Balmoral Ave', 'Kingsbury St & Erie St', 'Clark St & Elm St', 'Michigan Ave & 8th St', 'Cornell Ave & Hyde Park Blvd', 'Campbell Ave & Montrose Ave', 'Broadway & Thorndale Ave', 'Clark St & 9th St (AMLI)', 'Sangamon St & Washington Blvd', 'Winthrop Ave & Lawrence Ave', 'Avondale Ave & Irving Park Rd', 'Wabash Ave & Grand Ave', 'Wilton Ave & Belmont Ave', 'St. Louis Ave & Balmoral Ave', 'Leavitt St & Chicago Ave', 'Washtenaw Ave & Lawrence A ...

# %%
df['member_casual'].value_counts()
# Out:
# member    3300919
# casual    2559857
# Name: member_casual, dtype: int64

# %%
sns.set(rc={'figure.figsize': [7, 5]}, font_scale=1.3)
sns.countplot(data=df,x='member_casual')
# Out:
# <AxesSubplot:xlabel='member_casual', ylabel='count'>

# %%
df['started']=pd.to_datetime(df['started_at'],format='%Y/%m/%d %H:%M',errors='coerce')

# %%
df['started_at']=df['started']
df.drop('started',axis=1,inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5860776 entries, 0 to 5860775
# Data columns (total 13 columns):
#  #   Column              Dtype
# ---  ------              -----
#  0   ride_id             int64
#  1   rideable_type       object
#  2   started_at          datetime64[ns]
#  3   ended_at            object
#  4   start_station_name  object
#  5   start_station_id    object
#  6   end_station_name    object
#  7   end_station_id      object
#  8   start_lat           float64
#  9   start_lng           float64
#  10  end_lat             float64
#  11  end_lng             float64
#  12  member_casual       object
# dtypes: datetime64[ns](1), float64(4), int64(1), object(7)
# memory usage: 581.3+ MB

# %%
df['ended']=pd.to_datetime(df['started_at'],format='%Y/%m/%d %H:%M',errors='coerce')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5860776 entries, 0 to 5860775
# Data columns (total 14 columns):
#  #   Column              Dtype
# ---  ------              -----
#  0   ride_id             int64
#  1   rideable_type       object
#  2   started_at          datetime64[ns]
#  3   ended_at            object
#  4   start_station_name  object
#  5   start_station_id    object
#  6   end_station_name    object
#  7   end_station_id      object
#  8   start_lat           float64
#  9   start_lng           float64
#  10  end_lat             float64
#  11  end_lng             float64
#  12  member_casual       object
#  13  ended               datetime64[ns]
# dtypes: datetime64[ns](2), float64(4), int64(1), object(7)
# memory usage: 626.0+ MB

# %%
df['ended_at']=df['ended']
df.drop('ended',axis=1,inplace=True)

# %%
print(df['start_station_name'].unique())
# Out:
# [nan 'Orleans St & Elm St' 'Desplaines St & Kinzie St' ...
#  'Tuley (Murray) Park' 'Harvey Ave & North Ave'
#  'Springfield Ave & 63rd St']

# %%
df['start_station_name'].isna().sum()/df.shape[0]*100
# Out:
# 14.045358498601551

# %%
print(df['start_station_name'].unique().tolist())
# Out:
# [nan, 'Orleans St & Elm St', 'Desplaines St & Kinzie St', 'Clark St & Grace St', 'Kingsbury St & Kinzie St', 'Sheridan Rd & Noyes St (NU)', 'Larrabee St & Armitage Ave', 'State St & 19th St', 'Michigan Ave & Oak St', 'Dearborn St & Monroe St', 'Aberdeen St & Jackson Blvd', 'Wells St & Walton St', 'Clark St & Leland Ave', 'Cornell Dr & Hayes Dr', 'Halsted St & North Branch St', 'Central Park Ave & North Ave', 'Clark St & Chicago Ave', 'Drake Ave & Montrose Ave', 'Damen Ave & Pershing Rd', 'Clark St & Newport St', 'Seeley Ave & Garfield Blvd', 'Burling St & Diversey Pkwy', 'Troy St & Elston Ave', 'N Sheffield Ave & W Wellington Ave', 'Sheffield Ave & Fullerton Ave', 'Fairbanks Ct & Grand Ave', 'Sheffield Ave & Wrightwood Ave', 'Ritchie Ct & Banks St', 'Ashland Ave & Grace St', 'Clinton St & Polk St', 'Dorchester Ave & 49th St', 'State St & 35th St', 'LaSalle St & Washington St', 'Ashland Ave & 63rd St', 'Wabash Ave & 16th St', 'Glenwood Ave & Touhy Ave', 'Halsted St & 18th St', 'Clark St & Armitage Ave', 'Wells St & Polk St', 'Halsted St & Polk St', 'Indiana Ave & 26th St', 'Central Park Ave & Elbridge Ave', 'Cannon Dr & Fullerton Ave', 'Cityfront Plaza Dr & Pioneer Ct', 'Sheridan Rd & Irving Park Rd', 'LaSalle St & Jackson Blvd', 'Ellis Ave & 55th St', 'Harper Ave & 59th St', 'Damen Ave & Leland Ave', 'Austin Blvd & Madison St', 'California Ave & Lake St', 'Elizabeth (May) St & Fulton St', 'California Ave & Cortez St', 'Clark St & Lunt Ave', 'Wabash Ave & Roosevelt Rd', 'LaSalle Dr & Huron St', 'Smith Park', 'Lake Shore Dr & North Blvd', 'Campbell Ave & North Ave', 'Kedzie Ave & Palmer Ct', 'Milwaukee Ave & Rockwell St', 'Spaulding Ave & Armitage Ave', 'Damen Ave & Wabansia Ave', 'California Ave & Milwaukee Ave', 'Wood St & Milwaukee Ave', 'Kimball Ave & Belmont Ave', 'Western Ave & Monroe St', 'Elston Ave & Cortland St', 'Elston Ave & Wabansia Ave', 'Clinton St & Madison St', 'St. Louis Ave & Fullerton Ave', 'Morgan St & Polk St', 'Milwaukee Ave & Wabansia Ave', 'Sheridan Rd & Montrose Ave', 'Damen Ave & Grand Ave', 'Ashland Ave & Division St', 'Damen Ave & Cullerton St', 'Sheridan Rd & Lawrence Ave', 'Damen Ave & Wellington Ave', 'Racine Ave & Wrightwood Ave', 'Southport Ave & Roscoe St', 'Broadway & Thorndale Ave', 'Orleans St & Chestnut St (NEXT Apts)', 'Halsted St & Wrightwood Ave', 'Paulina Ave & North Ave', 'Broadway & Sheridan Rd', 'Broadway & Barry Ave', 'Broadway & Wilson - Truman College Vaccination Site', 'Halsted St & Roscoe St', 'Lincoln Ave & Belmont Ave', 'Bernard St & Elston Ave', 'Sedgwick St & Webster Ave', 'Calumet Ave & 18th St', 'Cornell Ave & Hyde Park Blvd', 'Broadway & Waveland Ave', 'Kedzie Ave & Milwaukee Ave', 'Lincoln Ave & Diversey Pkwy', 'Halsted St & 35th St', 'Lincoln Ave & Addison St', 'Clarendon Ave & Gordon Ter', 'Wallace St & 35th St', 'California Ave & Altgeld St', 'Clark St & Wellington Ave', 'Clark St & Wrightwood Ave', 'Benson Ave & Church St', 'Wood St & Taylor St (Temp)', 'Lincoln Park Conservatory', 'Indiana Ave & Roosevelt Rd', 'McClurg Ct & Erie St', 'Clinton St & Washington Blvd', 'Shedd Aquarium', 'Cottage Grove Ave & 47th St', 'Wentworth Ave & 24th St (Temp)', 'Clark St & Schreiber Ave', 'State St & 33rd St', 'Dearborn St & Van Buren St', 'Ashland Ave & Archer Ave', 'Morgan St & 31st St', 'Racine Ave & 15th St', 'Honore St & Division St', 'Ashland Ave & Blackhawk St', 'Lincoln Ave & Belle Plaine Ave', 'Federal St & Polk St', 'Shields Ave & 28th Pl', 'Lake Shore Dr & Belmont Ave', 'Loomis St & Lexington St', 'State St & 29th St', 'Sheffield Ave & Wellington Ave', 'Wells St & Concord Ln', 'Lincoln Ave & Waveland Ave', 'Paulina St & Montrose Ave', 'Michigan Ave & Pearson St', 'Damen Ave & Sunnyside Ave', 'Monticello Ave & Irving Park Rd', 'Western Ave & Leland Ave', 'Lincoln Ave & Winona St', 'Damen Ave & Foster Ave', 'Ravenswood Ave & Lawrence Ave', 'Stave St & Armitage Ave', 'Damen Ave & Pierce Ave', 'Montrose Harbor', 'Halsted St & Dickens Ave', 'Clybourn Ave & Division St', 'Cam ...

# %%
df.isnull().sum()
# Out:
# ride_id                    0
# rideable_type              0
# started_at                 0
# ended_at                   0
# start_station_name    823167
# start_station_id      823164
# end_station_name      878338
# end_station_id        878338
# start_lat                  0
# start_lng                  0
# end_lat                 5036
# end_lng                 5036
# member_casual              0
# dtype: int64

# %%
df.isnull().mean()*100
# Out:
# ride_id                0.000000
# rideable_type          0.000000
# started_at             0.000000
# ended_at               0.000000
# start_station_name    14.045358
# start_station_id      14.045307
# end_station_name      14.986718
# end_station_id        14.986718
# start_lat              0.000000
# start_lng              0.000000
# end_lat                0.085927
# end_lng                0.085927
# member_casual          0.000000
# dtype: float64

# %%
df[(df['start_station_name'].isna()) & (df['start_station_id'].isna())]
# Out:
#                ride_id  rideable_type          started_at            ended_at  \
# 0            999384320  electric_bike 2021-06-13 14:31:28 2021-06-13 14:31:28
# 1             60488520  electric_bike 2021-06-04 11:18:02 2021-06-04 11:18:02
# 2        9598066680452  electric_bike 2021-06-04 09:49:35 2021-06-04 09:49:35
# 3           3048412214  electric_bike 2021-06-03 19:56:05 2021-06-03 19:56:05
# 4              9898737  electric_bike 2021-06-04 14:05:51 2021-06-04 14:05:51
# ...                ...            ...                 ...                 ...
# 5860760       78334399  electric_bike 2022-05-05 10:58:07 2022-05-05 10:58:07
# 5860761     3875893421  electric_bike 2022-05-12 07:22:19 2022-05-12 07:22:19
# 5860762    25515941484  electric_bike 2022-05-12 14:15:54 2022-05-12 14:15:54
# 5860763      209564570  electric_bike 2022-05-16 10:07:36 2022-05-16 10:07:36
# 5860764   692132111873  electric_bike 2022-05-12 15:19:21 2022-05-12 15:19:21
#
#         start_station_name start_station_id end_station_name end_station_id  \
# 0                      NaN              NaN              NaN            NaN
# 1                      NaN              NaN              NaN            NaN
# 2                      NaN              NaN              NaN            NaN
# 3                      NaN              NaN              NaN            NaN
# 4                      NaN              NaN              NaN            NaN
# ...                    ...              ...              ...            ...
# 5860760                NaN              NaN              NaN            NaN
# 5860761                NaN              NaN              NaN            NaN
# 5860762                NaN              NaN              NaN            NaN
# 5860763                NaN              NaN              NaN            NaN
# 5860764                NaN              NaN              NaN            NaN
#
#          start_lat  start_lng  end_lat  end_lng member_casual
# 0            41.80     -87.59    41.80   -87.60        member
# 1            41.79     -87.59    41.80   -87.60        member
# 2            41.80     -87.60    41.79   -87.59        member
# 3            41.78     -87.58    41.80   -87.60        member
# 4            41.80     -87.59    41.79   -87.59        member
# ...            ...        ...      ...      ...           ...
# 5860760      41.79     -87.60    41.79   -87.60        member
# 5860761      41.79     -87.60    41.79   -87.60        member
# 5860762      41.79     -87.60    41.80   -87.60        member
# 5860763      41.90     -87.68    41.90   -87.64        member
# 5860764      41.79     -87.60    41.79   -87.60        member
#
# [823164 rows x 13 columns]

# %% [markdown]
# ## Try To deop all nans

# %%
df.dropna()
# Out:
#                ride_id  rideable_type          started_at            ended_at  \
# 50           904584538   classic_bike 2021-06-04 07:29:18 2021-06-04 07:29:18
# 51         41853006552   classic_bike 2021-06-23 08:39:36 2021-06-23 08:39:36
# 53         60970908555   classic_bike 2021-06-27 12:26:58 2021-06-27 12:26:58
# 56           710160304   classic_bike 2021-06-01 12:30:24 2021-06-01 12:30:24
# 57           375200145   classic_bike 2021-06-01 11:32:17 2021-06-01 11:32:17
# ...                ...            ...                 ...                 ...
# 5859919     3166337875   classic_bike 2022-05-08 13:28:53 2022-05-08 13:28:53
# 5860100      717706137   classic_bike 2022-05-14 10:10:24 2022-05-14 10:10:24
# 5860296     7395666624   classic_bike 2022-05-06 18:52:52 2022-05-06 18:52:52
# 5860363  1684511515736   classic_bike 2022-05-30 20:57:52 2022-05-30 20:57:52
# 5860465     9841060685  electric_bike 2022-05-26 20:18:39 2022-05-26 20:18:39
#
#                       start_station_name start_station_id  \
# 50                   Orleans St & Elm St     TA1306000006
# 51             Desplaines St & Kinzie St     TA1306000003
# 53                   Clark St & Grace St     TA1307000127
# 56              Kingsbury St & Kinzie St     KA1503000043
# 57             Desplaines St & Kinzie St     TA1306000003
# ...                                  ...              ...
# 5859919     California Ave & Division St            13256
# 5860100   California Ave & Milwaukee Ave            13084
# 5860296      Campbell Ave & Montrose Ave            15623
# 5860363   California Ave & Milwaukee Ave            13084
# 5860465  Central Park Ave & Douglas Blvd            329.0
#
#                         end_station_name end_station_id  start_lat  start_lng  \
# 50                   Orleans St & Elm St   TA1306000006  41.902924 -87.637715
# 51              Kingsbury St & Kinzie St   KA1503000043  41.888716 -87.644448
# 53                 Clark St & Leland Ave   TA1309000014  41.950780 -87.659172
# 56             Desplaines St & Kinzie St   TA1306000003  41.889177 -87.638506
# 57              Kingsbury St & Kinzie St   KA1503000043  41.888716 -87.644448
# ...                                  ...            ...        ...        ...
# 5859919            Wood St & Chicago Ave            637  41.903029 -87.697474
# 5860100   California Ave & Milwaukee Ave          13084  41.922695 -87.697153
# 5860296      Campbell Ave & Montrose Ave          15623  41.961526 -87.691165
# 5860363   California Ave & Milwaukee Ave          13084  41.922695 -87.697153
# 5860465  Central Park Ave & Douglas Blvd          329.0  41.860000 -87.720000
#
#            end_lat    end_lng member_casual
# 50       41.902924 -87.637715        member
# 51       41.889177 -87.638506        member
# 53       41.967096 -87.667429        member
# 56       41.888716 -87.644448        member
# 57       41.889177 -87.638506        member
# ...            ...        ...           ...
# 5859919  41.895634 -87.672069        casual
# 5860100  41.922695 -87.697153        member
# 5860296  41.961526 -87.691165        member
# 5860363  41.922695 -87.697153        member
# 5860465  41.860000 -87.720000        member
#
# [4667299 rows x 13 columns]

# %%
(5860776-4667299)/5860776*100
# Out:
# 20.36380506608681

# %% [markdown]
# ## I want to discover if The ID of station is unique or note

# %%
df_NaNLess=df.dropna()

# %%
df_NaNLess['start_station_name'].value_counts()
# Out:
# Streeter Dr & Grand Ave                         81597
# Michigan Ave & Oak St                           42258
# Wells St & Concord Ln                           41883
# Millennium Park                                 39297
# Clark St & Elm St                               38979
#                                                 ...
# Karlov Ave & Milwaukee Ave                          1
# Newcastle Ave & Wellington Ave                      1
# Avenue J & 112th St                                 1
# Pawel Bialowas - Test- PBSC charging station        1
# Lyft Driver Center Private Rack                     1
# Name: start_station_name, Length: 1045, dtype: int64

# %%
df_NaNLess['start_station_id'].value_counts()
# Out:
# 13022           81597
# LF-005          46096
# 13042           42258
# 13300           42243
# TA1308000050    41883
#                 ...
# 839                 1
# 845                 1
# 675                 1
# 751                 1
# 808                 1
# Name: start_station_id, Length: 1013, dtype: int64

# %%
df_NaNLess[(df_NaNLess['start_station_id']=='LF-005')]['start_station_name'].unique()
# Out:
# array(['Lake Shore Dr & North Blvd', 'DuSable Lake Shore Dr & North Blvd'],
#       dtype=object)

# %% [markdown]
# ### I descoverd that the Id isnot uniqe which means that I can fill null Rows

# %% [markdown]
# ### The Technic That I will do is I will try to expect the null value with helpe of  kowen
# ### (start_station_name	start_station_id	end_station_name	end_station_id)

# %%
df[(df['start_station_name'].isna()) & (df['start_station_id'].isna())
    & (df['end_station_name'].isna()) & (df['end_station_id'].isna())]
# Out:
#                ride_id  rideable_type          started_at            ended_at  \
# 0            999384320  electric_bike 2021-06-13 14:31:28 2021-06-13 14:31:28
# 1             60488520  electric_bike 2021-06-04 11:18:02 2021-06-04 11:18:02
# 2        9598066680452  electric_bike 2021-06-04 09:49:35 2021-06-04 09:49:35
# 3           3048412214  electric_bike 2021-06-03 19:56:05 2021-06-03 19:56:05
# 4              9898737  electric_bike 2021-06-04 14:05:51 2021-06-04 14:05:51
# ...                ...            ...                 ...                 ...
# 5860760       78334399  electric_bike 2022-05-05 10:58:07 2022-05-05 10:58:07
# 5860761     3875893421  electric_bike 2022-05-12 07:22:19 2022-05-12 07:22:19
# 5860762    25515941484  electric_bike 2022-05-12 14:15:54 2022-05-12 14:15:54
# 5860763      209564570  electric_bike 2022-05-16 10:07:36 2022-05-16 10:07:36
# 5860764   692132111873  electric_bike 2022-05-12 15:19:21 2022-05-12 15:19:21
#
#         start_station_name start_station_id end_station_name end_station_id  \
# 0                      NaN              NaN              NaN            NaN
# 1                      NaN              NaN              NaN            NaN
# 2                      NaN              NaN              NaN            NaN
# 3                      NaN              NaN              NaN            NaN
# 4                      NaN              NaN              NaN            NaN
# ...                    ...              ...              ...            ...
# 5860760                NaN              NaN              NaN            NaN
# 5860761                NaN              NaN              NaN            NaN
# 5860762                NaN              NaN              NaN            NaN
# 5860763                NaN              NaN              NaN            NaN
# 5860764                NaN              NaN              NaN            NaN
#
#          start_lat  start_lng  end_lat  end_lng member_casual
# 0            41.80     -87.59    41.80   -87.60        member
# 1            41.79     -87.59    41.80   -87.60        member
# 2            41.80     -87.60    41.79   -87.59        member
# 3            41.78     -87.58    41.80   -87.60        member
# 4            41.80     -87.59    41.79   -87.59        member
# ...            ...        ...      ...      ...           ...
# 5860760      41.79     -87.60    41.79   -87.60        member
# 5860761      41.79     -87.60    41.79   -87.60        member
# 5860762      41.79     -87.60    41.80   -87.60        member
# 5860763      41.90     -87.68    41.90   -87.64        member
# 5860764      41.79     -87.60    41.79   -87.60        member
#
# [508026 rows x 13 columns]

# %%
508026/5860776*100
# Out:
# 8.668237789671538

# %%
nanIdx=df[(df['start_station_name'].isna()) & (df['start_station_id'].isna())
    & (df['end_station_name'].isna()) & (df['end_station_id'].isna())].index

# %%
df.drop(axis=0,index=nanIdx,inplace=True)

# %%
df
# Out:
#              ride_id  rideable_type          started_at            ended_at  \
# 9         5299462842  electric_bike 2021-06-23 17:57:29 2021-06-23 17:57:29
# 50         904584538   classic_bike 2021-06-04 07:29:18 2021-06-04 07:29:18
# 51       41853006552   classic_bike 2021-06-23 08:39:36 2021-06-23 08:39:36
# 53       60970908555   classic_bike 2021-06-27 12:26:58 2021-06-27 12:26:58
# 55        9869013083  electric_bike 2021-06-12 17:15:12 2021-06-12 17:15:12
# ...              ...            ...                 ...                 ...
# 5860771    889100534  electric_bike 2022-05-27 22:00:02 2022-05-27 22:00:02
# 5860772        47851  electric_bike 2022-05-15 16:05:39 2022-05-15 16:05:39
# 5860773   8163840703  electric_bike 2022-05-21 10:10:13 2022-05-21 10:10:13
# 5860774    897443290  electric_bike 2022-05-12 07:53:58 2022-05-12 07:53:58
# 5860775    238987733  electric_bike 2022-05-11 21:14:28 2022-05-11 21:14:28
#
#                        start_station_name start_station_id  \
# 9                                     NaN              NaN
# 50                    Orleans St & Elm St     TA1306000006
# 51              Desplaines St & Kinzie St     TA1306000003
# 53                    Clark St & Grace St     TA1307000127
# 55                                    NaN              NaN
# ...                                   ...              ...
# 5860771             Clark St & Newport St              632
# 5860772             Clark St & Newport St              632
# 5860773  Francisco Ave & Bloomingdale Ave              429
# 5860774  Francisco Ave & Bloomingdale Ave              429
# 5860775             Clark St & Newport St              632
#
#                  end_station_name end_station_id  start_lat  start_lng  \
# 9           Michigan Ave & Oak St          13042  41.880000 -87.610000
# 50            Orleans St & Elm St   TA1306000006  41.902924 -87.637715
# 51       Kingsbury St & Kinzie St   KA1503000043  41.888716 -87.644448
# 53          Clark St & Leland Ave   TA1309000014  41.950780 -87.659172
# 55          Michigan Ave & Oak St          13042  41.890000 -87.610000
# ...                           ...            ...        ...        ...
# 5860771                       NaN            NaN  41.944557 -87.654830
# 5860772                       NaN            NaN  41.944479 -87.654758
# 5860773                       NaN            NaN  41.910000 -87.700000
# 5860774                       NaN            NaN  41.910000 -87.700000
# 5860775                       NaN            NaN  41.944567 -87.654802
#
#            end_lat    end_lng member_casual
# 9        41.901052 -87.623698        member
# 50       41.902924 -87.637715        member
# 51       41.889177 -87.638506        member
# 53       41.967096 -87.667429        member
# 55       41.901048 -87.623812        member
# ...            ...        ...           ...
# 5860771  41.920000 -87.650000        member
# 5860772  41.920000 -87.760000        member
# 5860773  41.920000 -87.660000        casual
# 5860774  41.900000 -87.690000        member
# 5860775  41.940000 -87.650000        member
#
# [5352750 rows x 13 columns]

# %% [markdown]
# ## Handel Sart Na

# %%
df[(df['start_station_name'].isna()) & (df['start_station_id'].notna())]
# Out:
#               ride_id  rideable_type          started_at            ended_at  \
# 1298858  176105181216  electric_bike 2021-07-18 03:44:22 2021-07-18 03:44:22
# 2424358   82150263056  electric_bike 2021-09-21 18:18:59 2021-09-21 18:18:59
# 3031877        197485  electric_bike 2021-09-22 07:14:42 2021-09-22 07:14:42
#
#         start_station_name start_station_id         end_station_name  \
# 1298858                NaN            13221                      NaN
# 2424358                NaN            20215  Hegewisch Metra Station
# 3031877                NaN           WL-008                      NaN
#
#         end_station_id  start_lat  start_lng    end_lat   end_lng  \
# 1298858            NaN  41.907655 -87.672552  41.950000 -87.74000
# 2424358          20215  41.648500 -87.546089  41.648589 -87.54625
# 3031877            NaN  41.867117 -87.641087  41.880000 -87.64000
#
#         member_casual
# 1298858        casual
# 2424358        casual
# 3031877        casual

# %%
df[df['start_station_id']=='13221']['start_station_name'].unique()
# Out:
# array(['Wood St & Milwaukee Ave'], dtype=object)

# %%
df.at[1298858,'start_station_name'] ='Wood St & Milwaukee Ave'

# %%
df[df['start_station_id']=='20215']['start_station_name'].unique()
# Out:
# array(['Hegewisch Metra Station'], dtype=object)

# %%
df.at[2424358,'start_station_name'] ='Hegewisch Metra Station'

# %%
df[df['start_station_id']=='3031877']['start_station_name'].unique()
# Out:
# array([], dtype=object)

# %%
#df.at[2424358,'start_station_name'] ='Hegewisch Metra Station'
df.drop(3031877,inplace=True)

# %%
df[(df['end_station_name'].isna()) & (df['end_station_id'].notna())]
# Out:
# Empty DataFrame
# Columns: [ride_id, rideable_type, started_at, ended_at, start_station_name, start_station_id, end_station_name, end_station_id, start_lat, start_lng, end_lat, end_lng, member_casual]
# Index: []

# %%
df['Start_Name_Id']=df['start_station_name']+df['start_station_id']

# %%
df
# Out:
#              ride_id  rideable_type          started_at            ended_at  \
# 9         5299462842  electric_bike 2021-06-23 17:57:29 2021-06-23 17:57:29
# 50         904584538   classic_bike 2021-06-04 07:29:18 2021-06-04 07:29:18
# 51       41853006552   classic_bike 2021-06-23 08:39:36 2021-06-23 08:39:36
# 53       60970908555   classic_bike 2021-06-27 12:26:58 2021-06-27 12:26:58
# 55        9869013083  electric_bike 2021-06-12 17:15:12 2021-06-12 17:15:12
# ...              ...            ...                 ...                 ...
# 5860771    889100534  electric_bike 2022-05-27 22:00:02 2022-05-27 22:00:02
# 5860772        47851  electric_bike 2022-05-15 16:05:39 2022-05-15 16:05:39
# 5860773   8163840703  electric_bike 2022-05-21 10:10:13 2022-05-21 10:10:13
# 5860774    897443290  electric_bike 2022-05-12 07:53:58 2022-05-12 07:53:58
# 5860775    238987733  electric_bike 2022-05-11 21:14:28 2022-05-11 21:14:28
#
#                        start_station_name start_station_id  \
# 9                                     NaN              NaN
# 50                    Orleans St & Elm St     TA1306000006
# 51              Desplaines St & Kinzie St     TA1306000003
# 53                    Clark St & Grace St     TA1307000127
# 55                                    NaN              NaN
# ...                                   ...              ...
# 5860771             Clark St & Newport St              632
# 5860772             Clark St & Newport St              632
# 5860773  Francisco Ave & Bloomingdale Ave              429
# 5860774  Francisco Ave & Bloomingdale Ave              429
# 5860775             Clark St & Newport St              632
#
#                  end_station_name end_station_id  start_lat  start_lng  \
# 9           Michigan Ave & Oak St          13042  41.880000 -87.610000
# 50            Orleans St & Elm St   TA1306000006  41.902924 -87.637715
# 51       Kingsbury St & Kinzie St   KA1503000043  41.888716 -87.644448
# 53          Clark St & Leland Ave   TA1309000014  41.950780 -87.659172
# 55          Michigan Ave & Oak St          13042  41.890000 -87.610000
# ...                           ...            ...        ...        ...
# 5860771                       NaN            NaN  41.944557 -87.654830
# 5860772                       NaN            NaN  41.944479 -87.654758
# 5860773                       NaN            NaN  41.910000 -87.700000
# 5860774                       NaN            NaN  41.910000 -87.700000
# 5860775                       NaN            NaN  41.944567 -87.654802
#
#            end_lat    end_lng member_casual  \
# 9        41.901052 -87.623698        member
# 50       41.902924 -87.637715        member
# 51       41.889177 -87.638506        member
# 53       41.967096 -87.667429        member
# 55       41.901048 -87.623812        member
# ...            ...        ...           ...
# 5860771  41.920000 -87.650000        member
# 5860772  41.920000 -87.760000        member
# 5860773  41.920000 -87.660000        casual
# 5860774  41.900000 -87.690000        member
# 5860775  41.940000 -87.650000        member
#
#                                  Start_Name_Id
# 9                                          NaN
# 50             Orleans St & Elm StTA1306000006
# 51       Desplaines St & Kinzie StTA1306000003
# 53             Clark St & Grace StTA1307000127
# 55                                         NaN
# ...                                        ...
# 5860771               Clark St & Newport St632
# 5860772               Clark St & Newport St632
# 5860773    Francisco Ave & Bloomingdale Ave429
# 5860774    Francisco Ave & Bloomingdale Ave429
# 5860775               Clark St & Newport St632
#
# [5352749 rows x 14 columns]

# %%
df['Start_Name_Id'].value_counts().sort_values(ascending=False).index[0]
# Out:
# 'Streeter Dr & Grand Ave13022'

# %%
df[(df['start_station_name']=='Streeter Dr & Grand Ave') & (df['start_station_id']=='13022')]
# Out:
#               ride_id  rideable_type          started_at            ended_at  \
# 12048        22064011   classic_bike 2021-06-15 19:52:48 2021-06-15 19:52:48
# 12309    243534285500   classic_bike 2021-06-09 19:56:59 2021-06-09 19:56:59
# 12864      6962792026  electric_bike 2021-06-05 19:14:06 2021-06-05 19:14:06
# 12893       824975723   classic_bike 2021-06-20 10:23:20 2021-06-20 10:23:20
# 13144        62950284   classic_bike 2021-06-17 14:07:12 2021-06-17 14:07:12
# ...               ...            ...                 ...                 ...
# 5850080   34713745587  electric_bike 2022-05-16 19:08:35 2022-05-16 19:08:35
# 5850082   49080557819  electric_bike 2022-05-23 16:20:06 2022-05-23 16:20:06
# 5850083    3459286044  electric_bike 2022-05-28 21:34:42 2022-05-28 21:34:42
# 5850084  212195226664  electric_bike 2022-05-29 14:12:42 2022-05-29 14:12:42
# 5850086    8854573040  electric_bike 2022-05-14 12:09:22 2022-05-14 12:09:22
#
#               start_station_name start_station_id  \
# 12048    Streeter Dr & Grand Ave            13022
# 12309    Streeter Dr & Grand Ave            13022
# 12864    Streeter Dr & Grand Ave            13022
# 12893    Streeter Dr & Grand Ave            13022
# 13144    Streeter Dr & Grand Ave            13022
# ...                          ...              ...
# 5850080  Streeter Dr & Grand Ave            13022
# 5850082  Streeter Dr & Grand Ave            13022
# 5850083  Streeter Dr & Grand Ave            13022
# 5850084  Streeter Dr & Grand Ave            13022
# 5850086  Streeter Dr & Grand Ave            13022
#
#                      end_station_name end_station_id  start_lat  start_lng  \
# 12048    Stetson Ave & South Water St   TA1308000029  41.892278 -87.612043
# 12309       Columbus Dr & Randolph St          13263  41.892278 -87.612043
# 12864    Spaulding Ave & Armitage Ave          15650  41.892277 -87.612159
# 12893    Southport Ave & Clybourn Ave   TA1309000030  41.892278 -87.612043
# 13144              Rush St & Cedar St   KA1504000133  41.892278 -87.612043
# ...                               ...            ...        ...        ...
# 5850080                           NaN            NaN  41.892312 -87.612162
# 5850082                           NaN            NaN  41.892130 -87.611928
# 5850083                           NaN            NaN  41.892211 -87.611924
# 5850084                           NaN            NaN  41.892224 -87.612289
# 5850086                           NaN            NaN  41.892231 -87.611993
#
#            end_lat    end_lng member_casual                 Start_Name_Id
# 12048    41.886835 -87.622320        casual  Streeter Dr & Grand Ave13022
# 12309    41.884728 -87.619521        member  Streeter Dr & Grand Ave13022
# 12864    41.917217 -87.710299        casual  Streeter Dr & Grand Ave13022
# 12893    41.920771 -87.663712        member  Streeter Dr & Grand Ave13022
# 13144    41.902309 -87.627691        member  Streeter Dr & Grand Ave13022
# ...            ...        ...           ...                           ...
# 5850080  41.880000 -87.620000        casual  Streeter Dr & Grand Ave13022
# 5850082  41.890000 -87.610000        casual  Streeter Dr & Grand Ave13022
# 5850083  41.890000 -87.610000        casual  Streeter Dr & Grand Ave13022
# 5850084  41.990000 -87.650000        casual  Streeter Dr & Grand Ave13022
# 5850086  41.910000 -87.620000        member  Streeter Dr & Grand Ave13022
#
# [84272 rows x 14 columns]

# %%
df['start_station_name'].fillna('Streeter Dr & Grand Ave',inplace=True)
df['start_station_id'].fillna('13002',inplace=True)

# %%
df.drop('Start_Name_Id',axis=1,inplace=True)

# %% [markdown]
# ## Handel End Na

# %%
df['End_Name_Id']=df['end_station_name']+df['end_station_id']

# %%
df['End_Name_Id'].value_counts().sort_values(ascending=False).index[0]
# Out:
# 'Streeter Dr & Grand Ave13022'

# %%
df['end_station_name'].fillna('Streeter Dr & Grand Ave',inplace=True)
df['end_station_id'].fillna('13002',inplace=True)

# %%
df.drop(['End_Name_Id'],axis=1,inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5352749 entries, 9 to 5860775
# Data columns (total 13 columns):
#  #   Column              Dtype
# ---  ------              -----
#  0   ride_id             int64
#  1   rideable_type       object
#  2   started_at          datetime64[ns]
#  3   ended_at            datetime64[ns]
#  4   start_station_name  object
#  5   start_station_id    object
#  6   end_station_name    object
#  7   end_station_id      object
#  8   start_lat           float64
#  9   start_lng           float64
#  10  end_lat             float64
#  11  end_lng             float64
#  12  member_casual       object
# dtypes: datetime64[ns](2), float64(4), int64(1), object(6)
# memory usage: 571.7+ MB

# %%
df['start_station_id'].isna().sum()
# Out:
# 0

# %%
df['start_station_id_Copy']=df['start_station_id'].apply(Id)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5352749 entries, 9 to 5860775
# Data columns (total 14 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   ride_id                int64
#  1   rideable_type          object
#  2   started_at             datetime64[ns]
#  3   ended_at               datetime64[ns]
#  4   start_station_name     object
#  5   start_station_id       object
#  6   end_station_name       object
#  7   end_station_id         object
#  8   start_lat              float64
#  9   start_lng              float64
#  10  end_lat                float64
#  11  end_lng                float64
#  12  member_casual          object
#  13  start_station_id_Copy  float64
# dtypes: datetime64[ns](2), float64(5), int64(1), object(6)
# memory usage: 612.6+ MB

# %%
df[['start_station_id_Copy','start_station_id']]
# Out:
#          start_station_id_Copy start_station_id
# 9                 1.300200e+04            13002
# 50                1.306000e+09     TA1306000006
# 51                1.306000e+09     TA1306000003
# 53                1.307000e+09     TA1307000127
# 55                1.300200e+04            13002
# ...                        ...              ...
# 5860771           6.320000e+02              632
# 5860772           6.320000e+02              632
# 5860773           4.290000e+02              429
# 5860774           4.290000e+02              429
# 5860775           6.320000e+02              632
#
# [5352749 rows x 2 columns]

# %%
df['end_station_id_Copy']=df['end_station_id'].apply(Id)

# %%
df[['end_station_id_Copy','end_station_id']]
# Out:
#          end_station_id_Copy end_station_id
# 9               1.304200e+04          13042
# 50              1.306000e+09   TA1306000006
# 51              1.503000e+09   KA1503000043
# 53              1.309000e+09   TA1309000014
# 55              1.304200e+04          13042
# ...                      ...            ...
# 5860771         1.300200e+04          13002
# 5860772         1.300200e+04          13002
# 5860773         1.300200e+04          13002
# 5860774         1.300200e+04          13002
# 5860775         1.300200e+04          13002
#
# [5352749 rows x 2 columns]

# %%
df['start_station_id']=df['start_station_id_Copy']
df['end_station_id']=df['end_station_id_Copy']
df.drop(['start_station_id_Copy','end_station_id_Copy'],axis=1,inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5352749 entries, 9 to 5860775
# Data columns (total 13 columns):
#  #   Column              Dtype
# ---  ------              -----
#  0   ride_id             int64
#  1   rideable_type       object
#  2   started_at          datetime64[ns]
#  3   ended_at            datetime64[ns]
#  4   start_station_name  object
#  5   start_station_id    float64
#  6   end_station_name    object
#  7   end_station_id      float64
#  8   start_lat           float64
#  9   start_lng           float64
#  10  end_lat             float64
#  11  end_lng             float64
#  12  member_casual       object
# dtypes: datetime64[ns](2), float64(6), int64(1), object(4)
# memory usage: 571.7+ MB

# %% [markdown]
# ## Handel lat and lng nan

# %%
df.isna().mean()*100
# Out:
# ride_id               0.000000
# rideable_type         0.000000
# started_at            0.000000
# ended_at              0.000000
# start_station_name    0.000000
# start_station_id      0.622484
# end_station_name      0.000000
# end_station_id        0.593658
# start_lat             0.000000
# start_lng             0.000000
# end_lat               0.094082
# end_lng               0.094082
# member_casual         0.000000
# dtype: float64

# %%
df.dropna(axis=0,inplace=True)

# %% [markdown]
# ## Lest Apply bivariate analysis

# %%
df[['start_station_name','end_station_name']]
# Out:
#                        start_station_name          end_station_name
# 9                 Streeter Dr & Grand Ave     Michigan Ave & Oak St
# 50                    Orleans St & Elm St       Orleans St & Elm St
# 51              Desplaines St & Kinzie St  Kingsbury St & Kinzie St
# 53                    Clark St & Grace St     Clark St & Leland Ave
# 55                Streeter Dr & Grand Ave     Michigan Ave & Oak St
# ...                                   ...                       ...
# 5860771             Clark St & Newport St   Streeter Dr & Grand Ave
# 5860772             Clark St & Newport St   Streeter Dr & Grand Ave
# 5860773  Francisco Ave & Bloomingdale Ave   Streeter Dr & Grand Ave
# 5860774  Francisco Ave & Bloomingdale Ave   Streeter Dr & Grand Ave
# 5860775             Clark St & Newport St   Streeter Dr & Grand Ave
#
# [5284785 rows x 2 columns]

# %% [markdown]
# ## Lest Apply bivariate analysis

# %%
df[df['started_at']==df['ended_at']]
# Out:
#              ride_id  rideable_type          started_at            ended_at  \
# 9         5299462842  electric_bike 2021-06-23 17:57:29 2021-06-23 17:57:29
# 50         904584538   classic_bike 2021-06-04 07:29:18 2021-06-04 07:29:18
# 51       41853006552   classic_bike 2021-06-23 08:39:36 2021-06-23 08:39:36
# 53       60970908555   classic_bike 2021-06-27 12:26:58 2021-06-27 12:26:58
# 55        9869013083  electric_bike 2021-06-12 17:15:12 2021-06-12 17:15:12
# ...              ...            ...                 ...                 ...
# 5860771    889100534  electric_bike 2022-05-27 22:00:02 2022-05-27 22:00:02
# 5860772        47851  electric_bike 2022-05-15 16:05:39 2022-05-15 16:05:39
# 5860773   8163840703  electric_bike 2022-05-21 10:10:13 2022-05-21 10:10:13
# 5860774    897443290  electric_bike 2022-05-12 07:53:58 2022-05-12 07:53:58
# 5860775    238987733  electric_bike 2022-05-11 21:14:28 2022-05-11 21:14:28
#
#                        start_station_name  start_station_id  \
# 9                 Streeter Dr & Grand Ave      1.300200e+04
# 50                    Orleans St & Elm St      1.306000e+09
# 51              Desplaines St & Kinzie St      1.306000e+09
# 53                    Clark St & Grace St      1.307000e+09
# 55                Streeter Dr & Grand Ave      1.300200e+04
# ...                                   ...               ...
# 5860771             Clark St & Newport St      6.320000e+02
# 5860772             Clark St & Newport St      6.320000e+02
# 5860773  Francisco Ave & Bloomingdale Ave      4.290000e+02
# 5860774  Francisco Ave & Bloomingdale Ave      4.290000e+02
# 5860775             Clark St & Newport St      6.320000e+02
#
#                  end_station_name  end_station_id  start_lat  start_lng  \
# 9           Michigan Ave & Oak St    1.304200e+04  41.880000 -87.610000
# 50            Orleans St & Elm St    1.306000e+09  41.902924 -87.637715
# 51       Kingsbury St & Kinzie St    1.503000e+09  41.888716 -87.644448
# 53          Clark St & Leland Ave    1.309000e+09  41.950780 -87.659172
# 55          Michigan Ave & Oak St    1.304200e+04  41.890000 -87.610000
# ...                           ...             ...        ...        ...
# 5860771   Streeter Dr & Grand Ave    1.300200e+04  41.944557 -87.654830
# 5860772   Streeter Dr & Grand Ave    1.300200e+04  41.944479 -87.654758
# 5860773   Streeter Dr & Grand Ave    1.300200e+04  41.910000 -87.700000
# 5860774   Streeter Dr & Grand Ave    1.300200e+04  41.910000 -87.700000
# 5860775   Streeter Dr & Grand Ave    1.300200e+04  41.944567 -87.654802
#
#            end_lat    end_lng member_casual
# 9        41.901052 -87.623698        member
# 50       41.902924 -87.637715        member
# 51       41.889177 -87.638506        member
# 53       41.967096 -87.667429        member
# 55       41.901048 -87.623812        member
# ...            ...        ...           ...
# 5860771  41.920000 -87.650000        member
# 5860772  41.920000 -87.760000        member
# 5860773  41.920000 -87.660000        casual
# 5860774  41.900000 -87.690000        member
# 5860775  41.940000 -87.650000        member
#
# [5284785 rows x 13 columns]

# %%
df.shape
# Out:
# (5284786, 13)

# %%
df.drop('ended_at',axis=1,inplace=True)

# %% [markdown]
# ## Apply feature engineering

# %%
from geopy.distance import great_circle

# %%
def get_des(x):
        loc1=(x['start_lat'],x['start_lng'])
        loc2=(x['end_lat'],x['end_lng'])
        return great_circle(loc1,loc2).kilometers

# %%
df['destace(KM)']=df.apply(get_des,axis=1)

# %%
df[['destace(KM)']]
# Out:
#          destace(KM)
# 9           2.601049
# 50          0.000000
# 51          0.494536
# 53          1.938474
# 55          1.678090
# ...              ...
# 5860771     2.759672
# 5860772     9.121459
# 5860773     3.491566
# 5860774     1.386114
# 5860775     0.644634
#
# [5284785 rows x 1 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5284785 entries, 9 to 5860775
# Data columns (total 13 columns):
#  #   Column              Dtype
# ---  ------              -----
#  0   ride_id             int64
#  1   rideable_type       object
#  2   started_at          datetime64[ns]
#  3   start_station_name  object
#  4   start_station_id    float64
#  5   end_station_name    object
#  6   end_station_id      float64
#  7   start_lat           float64
#  8   start_lng           float64
#  9   end_lat             float64
#  10  end_lng             float64
#  11  member_casual       object
#  12  destace(KM)         float64
# dtypes: datetime64[ns](1), float64(7), int64(1), object(4)
# memory usage: 564.5+ MB

# %%
df.describe()[['destace(KM)']]
# Out:
#         destace(KM)
# count  5.284785e+06
# mean   2.192354e+00
# std    1.956192e+00
# min    0.000000e+00
# 25%    9.165780e-01
# 50%    1.639177e+00
# 75%    2.873779e+00
# max    1.143837e+02

# %%
sns.set(rc={'figure.figsize': [5, 5]}, font_scale=1.3)
sns.kdeplot(data=df,x='destace(KM)')
# Out:
# <AxesSubplot:xlabel='destace(KM)', ylabel='Density'>

# %%
sns.set(rc={'figure.figsize': [10, 5]}, font_scale=1.3)
sns.boxplot(data=df,x='destace(KM)')
# Out:
# <AxesSubplot:xlabel='destace(KM)'>

# %%
df[df['destace(KM)']==df['destace(KM)'].max()]
# Out:
#            ride_id  rideable_type          started_at     start_station_name  \
# 4046035  943803803  electric_bike 2021-11-09 06:47:52  Narragansett & McLean
#
#          start_station_id         end_station_name  end_station_id  start_lat  \
# 4046035             309.0  Streeter Dr & Grand Ave         13002.0      41.92
#
#          start_lng  end_lat  end_lng member_casual  destace(KM)
# 4046035     -87.79    41.39   -88.97        casual   114.383732

# %%
df.drop(4046035,axis=0,inplace=True)

# %%
df[df['destace(KM)']==0].shape[0]/df.shape[0]*100
# Out:
# 4.7937617140527005

# %%
idx_of_zero_des=df[df['destace(KM)']==0].index

# %%
df.drop(index=idx_of_zero_des,axis=0,inplace=True)

# %%
df[df['destace(KM)']==0]
# Out:
# Empty DataFrame
# Columns: [ride_id, rideable_type, started_at, start_station_name, start_station_id, end_station_name, end_station_id, start_lat, start_lng, end_lat, end_lng, member_casual, destace(KM)]
# Index: []

# %%
sns.set(rc={'figure.figsize': [10, 10]}, font_scale=1.3)
sns.displot(data=df,x='destace(KM)',)

# %%
sns.kdeplot(data=df,x='destace(KM)')
# Out:
# <AxesSubplot:xlabel='destace(KM)', ylabel='Density'>

# %% [markdown]
# ## Handel OutLayers For destace(KM)

# %%
sns.boxplot(data=df,x='destace(KM)')
# Out:
# <AxesSubplot:xlabel='destace(KM)'>

# %%
sns.kdeplot(data=df,x='destace(KM)')
# Out:
# <AxesSubplot:xlabel='destace(KM)', ylabel='Density'>

# %%
from datasist.structdata import detect_outliers

# %%
outliers_indices = detect_outliers(data=df, n=0, features=['destace(KM)'])
outliers_indices
# Out:
# [220,
#  228,
#  310,
#  362,
#  407,
#  658,
#  688,
#  795,
#  1070,
#  1683,
#  2041,
#  2105,
#  2311,
#  2347,
#  2358,
#  2506,
#  3468,
#  3582,
#  3594,
#  3626,
#  3705,
#  3775,
#  3826,
#  3852,
#  4027,
#  4037,
#  4076,
#  4175,
#  4301,
#  4406,
#  4432,
#  4466,
#  4744,
#  5084,
#  5327,
#  5344,
#  5750,
#  5944,
#  6727,
#  7237,
#  7570,
#  7760,
#  7877,
#  8337,
#  8502,
#  8811,
#  8917,
#  9137,
#  9205,
#  9766,
#  10116,
#  10368,
#  10449,
#  10621,
#  10693,
#  10866,
#  11223,
#  11224,
#  11249,
#  11267,
#  11268,
#  11280,
#  11282,
#  11287,
#  11289,
#  11314,
#  11316,
#  11317,
#  11347,
#  11374,
#  11387,
#  11391,
#  11393,
#  11396,
#  11403,
#  11456,
#  11465,
#  11468,
#  11473,
#  11474,
#  11478,
#  11532,
#  11571,
#  11603,
#  11617,
#  11674,
#  11701,
#  11709,
#  11710,
#  11714,
#  11744,
#  11751,
#  11773,
#  11784,
#  11786,
#  11787,
#  11796,
#  11797,
#  11798,
#  11904,
#  11908,
#  11909,
#  11929,
#  12018,
#  12030,
#  12046,
#  12049,
#  12059,
#  12061,
#  12098,
#  12113,
#  12161,
#  12263,
#  12267,
#  12319,
#  12320,
#  12325,
#  12386,
#  12388,
#  12410,
#  12411,
#  12425,
#  12447,
#  12505,
#  12547,
#  12551,
#  12552,
#  12571,
#  12591,
#  12600,
#  12603,
#  12650,
#  12651,
#  12670,
#  12677,
#  12685,
#  12690,
#  12705,
#  12736,
#  12737,
#  12753,
#  12765,
#  12766,
#  12768,
#  12784,
#  12814,
#  12815,
#  12816,
#  12824,
#  12838,
#  12851,
#  12864,
#  12865,
#  12872,
#  12900,
#  12901,
#  12903,
#  12925,
#  12942,
#  12944,
#  12948,
#  12950,
#  12951,
#  12953,
#  12958,
#  12959,
#  12971,
#  12972,
#  12973,
#  12974,
#  12975,
#  12992,
#  12994,
#  12997,
#  12998,
#  13000,
#  13006,
#  13007,
#  13014,
#  13030,
#  13084,
#  13101,
#  13103,
#  13117,
#  13141,
#  13142,
#  13150,
#  13164,
#  13173,
#  13182,
#  13192,
#  13244,
#  13283,
#  13286,
#  13305,
#  13309,
#  13372,
#  13373,
#  13382,
#  13445,
#  13447,
#  13459,
#  13470,
#  13514,
#  13517,
#  13520,
#  13533,
#  13535,
#  13538,
#  13542,
#  13564,
#  13565,
#  13582,
#  13585,
#  13601,
#  13605,
#  13610,
#  13638,
#  13662,
#  13666,
#  13669,
#  13675,
#  13692,
#  13698,
#  13699,
#  13704,
#  13707,
#  13713,
#  13716,
#  13752,
#  13754,
#  13783,
#  13819,
#  13854,
#  13856,
#  13859,
#  13867,
#  13913,
#  13921,
#  13933,
#  13977,
#  13992,
#  14055,
#  14060,
#  14061,
#  14097,
#  14102,
#  14107,
#  14111,
#  14117,
#  14122,
#  14138,
#  14139,
#  14155,
#  14156,
#  14170,
#  14177,
#  14181,
#  14182,
#  14186,
#  14191,
#  14192,
#  14215,
#  14238,
#  14262,
#  14270,
#  14272,
#  14291,
#  14292,
#  14298,
#  14307,
#  14310,
#  14312,
#  14324,
#  14325,
#  14394,
#  14396,
#  14401,
#  14404,
#  14413,
#  14429,
#  14435,
#  14469,
#  14471,
#  14478,
#  14488,
#  14489,
#  14528,
#  14558,
#  14643,
#  14668,
#  14701,
#  14709,
#  14716,
#  14723,
#  14725,
#  14768,
#  14774,
#  14806,
#  14807,
#  15013,
#  15016,
#  15032,
#  15039,
#  15057,
#  15062,
#  15066,
#  15067,
#  15073,
#  15075,
#  15135,
#  15149,
#  15167,
#  15172,
#  15186,
#  15192,
#  15201,
#  15202,
#  15220,
#  15229,
#  15257,
#  15258,
#  15259,
#  15267,
#  15291,
#  15306,
#  15309,
#  15390,
#  15397,
#  15411,
#  15413,
#  15433,
#  15439,
#  15451,
#  15487,
#  15502,
#  15536,
#  15540,
#  15584,
#  15620,
#  15638,
#  15698,
#  15713,
#  15719,
#  15754,
#  15763,
#  15784,
#  15786,
#  15787,
#  15789,
#  15835,
#  15837,
#  15854,
#  15886,
#  15888,
#  15946,
#  15974,
#  16012,
#  16031,
#  16044,
#  16064,
#  16067,
#  16079,
#  16085,
#  16087,
#  16088,
#  16100,
#  16157,
#  16158,
#  16159,
#  16197,
#  16198,
#  16239,
#  16242,
#  16245,
#  16246,
#  16247,
#  16248,
#  16251,
#  16257,
#  16281,
#  16301,
#  16302,
#  16323,
#  16326,
#  16348,
#  16364,
#  16388,
#  16416,
#  16481,
#  16484,
#  16595,
#  16607,
#  16611,
#  16620,
#  16660,
#  16683,
#  16684,
#  16685,
#  16698,
#  16705,
#  16710,
#  16720,
#  16740,
#  16786,
#  16818,
#  16908,
#  16923,
#  16952,
#  16957,
#  16962,
#  16965,
#  16968,
#  16984,
#  16991,
#  16995,
#  17030,
#  17061,
#  17064,
#  17150,
#  17153,
#  17161,
#  17162,
#  17188,
#  17265,
#  17268,
#  17283,
#  17328,
#  17329,
#  17379,
#  17391,
#  17395,
#  17433,
#  17504,
#  17528,
#  17604,
#  17610,
#  17638,
#  17656,
#  17663,
#  17664,
#  17675,
#  17681,
#  17684,
#  17745,
#  17750,
#  17760,
#  17804,
#  17857,
#  17860,
#  17861,
#  17868,
#  17871,
#  17873,
#  17874,
#  17898,
#  17901,
#  17973,
#  17990,
#  18010,
#  18018,
#  18020,
#  18023,
#  18029,
#  18031,
#  18039,
#  18048,
#  18049,
#  18054,
#  18067,
#  18092,
#  18115,
#  18188,
#  18189,
#  18197,
#  18216,
#  18224,
#  18229,
#  18243,
#  18247,
#  18267,
#  18369,
#  18407,
#  18425,
#  18430,
#  18431,
#  18436,
#  18440,
#  18475,
#  18490,
#  18495,
#  18497,
#  18509,
#  18510,
#  18511,
#  18519,
#  18526,
#  18530,
#  18543,
#  18545,
#  18549,
#  18559,
#  18560,
#  18568,
#  18573,
#  18609,
#  18618,
#  18620,
#  18666,
#  18770,
#  18951,
#  18957,
#  18986,
#  18996,
#  19016,
#  19022,
#  19023,
#  19038,
#  19060,
#  19073,
#  19082,
#  19086,
#  19092,
#  19120,
#  19129,
#  19150,
#  19176,
#  19181,
#  19202,
#  19213,
#  19217,
#  19231,
#  19241,
#  19253,
#  19258,
#  19264,
#  19329,
#  19339,
#  19342,
#  19354,
#  19374,
#  19385,
#  19386,
#  19389,
#  19394,
#  19420,
#  19430,
#  19459,
#  19460,
#  19475,
#  19528,
#  19531,
#  19534,
#  19541,
#  19561,
#  19565,
#  19572,
#  19600,
#  19603,
#  19622,
#  19627,
#  19642,
#  19647,
#  19648,
#  19649,
#  19650,
#  19685,
#  19687,
#  19688,
#  19700,
#  19762,
#  19769,
#  19772,
#  19783,
#  19795,
#  19798,
#  19808,
#  19813,
#  19817,
#  19824,
#  19837,
#  19839,
#  19894,
#  19923,
#  19926,
#  19935,
#  19942,
#  19945,
#  19948,
#  19949,
#  19954,
#  19976,
#  20011,
#  20063,
#  20071,
#  20085,
#  20094,
#  20106,
#  20176,
#  20204,
#  20221,
#  20223,
#  20239,
#  20257,
#  20259,
#  20343,
#  20349,
#  20351,
#  20352,
#  20385,
#  20388,
#  20458,
#  20478,
#  20552,
#  20655,
#  20720,
#  20738,
#  20765,
#  20768,
#  20769,
#  20780,
#  20786,
#  20792,
#  20845,
#  20846,
#  20869,
#  20875,
#  20879,
#  20880,
#  20881,
#  20926,
#  20943,
#  20949,
#  20951,
#  20954,
#  20961,
#  21035,
#  21037,
#  21039,
#  21047,
#  21056,
#  21058,
#  21059,
#  21063,
#  21064,
#  21066,
#  21070,
#  21071,
#  21072,
#  21075,
#  21076,
#  21077,
#  21078,
#  21080,
#  21095,
#  21120,
#  21133,
#  21151,
#  21159,
#  21162,
#  21177,
#  21229,
#  21230,
#  21236,
#  21249,
#  21254,
#  21255,
#  21267,
#  21272,
#  21279,
#  21297,
#  21306,
#  21348,
#  21349,
#  21399,
#  21507,
#  21522,
#  21530,
#  21533,
#  21548,
#  21549,
#  21550,
#  21566,
#  21576,
#  21589,
#  21624,
#  21627,
#  21639,
#  21654,
#  21656,
#  21657,
#  21681,
#  21682,
#  21686,
#  21725,
#  21727,
#  21790,
#  21827,
#  21957,
#  21978,
#  21996,
#  22003,
#  22005,
#  22069,
#  22078,
#  22089,
#  22129,
#  22131,
#  22134,
#  22141,
#  22143,
#  22147,
#  22169,
#  22197,
#  22198,
#  22207,
#  22224,
#  22257,
#  22278,
#  22286,
#  22289,
#  22293,
#  22294,
#  22301,
#  22329,
#  22332,
#  22337,
#  22343,
#  22345,
#  22348,
#  22356,
#  22361,
#  22373,
#  22433,
#  22435,
#  22449,
#  22460,
#  22468,
#  22469,
#  22506,
#  22522,
#  22541,
#  22557,
#  22559,
#  22572,
#  22583,
#  22585,
#  22636,
#  22660,
#  22680,
#  22712,
#  22730,
#  22732,
#  22738,
#  22739,
#  22742,
#  22746,
#  22748,
#  22752,
#  22756,
#  22769,
#  22770,
#  22787,
#  22808,
#  22816,
#  22828,
#  22839,
#  22927,
#  22941,
#  22972,
#  22981,
#  22993,
#  22994,
#  22996,
#  22997,
#  23007,
#  23029,
#  23059,
#  23074,
#  23090,
#  23092,
#  23093,
#  23117,
#  23119,
#  23137,
#  23141,
#  23152,
#  23163,
#  23226,
#  23390,
#  23439,
#  23441,
#  23482,
#  23505,
#  23578,
#  23600,
#  23611,
#  23626,
#  23636,
#  23706,
#  23708,
#  23719,
#  23742,
#  23847,
#  23953,
#  23972,
#  23977,
#  23991,
#  24010,
#  24014,
#  24015,
#  24079,
#  24113,
#  24162,
#  24201,
#  24300,
#  24351,
#  24382,
#  24384,
#  24385,
#  24468,
#  24470,
#  24493,
#  24497,
#  24503,
#  24510,
#  24517,
#  24537,
#  24541,
#  24548,
#  24567,
#  24570,
#  24571,
#  24596,
#  24685,
#  24747,
#  24751,
#  24759,
#  24760,
#  24794,
#  24802,
#  24874,
#  24911,
#  24919,
#  24964,
#  24981,
#  24984,
#  24991,
#  25023,
#  25061,
#  25079,
#  25085,
#  25117,
#  25118,
#  25180,
#  25189,
#  25202,
#  25218,
#  25240,
#  25245,
#  25254,
#  25260,
#  25271,
#  25280,
#  25301,
#  25309,
#  25320,
#  25324,
#  25328,
#  25334,
#  25386,
#  25390,
#  25406,
#  25407,
#  25409,
#  25473,
#  25474,
#  25479,
#  25481,
#  25508,
#  25518,
#  25520,
#  25522,
#  25523,
#  25525,
#  25594,
#  25664,
#  25719,
#  25720,
#  25754,
#  25820,
#  25823,
#  25852,
#  25882,
#  25887,
#  25984,
#  26039,
#  26043,
#  26054,
#  26060,
#  26063,
#  26064,
#  26074,
#  26075,
#  26078,
#  26082,
#  26083,
#  26086,
#  26113,
#  26125,
#  26141,
#  26145,
#  26146,
#  26188,
#  26196,
#  26246,
#  26263,
#  26265,
#  26274,
#  26315,
#  26316,
#  26322,
#  26324,
#  26406,
#  26427,
#  26432,
#  26436,
#  26438,
#  26440,
#  26464,
#  26480,
#  26484,
#  26492,
#  26493,
#  26495,
#  26496,
#  26507,
#  26511,
#  26512,
#  26515,
#  26516,
#  26517,
#  26543,
#  26569,
#  26576,
#  26581,
#  26584,
#  26590,
#  26592,
#  26594,
#  26602,
#  26615,
#  26616,
#  26617,
#  26639,
#  26658,
#  26679,
#  26689,
#  26698,
#  26700,
#  26703,
#  26712,
#  26713,
#  26715,
#  26716,
#  26719,
#  26727,
#  26744,
#  26749,
#  26751,
#  26755,
#  26757,
#  26764,
#  26765,
#  26767,
#  26768,
#  26770,
#  26780,
#  26781,
#  26784,
#  26785,
#  26787,
#  26791,
#  26802,
#  26817,
#  26833,
#  26834,
#  26837,
#  26838,
#  26841,
#  26842,
#  26844,
#  26845,
#  26846,
#  26848,
#  26849,
#  26850,
#  26851,
#  26856,
#  26858,
#  ...]

# %%
df[df.index.isin(outliers_indices)]
# Out:
#                ride_id  rideable_type          started_at  \
# 220         2953485860  electric_bike 2021-06-02 15:53:01
# 228         3867380714   classic_bike 2021-06-14 15:20:00
# 310         1617575441  electric_bike 2021-06-27 08:43:59
# 362      8815190515274  electric_bike 2021-06-05 16:31:41
# 407            6561359  electric_bike 2021-06-03 21:15:09
# ...                ...            ...                 ...
# 5859393   993052159458  electric_bike 2022-05-18 19:31:40
# 5859871      479257291  electric_bike 2022-05-20 13:17:45
# 5860447  9596000030320  electric_bike 2022-05-28 23:42:34
# 5860766   306526037350  electric_bike 2022-05-15 17:50:11
# 5860772          47851  electric_bike 2022-05-15 16:05:39
#
#                  start_station_name  start_station_id  \
# 220         Streeter Dr & Grand Ave      1.300200e+04
# 228             Clark St & Grace St      1.307000e+09
# 310         Streeter Dr & Grand Ave      1.300200e+04
# 362         Streeter Dr & Grand Ave      1.300200e+04
# 407      Aberdeen St & Jackson Blvd      1.315700e+04
# ...                             ...               ...
# 5859393     Streeter Dr & Grand Ave      1.300200e+04
# 5859871         Buckingham Fountain      1.554100e+04
# 5860447     Streeter Dr & Grand Ave      1.300200e+04
# 5860766        Racine Ave & 18th St      1.316400e+04
# 5860772       Clark St & Newport St      6.320000e+02
#
#                        end_station_name  end_station_id  start_lat  start_lng  \
# 220           Desplaines St & Kinzie St    1.306000e+09  41.940000 -87.740000
# 228               Michigan Ave & Oak St    1.304200e+04  41.950780 -87.659172
# 310             Dearborn St & Monroe St    1.305000e+09  41.810000 -87.600000
# 362           Desplaines St & Kinzie St    1.306000e+09  41.780000 -87.570000
# 407             Streeter Dr & Grand Ave    1.300200e+04  41.877724 -87.654892
# ...                                 ...             ...        ...        ...
# 5859393  California Ave & Milwaukee Ave    1.308400e+04  41.850000 -87.690000
# 5859871         Streeter Dr & Grand Ave    1.300200e+04  41.876302 -87.620374
# 5860447  California Ave & Milwaukee Ave    1.308400e+04  41.860000 -87.610000
# 5860766         Streeter Dr & Grand Ave    1.300200e+04  41.858122 -87.656441
# 5860772         Streeter Dr & Grand Ave    1.300200e+04  41.944479 -87.654758
#
#            end_lat    end_lng member_casual  destace(KM)
# 220      41.889100 -87.644645        casual     9.710179
# 228      41.900960 -87.623777        casual     6.266017
# 310      41.880549 -87.629653        casual     8.220211
# 362      41.888549 -87.644442        casual    13.554507
# 407      41.900000 -87.730000        casual     6.692578
# ...            ...        ...           ...          ...
# 5859393  41.922695 -87.697153        member     8.104986
# 5859871  41.930000 -87.630000        casual     6.023858
# 5860447  41.922695 -87.697153        member    10.032106
# 5860766  41.930000 -87.700000        member     8.768098
# 5860772  41.920000 -87.760000        member     9.121459
#
# [286732 rows x 13 columns]

# %%
df[df.index.isin(outliers_indices)].shape[0]/df.shape[0]*100
# Out:
# 5.6988013778946955

# %%
df.describe()[['destace(KM)']]
# Out:
#         destace(KM)
# count  5.031444e+06
# mean   2.302720e+00
# std    1.939762e+00
# min    2.310476e-05
# 25%    1.019881e+00
# 50%    1.717136e+00
# 75%    2.959029e+00
# max    4.227217e+01

# %%
df[df['destace(KM)']>30]
# Out:
#                ride_id  rideable_type          started_at  \
# 155425      3152406495  electric_bike 2021-06-27 09:25:54
# 692514    797887309475  electric_bike 2021-06-27 14:08:04
# 805115        74198963    docked_bike 2021-07-30 17:46:58
# 853611           52869  electric_bike 2021-07-02 13:39:27
# 1753019      138338301    docked_bike 2021-08-11 03:01:45
# 3007462      517451142  electric_bike 2021-09-05 11:26:54
# 5340774      647051171  electric_bike 2022-05-28 23:39:19
# 5576993    65051755771  electric_bike 2022-05-15 10:02:30
# 5813899  3533769430396  electric_bike 2022-05-19 10:09:39
#
#                                         start_station_name  start_station_id  \
# 155425                             Streeter Dr & Grand Ave      1.300200e+04
# 692514                                 Avenue O & 134th St      2.021400e+04
# 805115   Broadway & Wilson - Truman College Vaccination...      1.307400e+04
# 853611                            Broadway & Granville Ave      1.557100e+04
# 1753019                       Ewing Ave & Burnham Greenway      2.022300e+04
# 3007462                               Broadway & Ridge Ave      1.557800e+04
# 5340774                            Streeter Dr & Grand Ave      1.300200e+04
# 5576993                            Streeter Dr & Grand Ave      1.300200e+04
# 5813899                             Dearborn St & Adams St      1.305000e+09
#
#                       end_station_name  end_station_id  start_lat  start_lng  \
# 155425             Avenue O & 134th St    2.021400e+04  41.930000 -87.640000
# 692514   Lakeview Ave & Fullerton Pkwy    1.309000e+09  41.651904 -87.539594
# 805115           Halsted St & 111th St    2.012700e+04  41.965221 -87.658139
# 853611        Vincennes Ave & 104th St    2.012400e+04  41.994727 -87.660365
# 1753019           Broadway & Ridge Ave    1.557800e+04  41.712749 -87.534814
# 3007462        Streeter Dr & Grand Ave    1.300200e+04  41.984068 -87.660334
# 5340774    Sheridan Rd & Noyes St (NU)    6.040000e+02  41.790000 -87.600000
# 5576993    Sheridan Rd & Noyes St (NU)    6.040000e+02  41.790000 -87.590000
# 5813899        Streeter Dr & Grand Ave    1.300200e+04  41.878811 -87.629584
#
#            end_lat    end_lng member_casual  destace(KM)
# 155425   41.651918 -87.539564        member    32.022889
# 692514   41.925865 -87.639047        member    31.559257
# 805115   41.692263 -87.642612        casual    30.378841
# 853611   41.705059 -87.657138        casual    32.210766
# 1753019  41.984045 -87.660274        casual    31.906523
# 3007462  41.720000 -87.540000        casual    31.008518
# 5340774  42.058239 -87.677432        casual    30.507047
# 5576993  42.058239 -87.677432        casual    30.691435
# 5813899  41.870000 -88.140000        member    42.272166

# %%
df[df['destace(KM)']>10].shape[0]/df.shape[0]*100
# Out:
# 0.7920191499696707

# %%
#df.drop(index=df[df['destace(KM)']>10].index,axis=0,inplace=True)

# %%
df[df['destace(KM)']<0.01].shape[0]/df.shape[0]*100
# Out:
# 0.7208467390276032

# %%
df.drop(index=df[df['destace(KM)']<0.01].index,axis=0,inplace=True)

# %%
sns.kdeplot(data=df,x='destace(KM)',shade=True)
# Out:
# <AxesSubplot:xlabel='destace(KM)', ylabel='Density'>

# %%
sns.set(rc={'figure.figsize': [10, 4]}, font_scale=1.3)

sns.boxplot(data=df,x='destace(KM)')
# Out:
# <AxesSubplot:xlabel='destace(KM)'>

# %%
df['day']=df['started_at'].dt.day_name()
df[['day']]
# Out:
#                day
# 9        Wednesday
# 51       Wednesday
# 53          Sunday
# 55        Saturday
# 56         Tuesday
# ...            ...
# 5860771     Friday
# 5860772     Sunday
# 5860773   Saturday
# 5860774   Thursday
# 5860775  Wednesday
#
# [4995175 rows x 1 columns]

# %%
df['month']=df['started_at'].dt.month_name()
df[['month']]
# Out:
#         month
# 9        June
# 51       June
# 53       June
# 55       June
# 56       June
# ...       ...
# 5860771   May
# 5860772   May
# 5860773   May
# 5860774   May
# 5860775   May
#
# [4995175 rows x 1 columns]

# %%
df['month'].unique()
# Out:
# array(['June', 'July', 'August', 'September', 'October', 'November',
#        'December', 'January', 'February', 'March', 'April', 'May'],
#       dtype=object)

# %%
df['year']=df['started_at'].dt.year
df['year'].unique()
# Out:
# array([2021, 2022], dtype=int64)

# %%
df['hour']=df['started_at'].dt.hour

# %% [markdown]
# ## Lets divide the day to piriods

# %%
periods={'Morning':[i for i in range(1,14)],'Afternoon':[i for i in range(14,20)],'Evening':[i for i in range(20,22)],
     'Night':[i for i in range(22,25)]}

# %%
def get_periods(x):
    if x in periods['Morning']:
        return 'Morning'
    elif x in periods['Afternoon']:
        return 'Afternoon'
    elif x in periods['Evening']:
        return 'Evening'
    else:
        return 'Night'

# %%
df['period']=df['hour'].apply(get_periods)
df[['period']]
# Out:
#             period
# 9        Afternoon
# 51         Morning
# 53         Morning
# 55       Afternoon
# 56         Morning
# ...            ...
# 5860771      Night
# 5860772  Afternoon
# 5860773    Morning
# 5860774    Morning
# 5860775    Evening
#
# [4995175 rows x 1 columns]

# %%
df['period'].value_counts()
# Out:
# Afternoon    2319184
# Morning      1940700
# Evening       401132
# Night         334159
# Name: period, dtype: int64

# %%
sns.countplot(data=df,x='period')
# Out:
# <AxesSubplot:xlabel='period', ylabel='count'>

# %% [markdown]
# # Lets Answer Business Questions

# %% [markdown]
# ## Questions
#
# ### 1- For each rideable_type calculate the sum of kms ridead
# ### 2- For each member_casual calculate the sum of kms ridead
# ### 3- For each rideable_type for each member_casual calculate the sum of kms driven
# ### 4- How many Rides in every start_station_name and visualize the top 10
# ### 5- How many Rides driven in all Days of this month and visualize them descening
# ### 6- How many Rides driven in all period of the day and visualiaze them descending
# ### 7- How many KMS driven in all period of the day and visualiaze them descending
# ### 8- For each rideable_type for each member_casual which has most driven count
# ### 9- Which start station and end station with maximam number of Rides between them
# ### 10- Which start station and end station with maximam number of kms between them
# ### 11-How many Rides driven in all Months of year and visualize the top 4 month descening
# ### 12-How many kms driven in all Months of year and visualize the top 4 month descening and then divide them    by days of week
# ### 13-How many Rides driven in every year
#
# ### 14- For each month for each week calculate the sum of kms driven (12)
# ### 15- REPET 14 but for each year

# %% [markdown]
# ### 1- For each rideable_type calculate the sum of kms ridead

# %%
sns.set(rc={'figure.figsize': [9, 5]}, font_scale=1.3)
sns.barplot(data=df,x='rideable_type',y='destace(KM)',estimator=sum)
# Out:
# <AxesSubplot:xlabel='rideable_type', ylabel='destace(KM)'>

# %%
df.groupby('rideable_type').sum()[['destace(KM)']]
# Out:
#                 destace(KM)
# rideable_type
# classic_bike   6.249527e+06
# docked_bike    5.233911e+05
# electric_bike  4.331956e+06

# %% [markdown]
# ### 2- For each member_casual calculate the sum of kms ridead

# %%
sns.set(rc={'figure.figsize': [9, 5]}, font_scale=1.3)
sns.barplot(data=df,x='member_casual',y='destace(KM)',estimator=sum)
# Out:
# <AxesSubplot:xlabel='member_casual', ylabel='destace(KM)'>

# %%
### df.groupby('member_casual').sum()[['destace(KM)']]

# %% [markdown]
# ### 3- For each rideable_type for each member_casual calculate the sum of kms driven

# %%
df.pivot_table(index='rideable_type',columns='member_casual',values='destace(KM)',aggfunc=sum)
# Out:
# member_casual        casual        member
# rideable_type
# classic_bike   2.490396e+06  3.759131e+06
# docked_bike    5.233911e+05           NaN
# electric_bike  1.952353e+06  2.379603e+06

# %%
df[(df['member_casual']=='member')&(df['rideable_type']=='docked_bike')]
# Out:
# Empty DataFrame
# Columns: [ride_id, rideable_type, started_at, start_station_name, start_station_id, end_station_name, end_station_id, start_lat, start_lng, end_lat, end_lng, member_casual, destace(KM), day, month, year, hour, period]
# Index: []

# %%
sns.barplot(data=df,x='rideable_type',y='destace(KM)',hue='member_casual',estimator=sum)
# Out:
# <AxesSubplot:xlabel='rideable_type', ylabel='destace(KM)'>

# %% [markdown]
# ### 4- How many Rides in every start_station and visualize the top 10

# %%
df['start_station_name'].value_counts()
# Out:
# Streeter Dr & Grand Ave      374537
# Wells St & Concord Ln         41979
# Clark St & Elm St             38692
# Michigan Ave & Oak St         36770
# Wells St & Elm St             35353
#                               ...
# Evans Ave & 63rd St               1
# West Chatham Park                 1
# Keeler Ave & Madison St           1
# Kedzie & 103rd St - East          1
# Springfield Ave & 63rd St         1
# Name: start_station_name, Length: 1081, dtype: int64

# %%
Index_oftop_10_start_station_name=df['start_station_name'].value_counts().sort_values(ascending=False).head(10).index
Index_oftop_10_start_station_name
# Out:
# Index(['Streeter Dr & Grand Ave', 'Wells St & Concord Ln', 'Clark St & Elm St',
#        'Michigan Ave & Oak St', 'Wells St & Elm St',
#        'Kingsbury St & Kinzie St', 'Millennium Park', 'Theater on the Lake',
#        'Clark St & Armitage Ave', 'Clark St & Lincoln Ave'],
#       dtype='object')

# %%
Data_of_top_10_start_station_name=df[df['start_station_name'].isin(Index_oftop_10_start_station_name)]
Data_of_top_10_start_station_name
# Out:
#               ride_id  rideable_type          started_at  \
# 9          5299462842  electric_bike 2021-06-23 17:57:29
# 55         9869013083  electric_bike 2021-06-12 17:15:12
# 56          710160304   classic_bike 2021-06-01 12:30:24
# 58         7604477276  electric_bike 2021-06-05 15:50:02
# 66       495426074023   classic_bike 2021-06-17 17:55:12
# ...               ...            ...                 ...
# 5860609     884716801  electric_bike 2022-05-30 19:40:34
# 5860639   27248959391  electric_bike 2022-05-01 08:42:53
# 5860709  341844792914  electric_bike 2022-05-31 21:52:44
# 5860735  388996719061  electric_bike 2022-05-10 21:46:44
# 5860743   38940099286  electric_bike 2022-05-10 08:12:34
#
#                start_station_name  start_station_id  \
# 9         Streeter Dr & Grand Ave      1.300200e+04
# 55        Streeter Dr & Grand Ave      1.300200e+04
# 56       Kingsbury St & Kinzie St      1.503000e+09
# 58        Streeter Dr & Grand Ave      1.300200e+04
# 66       Kingsbury St & Kinzie St      1.503000e+09
# ...                           ...               ...
# 5860609   Streeter Dr & Grand Ave      1.300200e+04
# 5860639   Streeter Dr & Grand Ave      1.300200e+04
# 5860709   Streeter Dr & Grand Ave      1.300200e+04
# 5860735   Streeter Dr & Grand Ave      1.300200e+04
# 5860743   Streeter Dr & Grand Ave      1.300200e+04
#
#                        end_station_name  end_station_id  start_lat  start_lng  \
# 9                 Michigan Ave & Oak St    1.304200e+04  41.880000 -87.610000
# 55                Michigan Ave & Oak St    1.304200e+04  41.890000 -87.610000
# 56            Desplaines St & Kinzie St    1.306000e+09  41.889177 -87.638506
# 58                Clark St & Leland Ave    1.309000e+09  41.960000 -87.640000
# 66            Desplaines St & Kinzie St    1.306000e+09  41.889177 -87.638506
# ...                                 ...             ...        ...        ...
# 5860609  California Ave & Milwaukee Ave    1.308400e+04  41.910000 -87.680000
# 5860639  California Ave & Milwaukee Ave    1.308400e+04  41.900000 -87.690000
# 5860709    California Ave & Division St    1.325600e+04  41.900000 -87.690000
# 5860735     Campbell Ave & Montrose Ave    1.562300e+04  41.950000 -87.650000
# 5860743  California Ave & Milwaukee Ave    1.308400e+04  41.920000 -87.710000
#
#            end_lat    end_lng member_casual  destace(KM)        day month  \
# 9        41.901052 -87.623698        member     2.601049  Wednesday  June
# 55       41.901048 -87.623812        member     1.678090   Saturday  June
# 56       41.888716 -87.644448        member     0.494536    Tuesday  June
# 58       41.967113 -87.667159        member     2.380750   Saturday  June
# 66       41.888716 -87.644448        member     0.494536   Thursday  June
# ...            ...        ...           ...          ...        ...   ...
# 5860609  41.922695 -87.697153        member     2.001760     Monday   May
# 5860639  41.922695 -87.697153        member     2.592059     Sunday   May
# 5860709  41.903029 -87.697474        member     0.704315    Tuesday   May
# 5860735  41.961526 -87.691165        member     3.637275    Tuesday   May
# 5860743  41.922695 -87.697153        member     1.104347    Tuesday   May
#
#          year  hour     period
# 9        2021    17  Afternoon
# 55       2021    17  Afternoon
# 56       2021    12    Morning
# 58       2021    15  Afternoon
# 66       2021    17  Afternoon
# ...       ...   ...        ...
# 5860609  2022    19  Afternoon
# 5860639  2022     8    Morning
# 5860709  2022    21    Evening
# 5860735  2022    21    Evening
# 5860743  2022     8    Morning
#
# [690350 rows x 18 columns]

# %%
sns.countplot(data=Data_of_top_10_start_station_name,y='start_station_name',order=Index_oftop_10_start_station_name)
# Out:
# <AxesSubplot:xlabel='count', ylabel='start_station_name'>

# %% [markdown]
# ### 5- How many Rides driven in all Days and visualize them descening

# %%
df['day'].value_counts()
# Out:
# Saturday     827912
# Sunday       716456
# Friday       688765
# Tuesday      686985
# Thursday     685556
# Wednesday    676951
# Monday       642753
# Name: day, dtype: int64

# %%
sns.countplot(data=df,x='day',order=df['day'].value_counts().index)
# Out:
# <AxesSubplot:xlabel='day', ylabel='count'>

# %% [markdown]
# ### 6- How many Rides driven in all period of the day and visualiaze them descending

# %%
df['period'].value_counts()
# Out:
# Afternoon    2287596
# Morning      1911335
# Evening       396412
# Night         330035
# Name: period, dtype: int64

# %%
sns.countplot(data=df,x='period',order=df['period'].value_counts().index)
# Out:
# <AxesSubplot:xlabel='period', ylabel='count'>

# %% [markdown]
# ### 7- How many KMS driven in all period of the day and visualiaze them descending

# %%
sns.barplot(data=df,x='period',y='destace(KM)',estimator=sum,order=df['period'].value_counts().index)
# Out:
# <AxesSubplot:xlabel='period', ylabel='destace(KM)'>

# %%
df.groupby('period').sum()['destace(KM)']
# Out:
# period
# Afternoon    5.222775e+06
# Evening      8.629509e+05
# Morning      4.269627e+06
# Night        7.495212e+05
# Name: destace(KM), dtype: float64

# %% [markdown]
# ### 8- For each rideable_type for each member_casual which has most driven count

# %%
df['dumy']=1

# %%
df.pivot_table(columns='rideable_type',index='member_casual',values='dumy',aggfunc=sum)
# Out:
# rideable_type  classic_bike  docked_bike  electric_bike
# member_casual
# casual            1095018.0     215397.0       758954.0
# member            1869174.0          NaN       986835.0

# %%
sns.countplot(data=df,x='rideable_type',hue='member_casual')
# Out:
# <AxesSubplot:xlabel='rideable_type', ylabel='count'>

# %% [markdown]
# ### 9- Which start station and end station with maximam number of Rides between them

# %%
pivot_Rides= df.pivot_table(columns='start_station_name',index='end_station_name',values='dumy',aggfunc=sum)
pivot_Rides
# Out:
# start_station_name                 111th St - Morgan Park Metra  \
# end_station_name
# 111th St - Morgan Park Metra                                NaN
# 2112 W Peterson Ave                                         NaN
# 532 E 43rd St                                               NaN
# 63rd & Western Ave - north corner                           NaN
# 63rd & Western Ave - south corner                           NaN
# ...                                                         ...
# Woodlawn Ave & Lake Park Ave                                NaN
# Yates Blvd & 75th St                                        NaN
# Yates Blvd & 93rd St                                        NaN
# Yates Blvd & Exchange Ave                                   NaN
# Zapata Academy                                              NaN
#
# start_station_name                 2112 W Peterson Ave  351  532 E 43rd St  \
# end_station_name
# 111th St - Morgan Park Metra                       NaN  NaN            NaN
# 2112 W Peterson Ave                                NaN  NaN            NaN
# 532 E 43rd St                                      NaN  NaN            NaN
# 63rd & Western Ave - north corner                  NaN  NaN            NaN
# 63rd & Western Ave - south corner                  NaN  NaN            NaN
# ...                                                ...  ...            ...
# Woodlawn Ave & Lake Park Ave                       NaN  NaN            NaN
# Yates Blvd & 75th St                               NaN  NaN            NaN
# Yates Blvd & 93rd St                               NaN  NaN            NaN
# Yates Blvd & Exchange Ave                          NaN  NaN            NaN
# Zapata Academy                                     NaN  NaN            NaN
#
# start_station_name                 63rd & Western Ave - north corner  \
# end_station_name
# 111th St - Morgan Park Metra                                     NaN
# 2112 W Peterson Ave                                              NaN
# 532 E 43rd St                                                    NaN
# 63rd & Western Ave - north corner                                NaN
# 63rd & Western Ave - south corner                                NaN
# ...                                                              ...
# Woodlawn Ave & Lake Park Ave                                     NaN
# Yates Blvd & 75th St                                             NaN
# Yates Blvd & 93rd St                                             NaN
# Yates Blvd & Exchange Ave                                        NaN
# Zapata Academy                                                   NaN
#
# start_station_name                 63rd & Western Ave - south corner  \
# end_station_name
# 111th St - Morgan Park Metra                                     NaN
# 2112 W Peterson Ave                                              NaN
# 532 E 43rd St                                                    NaN
# 63rd & Western Ave - north corner                                NaN
# 63rd & Western Ave - south corner                                NaN
# ...                                                              ...
# Woodlawn Ave & Lake Park Ave                                     NaN
# Yates Blvd & 75th St                                             NaN
# Yates Blvd & 93rd St                                             NaN
# Yates Blvd & Exchange Ave                                        NaN
# Zapata Academy                                                   NaN
#
# start_station_name                 63rd St Beach  83rd St (Avalon Park) Metra  \
# end_station_name
# 111th St - Morgan Park Metra                 NaN                          NaN
# 2112 W Peterson Ave                          NaN                          NaN
# 532 E 43rd St                                NaN                          NaN
# 63rd & Western Ave - north corner            NaN                          NaN
# 63rd & Western Ave - south corner            NaN                          NaN
# ...                                          ...                          ...
# Woodlawn Ave & Lake Park Ave                 5.0                          NaN
# Yates Blvd & 75th St                         2.0                          1.0
# Yates Blvd & 93rd St                         1.0                          NaN
# Yates Blvd & Exchange Ave                    NaN                          NaN
# Zapata Academy                               NaN                          NaN
#
# start_station_name                 900 W Harrison St  \
# end_station_name
# 111th St - Morgan Park Metra                     NaN
# 2112 W Peterson Ave                              NaN
# 532 E 43rd St                                    NaN
# 63rd & Western Ave - north corner                NaN
# 63rd & Western Ave - south corner                NaN
# ...                                              ...
# Woodlawn Ave & Lake Park Ave                     NaN
# Yates Blvd & 75th St                             NaN
# Yates Blvd & 93rd St                             NaN
# Yates Blvd & Exchange Ave                        NaN
# Zapata Academy                                   NaN
#
# start_station_name                 Aberdeen St & Jackson Blvd  ...  \
# end_station_name                                               ...
# 111th St - Morgan Park Metra                              NaN  ...
# 2112 W Peterson Ave                                       NaN  ...
# 532 E 43rd St                                             NaN  ...
# 63rd & Western Ave - north corner                         NaN  ...
# 63rd & Western Ave - south corner                         NaN  ...
# ...                                                       ...  ...
# Woodlawn Ave & Lake Park Ave                              NaN  ...
# Yates Blvd & 75th St                                      NaN  ...
# Yates Blvd & 93rd St                                      NaN  ...
# Yates Blvd & Exchange Ave                                 NaN  ...
# Zapata Academy                                            NaN  ...
#
# start_station_name                 Wood St & Milwaukee Ave  \
# end_station_name
# 111th St - Morgan Park Metra                           NaN
# 2112 W Peterson Ave                                    NaN
# 532 E 43rd St                                          NaN
# 63rd & Western Ave - north corner                      NaN
# 63rd & Western Ave - south corner                      NaN
# ...                                                    ...
# Woodlawn Ave & Lake Park Ave                           NaN
# Yates Blvd & 75th St                                   NaN
# Yates Blvd & 93rd St                                   NaN
# Yates Blvd & Exchange Ave                              NaN
# Zapata Academy                                         NaN
#
# start_station_name                 Wood St & Taylor St (Temp)  \
# end_station_name
# 111th St - Morgan Park Metra                              NaN
# 2112 W Peterson Ave                                       NaN
# 532 E 43rd St                                             NaN
# 63rd & Western Ave - north corner                         NaN
# 63rd & Western Ave - south corner                         NaN
# ...                                                       ...
# Woodlawn Ave & Lake Park Ave                              NaN
# Yates Blvd & 75th St                                      NaN
# Yates Blvd & 93rd St                                      NaN
# Yates Blvd & Exchange Ave                                 NaN
# Zapata Academy                                            NaN
#
# start_station_name                 Woodlawn & 103rd - Olive Harvey Vaccination Site  \
# end_station_name
# 111th St - Morgan Park Metra                                                    NaN
# 2112 W Peterson Ave                                                             NaN
# 532 E 43rd St                                                                   NaN
# 63rd & Western Ave - north corner                                               NaN
# 63rd & Western Ave - south corner                                               NaN
# ...                                                                             ...
# Woodlawn Ave & Lake Park Ave                                                    NaN
# Yates Blvd & 75th St                                                            NaN
# Yates Blvd & 93rd St                                                            NaN
# Yates Blvd & Exchange Ave                                                       NaN
# Zapata Academy                                                                  NaN
#
# start_station_name                 Woodlawn Ave & 55th St  \
# end_station_name
# 111th St - Morgan Park Metra                          NaN
# 2112 W Peterson Ave                                   NaN
# 532 E 43rd St                                         NaN
# 63rd & Western Ave - north corner                     NaN
# 63rd & Western Ave - south corner                     NaN
# ...                                                   ...
# Woodlawn Ave & Lake Park Ave                        119.0
# Yates Blvd & 75th St                                  1.0
# Yates Blvd & 93rd St                                  NaN
# Yates Blvd & Exchange Ave                             NaN
# Zapata Academy                                        NaN
#
# start_station_name                 Woodlawn Ave & 75th St  \
# end_station_name
# 111th St - Morgan Park Metra                          NaN
# 2112 W Peterson Ave                                   NaN
# 532 E 43rd St                                         NaN
# 63rd & Western Ave - north corner                     NaN
# 63rd & Western Ave - south corner                     NaN
# ...                                                   ...
# Woodlawn Ave & Lake Park Ave                          NaN
# Yates Blvd & 75th St                                  NaN
# Yates Blvd & 93rd St                                  NaN
# Yates Blvd & Exchange Ave                             NaN
# Zapata Academy                                        NaN
#
# start_station_name                 Woodlawn Ave & Lake Park Ave  \
# end_station_name
# 111th St - Morgan Park Metra                                NaN
# 2112 W Peterson Ave                                         NaN
# 532 E 43rd St                                               NaN
# 63rd & Western Ave - north corner                           NaN
# 63rd & Western Ave - south corner                           NaN
# ...                                                         ...
# Woodlawn Ave & Lake Park Ave                                NaN
# Yates Blvd & 75th St                                        NaN
# Yates Blvd & 93rd St                                        NaN
# Yates Blvd & Exchange Ave                                   NaN
# Zapata Academy                                              NaN
#
# start_station_name                 Yates Blvd & 75th St  Yates Blvd & 93rd St  \
# end_station_name
# 111th St - Morgan Park Metra                        NaN                   NaN
# 2112 W Peterson Ave                                 NaN                   NaN
# 532 E 43rd St                                       NaN                   NaN
# 63rd & Western Ave - north corner                   NaN                   NaN
# 63rd & Western Ave - south corner                   NaN                   NaN
# ...                                                 ...                   ...
# Woodlawn Ave & Lake Park Ave                        NaN                   NaN
# Yates Blvd & 75th St                                NaN                   NaN
# Yates Blvd & 93rd St                                NaN                   1.0
# Yates Blvd & Exchange Ave                           NaN                   NaN
# Zapata Academy                                      NaN                   NaN
#
# start_station_name                 Yates Blvd & Exchange Ave  Zapata Academy
# end_station_name
# 111th St - Morgan Park Metra                             NaN             NaN
# 2112 W Peterson Ave                                      NaN             NaN
# 532 E 43rd St                                            NaN             NaN
# 63rd & Western Ave - north corner                        NaN             NaN
# 63rd & Western Ave - south corner                        NaN             NaN
# ...                                                      ...             ...
# Woodlawn Ave & Lake Park Ave                             NaN             NaN
# Yates Blvd & 75th St                                     NaN             NaN
# Yates Blvd & 93rd St                                     NaN             NaN
# Yates Blvd & Exchange Ave                                NaN             NaN
# Zapata Academy                                           NaN             NaN
#
# [1091 rows x 1081 columns]

# %%
pivot_Rides.max().sort_values(ascending=False)
# Out:
# start_station_name
# Ellis Ave & 60th St                  6283.0
# University Ave & 57th St             5887.0
# Ellis Ave & 55th St                  5546.0
# DuSable Lake Shore Dr & Monroe St    5359.0
# Millennium Park                      5088.0
#                                       ...
# Kolin Ave & Archer Ave                  1.0
# Pullman - Planet Fitness                1.0
# Lafayette Ave & 87th St - NW            1.0
# Vincennes Ave & 99th St                 1.0
# Zapata Academy                          1.0
# Length: 1081, dtype: float64

# %%
max_start_station_km=pivot_Rides['Ellis Ave & 60th St'].sort_values(ascending=False).index[0]
max_start_station_km
# Out:
# 'University Ave & 57th St'

# %%
max_end_station_km=pivot_Rides[max_start_station_km].sort_values(ascending=False).index[0]
max_end_station_km
# Out:
# 'Ellis Ave & 60th St'

# %%
df[(df['start_station_name']==max_start_station_km)&(df['end_station_name']==max_end_station_km)]
# Out:
#                ride_id rideable_type          started_at  \
# 121127   9574942265602  classic_bike 2021-06-04 17:19:01
# 121132     87767623566  classic_bike 2021-06-01 17:24:03
# 121137     60119470620  classic_bike 2021-06-05 23:11:36
# 121138        50390664  classic_bike 2021-06-05 22:11:49
# 121141        46521402  classic_bike 2021-06-09 21:42:51
# ...                ...           ...                 ...
# 5712316      147633069  classic_bike 2022-05-30 17:39:24
# 5712317  4088358264396  classic_bike 2022-05-12 15:28:03
# 5712318         453615  classic_bike 2022-05-20 18:16:17
# 5712319       61179865  classic_bike 2022-05-20 12:36:48
# 5712320      663120167  classic_bike 2022-05-19 18:26:44
#
#                start_station_name  start_station_id     end_station_name  \
# 121127   University Ave & 57th St      1.503000e+09  Ellis Ave & 60th St
# 121132   University Ave & 57th St      1.503000e+09  Ellis Ave & 60th St
# 121137   University Ave & 57th St      1.503000e+09  Ellis Ave & 60th St
# 121138   University Ave & 57th St      1.503000e+09  Ellis Ave & 60th St
# 121141   University Ave & 57th St      1.503000e+09  Ellis Ave & 60th St
# ...                           ...               ...                  ...
# 5712316  University Ave & 57th St      1.503000e+09  Ellis Ave & 60th St
# 5712317  University Ave & 57th St      1.503000e+09  Ellis Ave & 60th St
# 5712318  University Ave & 57th St      1.503000e+09  Ellis Ave & 60th St
# 5712319  University Ave & 57th St      1.503000e+09  Ellis Ave & 60th St
# 5712320  University Ave & 57th St      1.503000e+09  Ellis Ave & 60th St
#
#          end_station_id  start_lat  start_lng    end_lat    end_lng  \
# 121127     1.503000e+09  41.791478 -87.599861  41.785097 -87.601073
# 121132     1.503000e+09  41.791478 -87.599861  41.785097 -87.601073
# 121137     1.503000e+09  41.791478 -87.599861  41.785097 -87.601073
# 121138     1.503000e+09  41.791478 -87.599861  41.785097 -87.601073
# 121141     1.503000e+09  41.791478 -87.599861  41.785097 -87.601073
# ...                 ...        ...        ...        ...        ...
# 5712316    1.503000e+09  41.791478 -87.599861  41.785097 -87.601073
# 5712317    1.503000e+09  41.791478 -87.599861  41.785097 -87.601073
# 5712318    1.503000e+09  41.791478 -87.599861  41.785097 -87.601073
# 5712319    1.503000e+09  41.791478 -87.599861  41.785097 -87.601073
# 5712320    1.503000e+09  41.791478 -87.599861  41.785097 -87.601073
#
#         member_casual  destace(KM)        day month  year  hour     period  \
# 121127         member     0.716597     Friday  June  2021    17  Afternoon
# 121132         member     0.716597    Tuesday  June  2021    17  Afternoon
# 121137         member     0.716597   Saturday  June  2021    23      Night
# 121138         member     0.716597   Saturday  June  2021    22      Night
# 121141         member     0.716597  Wednesday  June  2021    21    Evening
# ...               ...          ...        ...   ...   ...   ...        ...
# 5712316        casual     0.716597     Monday   May  2022    17  Afternoon
# 5712317        member     0.716597   Thursday   May  2022    15  Afternoon
# 5712318        member     0.716597     Friday   May  2022    18  Afternoon
# 5712319        member     0.716597     Friday   May  2022    12    Morning
# 5712320        member     0.716597   Thursday   May  2022    18  Afternoon
#
#          dumy
# 121127      1
# 121132      1
# 121137      1
# 121138      1
# 121141      1
# ...       ...
# 5712316     1
# 5712317     1
# 5712318     1
# 5712319     1
# 5712320     1
#
# [5887 rows x 19 columns]

# %% [markdown]
# ### 10- Which start station and end station with maximam number of kms between them

# %%
pivot= df.pivot_table(columns='start_station_name',index='end_station_name',values='destace(KM)',aggfunc=sum)
pivot
# Out:
# start_station_name                 111th St - Morgan Park Metra  \
# end_station_name
# 111th St - Morgan Park Metra                                NaN
# 2112 W Peterson Ave                                         NaN
# 532 E 43rd St                                               NaN
# 63rd & Western Ave - north corner                           NaN
# 63rd & Western Ave - south corner                           NaN
# ...                                                         ...
# Woodlawn Ave & Lake Park Ave                                NaN
# Yates Blvd & 75th St                                        NaN
# Yates Blvd & 93rd St                                        NaN
# Yates Blvd & Exchange Ave                                   NaN
# Zapata Academy                                              NaN
#
# start_station_name                 2112 W Peterson Ave  351  532 E 43rd St  \
# end_station_name
# 111th St - Morgan Park Metra                       NaN  NaN            NaN
# 2112 W Peterson Ave                                NaN  NaN            NaN
# 532 E 43rd St                                      NaN  NaN            NaN
# 63rd & Western Ave - north corner                  NaN  NaN            NaN
# 63rd & Western Ave - south corner                  NaN  NaN            NaN
# ...                                                ...  ...            ...
# Woodlawn Ave & Lake Park Ave                       NaN  NaN            NaN
# Yates Blvd & 75th St                               NaN  NaN            NaN
# Yates Blvd & 93rd St                               NaN  NaN            NaN
# Yates Blvd & Exchange Ave                          NaN  NaN            NaN
# Zapata Academy                                     NaN  NaN            NaN
#
# start_station_name                 63rd & Western Ave - north corner  \
# end_station_name
# 111th St - Morgan Park Metra                                     NaN
# 2112 W Peterson Ave                                              NaN
# 532 E 43rd St                                                    NaN
# 63rd & Western Ave - north corner                                NaN
# 63rd & Western Ave - south corner                                NaN
# ...                                                              ...
# Woodlawn Ave & Lake Park Ave                                     NaN
# Yates Blvd & 75th St                                             NaN
# Yates Blvd & 93rd St                                             NaN
# Yates Blvd & Exchange Ave                                        NaN
# Zapata Academy                                                   NaN
#
# start_station_name                 63rd & Western Ave - south corner  \
# end_station_name
# 111th St - Morgan Park Metra                                     NaN
# 2112 W Peterson Ave                                              NaN
# 532 E 43rd St                                                    NaN
# 63rd & Western Ave - north corner                                NaN
# 63rd & Western Ave - south corner                                NaN
# ...                                                              ...
# Woodlawn Ave & Lake Park Ave                                     NaN
# Yates Blvd & 75th St                                             NaN
# Yates Blvd & 93rd St                                             NaN
# Yates Blvd & Exchange Ave                                        NaN
# Zapata Academy                                                   NaN
#
# start_station_name                 63rd St Beach  83rd St (Avalon Park) Metra  \
# end_station_name
# 111th St - Morgan Park Metra                 NaN                          NaN
# 2112 W Peterson Ave                          NaN                          NaN
# 532 E 43rd St                                NaN                          NaN
# 63rd & Western Ave - north corner            NaN                          NaN
# 63rd & Western Ave - south corner            NaN                          NaN
# ...                                          ...                          ...
# Woodlawn Ave & Lake Park Ave           20.342515                          NaN
# Yates Blvd & 75th St                    5.190108                     3.479421
# Yates Blvd & 93rd St                    6.144123                          NaN
# Yates Blvd & Exchange Ave                    NaN                          NaN
# Zapata Academy                               NaN                          NaN
#
# start_station_name                 900 W Harrison St  \
# end_station_name
# 111th St - Morgan Park Metra                     NaN
# 2112 W Peterson Ave                              NaN
# 532 E 43rd St                                    NaN
# 63rd & Western Ave - north corner                NaN
# 63rd & Western Ave - south corner                NaN
# ...                                              ...
# Woodlawn Ave & Lake Park Ave                     NaN
# Yates Blvd & 75th St                             NaN
# Yates Blvd & 93rd St                             NaN
# Yates Blvd & Exchange Ave                        NaN
# Zapata Academy                                   NaN
#
# start_station_name                 Aberdeen St & Jackson Blvd  ...  \
# end_station_name                                               ...
# 111th St - Morgan Park Metra                              NaN  ...
# 2112 W Peterson Ave                                       NaN  ...
# 532 E 43rd St                                             NaN  ...
# 63rd & Western Ave - north corner                         NaN  ...
# 63rd & Western Ave - south corner                         NaN  ...
# ...                                                       ...  ...
# Woodlawn Ave & Lake Park Ave                              NaN  ...
# Yates Blvd & 75th St                                      NaN  ...
# Yates Blvd & 93rd St                                      NaN  ...
# Yates Blvd & Exchange Ave                                 NaN  ...
# Zapata Academy                                            NaN  ...
#
# start_station_name                 Wood St & Milwaukee Ave  \
# end_station_name
# 111th St - Morgan Park Metra                           NaN
# 2112 W Peterson Ave                                    NaN
# 532 E 43rd St                                          NaN
# 63rd & Western Ave - north corner                      NaN
# 63rd & Western Ave - south corner                      NaN
# ...                                                    ...
# Woodlawn Ave & Lake Park Ave                           NaN
# Yates Blvd & 75th St                                   NaN
# Yates Blvd & 93rd St                                   NaN
# Yates Blvd & Exchange Ave                              NaN
# Zapata Academy                                         NaN
#
# start_station_name                 Wood St & Taylor St (Temp)  \
# end_station_name
# 111th St - Morgan Park Metra                              NaN
# 2112 W Peterson Ave                                       NaN
# 532 E 43rd St                                             NaN
# 63rd & Western Ave - north corner                         NaN
# 63rd & Western Ave - south corner                         NaN
# ...                                                       ...
# Woodlawn Ave & Lake Park Ave                              NaN
# Yates Blvd & 75th St                                      NaN
# Yates Blvd & 93rd St                                      NaN
# Yates Blvd & Exchange Ave                                 NaN
# Zapata Academy                                            NaN
#
# start_station_name                 Woodlawn & 103rd - Olive Harvey Vaccination Site  \
# end_station_name
# 111th St - Morgan Park Metra                                                    NaN
# 2112 W Peterson Ave                                                             NaN
# 532 E 43rd St                                                                   NaN
# 63rd & Western Ave - north corner                                               NaN
# 63rd & Western Ave - south corner                                               NaN
# ...                                                                             ...
# Woodlawn Ave & Lake Park Ave                                                    NaN
# Yates Blvd & 75th St                                                            NaN
# Yates Blvd & 93rd St                                                            NaN
# Yates Blvd & Exchange Ave                                                       NaN
# Zapata Academy                                                                  NaN
#
# start_station_name                 Woodlawn Ave & 55th St  \
# end_station_name
# 111th St - Morgan Park Metra                          NaN
# 2112 W Peterson Ave                                   NaN
# 532 E 43rd St                                         NaN
# 63rd & Western Ave - north corner                     NaN
# 63rd & Western Ave - south corner                     NaN
# ...                                                   ...
# Woodlawn Ave & Lake Park Ave                   249.108968
# Yates Blvd & 75th St                             4.761322
# Yates Blvd & 93rd St                                  NaN
# Yates Blvd & Exchange Ave                             NaN
# Zapata Academy                                        NaN
#
# start_station_name                 Woodlawn Ave & 75th St  \
# end_station_name
# 111th St - Morgan Park Metra                          NaN
# 2112 W Peterson Ave                                   NaN
# 532 E 43rd St                                         NaN
# 63rd & Western Ave - north corner                     NaN
# 63rd & Western Ave - south corner                     NaN
# ...                                                   ...
# Woodlawn Ave & Lake Park Ave                          NaN
# Yates Blvd & 75th St                                  NaN
# Yates Blvd & 93rd St                                  NaN
# Yates Blvd & Exchange Ave                             NaN
# Zapata Academy                                        NaN
#
# start_station_name                 Woodlawn Ave & Lake Park Ave  \
# end_station_name
# 111th St - Morgan Park Metra                                NaN
# 2112 W Peterson Ave                                         NaN
# 532 E 43rd St                                               NaN
# 63rd & Western Ave - north corner                           NaN
# 63rd & Western Ave - south corner                           NaN
# ...                                                         ...
# Woodlawn Ave & Lake Park Ave                                NaN
# Yates Blvd & 75th St                                        NaN
# Yates Blvd & 93rd St                                        NaN
# Yates Blvd & Exchange Ave                                   NaN
# Zapata Academy                                              NaN
#
# start_station_name                 Yates Blvd & 75th St  Yates Blvd & 93rd St  \
# end_station_name
# 111th St - Morgan Park Metra                        NaN                   NaN
# 2112 W Peterson Ave                                 NaN                   NaN
# 532 E 43rd St                                       NaN                   NaN
# 63rd & Western Ave - north corner                   NaN                   NaN
# 63rd & Western Ave - south corner                   NaN                   NaN
# ...                                                 ...                   ...
# Woodlawn Ave & Lake Park Ave                        NaN                   NaN
# Yates Blvd & 75th St                                NaN                   NaN
# Yates Blvd & 93rd St                                NaN              0.583246
# Yates Blvd & Exchange Ave                           NaN                   NaN
# Zapata Academy                                      NaN                   NaN
#
# start_station_name                 Yates Blvd & Exchange Ave  Zapata Academy
# end_station_name
# 111th St - Morgan Park Metra                             NaN             NaN
# 2112 W Peterson Ave                                      NaN             NaN
# 532 E 43rd St                                            NaN             NaN
# 63rd & Western Ave - north corner                        NaN             NaN
# 63rd & Western Ave - south corner                        NaN             NaN
# ...                                                      ...             ...
# Woodlawn Ave & Lake Park Ave                             NaN             NaN
# Yates Blvd & 75th St                                     NaN             NaN
# Yates Blvd & 93rd St                                     NaN             NaN
# Yates Blvd & Exchange Ave                                NaN             NaN
# Zapata Academy                                           NaN             NaN
#
# [1091 rows x 1081 columns]

# %%
max_start_station=pivot.max().sort_values(ascending=False).index[0]
max_start_station
# Out:
# 'Streeter Dr & Grand Ave'

# %%
max_end_station=pivot[max_start_station].sort_values(ascending=False).index[0]
max_end_station
# Out:
# 'Theater on the Lake'

# %%
df[(df['start_station_name']==max_start_station)&(df['end_station_name']==max_end_station)]
# Out:
#               ride_id  rideable_type          started_at  \
# 55412    778487381400   classic_bike 2021-06-06 12:54:55
# 55413    678803499025   classic_bike 2021-06-29 17:27:13
# 55414       940570822    docked_bike 2021-06-06 15:08:40
# 128471        6075311   classic_bike 2021-06-13 12:05:31
# 128472         621589   classic_bike 2021-06-17 22:17:01
# ...               ...            ...                 ...
# 5731516       5319871   classic_bike 2022-05-22 13:44:34
# 5731517      69399233   classic_bike 2022-05-10 16:51:27
# 5731518      53389482   classic_bike 2022-05-10 18:59:26
# 5732169     306092336  electric_bike 2022-05-30 20:18:18
# 5732172       5964592  electric_bike 2022-05-17 20:16:58
#
#               start_station_name  start_station_id     end_station_name  \
# 55412    Streeter Dr & Grand Ave           13022.0  Theater on the Lake
# 55413    Streeter Dr & Grand Ave           13022.0  Theater on the Lake
# 55414    Streeter Dr & Grand Ave           13022.0  Theater on the Lake
# 128471   Streeter Dr & Grand Ave           13022.0  Theater on the Lake
# 128472   Streeter Dr & Grand Ave           13022.0  Theater on the Lake
# ...                          ...               ...                  ...
# 5731516  Streeter Dr & Grand Ave           13022.0  Theater on the Lake
# 5731517  Streeter Dr & Grand Ave           13022.0  Theater on the Lake
# 5731518  Streeter Dr & Grand Ave           13022.0  Theater on the Lake
# 5732169  Streeter Dr & Grand Ave           13002.0  Theater on the Lake
# 5732172  Streeter Dr & Grand Ave           13002.0  Theater on the Lake
#
#          end_station_id  start_lat  start_lng    end_lat    end_lng  \
# 55412      1.308000e+09  41.892278 -87.612043  41.926277 -87.630834
# 55413      1.308000e+09  41.892278 -87.612043  41.926277 -87.630834
# 55414      1.308000e+09  41.892278 -87.612043  41.926277 -87.630834
# 128471     1.308000e+09  41.892278 -87.612043  41.926277 -87.630834
# 128472     1.308000e+09  41.892278 -87.612043  41.926277 -87.630834
# ...                 ...        ...        ...        ...        ...
# 5731516    1.308000e+09  41.892278 -87.612043  41.926277 -87.630834
# 5731517    1.308000e+09  41.892278 -87.612043  41.926277 -87.630834
# 5731518    1.308000e+09  41.892278 -87.612043  41.926277 -87.630834
# 5732169    1.308000e+09  41.900000 -87.620000  41.926277 -87.630834
# 5732172    1.308000e+09  41.910000 -87.620000  41.926277 -87.630834
#
#         member_casual  destace(KM)       day month  year  hour     period  \
# 55412          member     4.087827    Sunday  June  2021    12    Morning
# 55413          member     4.087827   Tuesday  June  2021    17  Afternoon
# 55414          casual     4.087827    Sunday  June  2021    15  Afternoon
# 128471         casual     4.087827    Sunday  June  2021    12    Morning
# 128472         casual     4.087827  Thursday  June  2021    22      Night
# ...               ...          ...       ...   ...   ...   ...        ...
# 5731516        casual     4.087827    Sunday   May  2022    13    Morning
# 5731517        casual     4.087827   Tuesday   May  2022    16  Afternoon
# 5731518        casual     4.087827   Tuesday   May  2022    18  Afternoon
# 5732169        casual     3.056308    Monday   May  2022    20    Evening
# 5732172        casual     2.019744   Tuesday   May  2022    20    Evening
#
#          dumy
# 55412       1
# 55413       1
# 55414       1
# 128471      1
# 128472      1
# ...       ...
# 5731516     1
# 5731517     1
# 5731518     1
# 5732169     1
# 5732172     1
#
# [3363 rows x 19 columns]

# %% [markdown]
# ### 11-How many Rides driven in all Months of year and visualize the top 4 month descening

# %%
sns.countplot(data=df,y='month',order=df['month'].value_counts().sort_values(ascending=False).index)
# Out:
# <AxesSubplot:xlabel='count', ylabel='month'>

# %%
df['month'].value_counts()
# Out:
# July         712914
# August       697684
# September    652566
# June         627061
# May          545905
# October      529178
# April        305049
# November     294783
# March        238598
# December     204218
# February      98093
# January       89126
# Name: month, dtype: int64

# %%
#visualize the top 4 month descening
top_4_month_descening_index=df['month'].value_counts().sort_values(ascending=False).head(4).index

# %%
top_4_month_descening_data=df[df['month'].isin(top_4_month_descening_index)]
top_4_month_descening_data
# Out:
#               ride_id  rideable_type          started_at  \
# 9          5299462842  electric_bike 2021-06-23 17:57:29
# 51        41853006552   classic_bike 2021-06-23 08:39:36
# 53        60970908555   classic_bike 2021-06-27 12:26:58
# 55         9869013083  electric_bike 2021-06-12 17:15:12
# 56          710160304   classic_bike 2021-06-01 12:30:24
# ...               ...            ...                 ...
# 3112499        660732   classic_bike 2021-09-22 15:46:57
# 3112500      14453604   classic_bike 2021-09-25 16:25:23
# 3112501    6346572345   classic_bike 2021-09-25 16:26:05
# 3112502  493607711006   classic_bike 2021-09-15 17:57:48
# 3112503    3431902023  electric_bike 2021-09-11 18:01:06
#
#                 start_station_name  start_station_id  \
# 9          Streeter Dr & Grand Ave      1.300200e+04
# 51       Desplaines St & Kinzie St      1.306000e+09
# 53             Clark St & Grace St      1.307000e+09
# 55         Streeter Dr & Grand Ave      1.300200e+04
# 56        Kingsbury St & Kinzie St      1.503000e+09
# ...                            ...               ...
# 3112499        Ellis Ave & 83rd St      5.840000e+02
# 3112500        Ellis Ave & 60th St      1.503000e+09
# 3112501        Ellis Ave & 60th St      1.503000e+09
# 3112502        Ellis Ave & 60th St      1.503000e+09
# 3112503        Wells St & Huron St      1.306000e+09
#
#                    end_station_name  end_station_id  start_lat  start_lng  \
# 9             Michigan Ave & Oak St    1.304200e+04  41.880000 -87.610000
# 51         Kingsbury St & Kinzie St    1.503000e+09  41.888716 -87.644448
# 53            Clark St & Leland Ave    1.309000e+09  41.950780 -87.659172
# 55            Michigan Ave & Oak St    1.304200e+04  41.890000 -87.610000
# 56        Desplaines St & Kinzie St    1.306000e+09  41.889177 -87.638506
# ...                             ...             ...        ...        ...
# 3112499  Stony Island Ave & 75th St    1.503000e+09  41.744123 -87.599034
# 3112500          Shore Dr & 55th St    1.308000e+09  41.785097 -87.601073
# 3112501          Shore Dr & 55th St    1.308000e+09  41.785097 -87.601073
# 3112502          Shore Dr & 55th St    1.308000e+09  41.785097 -87.601073
# 3112503        Clinton St & Lake St    1.302100e+04  41.894887 -87.634343
#
#            end_lat    end_lng member_casual  destace(KM)        day  \
# 9        41.901052 -87.623698        member     2.601049  Wednesday
# 51       41.889177 -87.638506        member     0.494536  Wednesday
# 53       41.967096 -87.667429        member     1.938474     Sunday
# 55       41.901048 -87.623812        member     1.678090   Saturday
# 56       41.888716 -87.644448        member     0.494536    Tuesday
# ...            ...        ...           ...          ...        ...
# 3112499  41.758670 -87.586883        casual     1.905899  Wednesday
# 3112500  41.795212 -87.580715        casual     2.028202   Saturday
# 3112501  41.795212 -87.580715        casual     2.028202   Saturday
# 3112502  41.795212 -87.580715        casual     2.028202  Wednesday
# 3112503  41.885771 -87.641373        member     1.168785   Saturday
#
#              month  year  hour     period
# 9             June  2021    17  Afternoon
# 51            June  2021     8    Morning
# 53            June  2021    12    Morning
# 55            June  2021    17  Afternoon
# 56            June  2021    12    Morning
# ...            ...   ...   ...        ...
# 3112499  September  2021    15  Afternoon
# 3112500  September  2021    16  Afternoon
# 3112501  September  2021    16  Afternoon
# 3112502  September  2021    17  Afternoon
# 3112503  September  2021    18  Afternoon
#
# [2690225 rows x 18 columns]

# %%
sns.countplot(data=top_4_month_descening_data,y='month',
              order=top_4_month_descening_data['month'].value_counts().sort_values(ascending=False).index)
# Out:
# <AxesSubplot:xlabel='count', ylabel='month'>

# %% [markdown]
# ### 12-How many kms driven in all Months of year and visualize the top 4 month descening and then divide them by days of week

# %%
df.groupby('month').sum()[['destace(KM)']]
# Out:
#             destace(KM)
# month
# April      6.722722e+05
# August     1.690874e+06
# December   4.173494e+05
# February   1.888357e+05
# January    1.652201e+05
# July       1.736752e+06
# June       1.524901e+06
# March      5.228555e+05
# May        1.288609e+06
# November   6.117740e+05
# October    1.196282e+06
# September  1.570105e+06

# %%
top_4_month_km_idx=df.groupby('month').sum()['destace(KM)'].sort_values(ascending=False).head(4).index
top_4_month_km_idx
# Out:
# Index(['July', 'August', 'September', 'June'], dtype='object', name='month')

# %%
top_4_month_km_data=df[df['month'].isin(top_4_month_km_idx)]
top_4_month_km_data
# Out:
#               ride_id  rideable_type          started_at  \
# 9          5299462842  electric_bike 2021-06-23 17:57:29
# 51        41853006552   classic_bike 2021-06-23 08:39:36
# 53        60970908555   classic_bike 2021-06-27 12:26:58
# 55         9869013083  electric_bike 2021-06-12 17:15:12
# 56          710160304   classic_bike 2021-06-01 12:30:24
# ...               ...            ...                 ...
# 3112499        660732   classic_bike 2021-09-22 15:46:57
# 3112500      14453604   classic_bike 2021-09-25 16:25:23
# 3112501    6346572345   classic_bike 2021-09-25 16:26:05
# 3112502  493607711006   classic_bike 2021-09-15 17:57:48
# 3112503    3431902023  electric_bike 2021-09-11 18:01:06
#
#                 start_station_name  start_station_id  \
# 9          Streeter Dr & Grand Ave      1.300200e+04
# 51       Desplaines St & Kinzie St      1.306000e+09
# 53             Clark St & Grace St      1.307000e+09
# 55         Streeter Dr & Grand Ave      1.300200e+04
# 56        Kingsbury St & Kinzie St      1.503000e+09
# ...                            ...               ...
# 3112499        Ellis Ave & 83rd St      5.840000e+02
# 3112500        Ellis Ave & 60th St      1.503000e+09
# 3112501        Ellis Ave & 60th St      1.503000e+09
# 3112502        Ellis Ave & 60th St      1.503000e+09
# 3112503        Wells St & Huron St      1.306000e+09
#
#                    end_station_name  end_station_id  start_lat  start_lng  \
# 9             Michigan Ave & Oak St    1.304200e+04  41.880000 -87.610000
# 51         Kingsbury St & Kinzie St    1.503000e+09  41.888716 -87.644448
# 53            Clark St & Leland Ave    1.309000e+09  41.950780 -87.659172
# 55            Michigan Ave & Oak St    1.304200e+04  41.890000 -87.610000
# 56        Desplaines St & Kinzie St    1.306000e+09  41.889177 -87.638506
# ...                             ...             ...        ...        ...
# 3112499  Stony Island Ave & 75th St    1.503000e+09  41.744123 -87.599034
# 3112500          Shore Dr & 55th St    1.308000e+09  41.785097 -87.601073
# 3112501          Shore Dr & 55th St    1.308000e+09  41.785097 -87.601073
# 3112502          Shore Dr & 55th St    1.308000e+09  41.785097 -87.601073
# 3112503        Clinton St & Lake St    1.302100e+04  41.894887 -87.634343
#
#            end_lat    end_lng member_casual  destace(KM)        day  \
# 9        41.901052 -87.623698        member     2.601049  Wednesday
# 51       41.889177 -87.638506        member     0.494536  Wednesday
# 53       41.967096 -87.667429        member     1.938474     Sunday
# 55       41.901048 -87.623812        member     1.678090   Saturday
# 56       41.888716 -87.644448        member     0.494536    Tuesday
# ...            ...        ...           ...          ...        ...
# 3112499  41.758670 -87.586883        casual     1.905899  Wednesday
# 3112500  41.795212 -87.580715        casual     2.028202   Saturday
# 3112501  41.795212 -87.580715        casual     2.028202   Saturday
# 3112502  41.795212 -87.580715        casual     2.028202  Wednesday
# 3112503  41.885771 -87.641373        member     1.168785   Saturday
#
#              month  year  hour     period
# 9             June  2021    17  Afternoon
# 51            June  2021     8    Morning
# 53            June  2021    12    Morning
# 55            June  2021    17  Afternoon
# 56            June  2021    12    Morning
# ...            ...   ...   ...        ...
# 3112499  September  2021    15  Afternoon
# 3112500  September  2021    16  Afternoon
# 3112501  September  2021    16  Afternoon
# 3112502  September  2021    17  Afternoon
# 3112503  September  2021    18  Afternoon
#
# [2690225 rows x 18 columns]

# %%
sns.barplot(data=top_4_month_km_data,y='month',x='destace(KM)' ,
                           order=top_4_month_km_data['month'].value_counts().sort_values(ascending=False).index)
# Out:
# <AxesSubplot:xlabel='destace(KM)', ylabel='month'>

# %%
sns.barplot(data=top_4_month_km_data,x='month',y='destace(KM)' ,hue='day',
                           order=top_4_month_km_data['month'].value_counts().sort_values(ascending=False).index)
# Out:
# <AxesSubplot:xlabel='month', ylabel='destace(KM)'>

# %% [markdown]
# ### 13-How many Rides driven in every year

# %%
sns.countplot(data=df,x='year')
# Out:
# <AxesSubplot:xlabel='year', ylabel='count'>

# %%
sns.countplot(data=df,y='month',hue='year',
              order=df['month'].value_counts().sort_values(ascending=False).index)
# Out:
# <AxesSubplot:xlabel='count', ylabel='month'>

# %% [markdown]
# ### 14- For each month for each week calculate the sum of kms driven (Q-12)

# %%
df.pivot_table(columns='month',index='day',values='destace(KM)',aggfunc=sum)
# Out:
# month              April         August      December      February  \
# day
# Friday      89247.200599  231985.971800  70015.327910  22881.626816
# Monday      79735.123292  221904.277658  50952.516081  39306.821629
# Saturday   149793.504470  300991.718334  50235.060819  19220.606177
# Sunday      81598.090530  314201.945630  39695.383915  26668.359138
# Thursday   100431.647161  208337.188639  82351.477499  21175.202421
# Tuesday     98784.224176  224377.298732  47652.100184  31579.889763
# Wednesday   72682.432732  189075.267725  76447.513505  28003.183201
#
# month           January           July           June         March  \
# day
# Friday     21790.754763  285208.827236  208088.472580  46119.309632
# Monday     24741.148095  194183.167878  156908.524277  82578.256838
# Saturday   23562.468616  359408.056975  262054.880545  67774.052292
# Sunday     17708.200314  235918.676139  246100.137457  74405.396619
# Thursday   26586.969630  252835.321775  187214.999199  78137.340113
# Tuesday    26224.674892  201408.921016  226777.295018  78212.031987
# Wednesday  24605.932438  207789.510912  237756.729412  95629.095346
#
# month                May       November        October      September
# day
# Friday     144175.969796   69437.895035  184711.856490  211634.579213
# Monday     222872.210142  100139.212784  113438.592130  186699.657530
# Saturday   209520.137798   89727.053095  261329.600177  274017.937649
# Sunday     217183.811635   79150.855654  200878.875927  255016.782633
# Thursday   172339.785244   68607.597119  122159.018067  247564.478227
# Tuesday    188231.081414  113749.364586  156368.398557  163730.909690
# Wednesday  134285.956734   90962.022694  157395.212651  231440.228212

# %%
sns.heatmap(df.pivot_table(columns='month',index='day',values='destace(KM)',aggfunc=sum))
# Out:
# <AxesSubplot:xlabel='month', ylabel='day'>

# %% [markdown]
# ### 15

# %%
df_2021=df[df['year']==2021]
df_2022=df[df['year']==2022]

# %%
#2021
df_2021.pivot_table(columns='month',index='day',values='destace(KM)',aggfunc=sum)
# Out:
# month             August      December           July           June  \
# day
# Friday     231985.971800  70015.327910  285208.827236  208088.472580
# Monday     221904.277658  50952.516081  194183.167878  156908.524277
# Saturday   300991.718334  50235.060819  359408.056975  262054.880545
# Sunday     314201.945630  39695.383915  235918.676139  246100.137457
# Thursday   208337.188639  82351.477499  252835.321775  187214.999199
# Tuesday    224377.298732  47652.100184  201408.921016  226777.295018
# Wednesday  189075.267725  76447.513505  207789.510912  237756.729412
#
# month           November        October      September
# day
# Friday      69437.895035  184711.856490  211634.579213
# Monday     100139.212784  113438.592130  186699.657530
# Saturday    89727.053095  261329.600177  274017.937649
# Sunday      79150.855654  200878.875927  255016.782633
# Thursday    68607.597119  122159.018067  247564.478227
# Tuesday    113749.364586  156368.398557  163730.909690
# Wednesday   90962.022694  157395.212651  231440.228212

# %%
sns.heatmap(df_2021.pivot_table(columns='month',index='day',values='destace(KM)',aggfunc=sum))
# Out:
# <AxesSubplot:xlabel='month', ylabel='day'>

# %%
#2022
df_2022.pivot_table(columns='month',index='day',values='destace(KM)',aggfunc=sum)
# Out:
# month              April      February       January         March  \
# day
# Friday      89247.200599  22881.626816  21790.754763  46119.309632
# Monday      79735.123292  39306.821629  24741.148095  82578.256838
# Saturday   149793.504470  19220.606177  23562.468616  67774.052292
# Sunday      81598.090530  26668.359138  17708.200314  74405.396619
# Thursday   100431.647161  21175.202421  26586.969630  78137.340113
# Tuesday     98784.224176  31579.889763  26224.674892  78212.031987
# Wednesday   72682.432732  28003.183201  24605.932438  95629.095346
#
# month                May
# day
# Friday     144175.969796
# Monday     222872.210142
# Saturday   209520.137798
# Sunday     217183.811635
# Thursday   172339.785244
# Tuesday    188231.081414
# Wednesday  134285.956734

# %%
sns.heatmap(df_2022.pivot_table(columns='month',index='day',values='destace(KM)',aggfunc=sum))
# Out:
# <AxesSubplot:xlabel='month', ylabel='day'>
